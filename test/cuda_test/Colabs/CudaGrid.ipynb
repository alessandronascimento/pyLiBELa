# %% [markdown]
# <a href="https://colab.research.google.com/github/alessandronascimento/pyLiBELa/blob/alex-works/test/cuda_test/Colabs/CudaGrid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install condacolab
! apt-get install openbabel libopenbabel-dev python-dev-is-python3 zlib1g-dev libeigen3-dev libgsl-dev libnlopt-cxx-dev libgsl-dev
import condacolab
condacolab.install()
! mamba install -c anaconda py-boost
# !nvidia-smi
# Out:
# Collecting condacolab
#   Downloading condacolab-0.1.7-py3-none-any.whl (7.2 kB)
# Installing collected packages: condacolab
# Successfully installed condacolab-0.1.7
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# zlib1g-dev is already the newest version (1:1.2.11.dfsg-2ubuntu9.2).
# zlib1g-dev set to manually installed.
# The following additional packages will be installed:
#   libgsl27 libgslcblas0 libinchi1 libmaeparser1 libnlopt-cxx0 libnlopt-dev
#   libnlopt0 libopenbabel7 python-is-python3
# Suggested packages:
#   libeigen3-doc libmpfrc++-dev gsl-ref-psdoc | gsl-doc-pdf | gsl-doc-info
#   | gsl-ref-html libopenbabel-doc
# The following NEW packages will be installed:
#   libeigen3-dev libgsl-dev libgsl27 libgslcblas0 libinchi1 libmaeparser1
#   libnlopt-cxx-dev libnlopt-cxx0 libnlopt-dev libnlopt0 libopenbabel-dev
#   libopenbabel7 openbabel python-dev-is-python3 python-is-python3
# 0 upgraded, 15 newly installed, 0 to remove and 8 not upgraded.
# Need to get 7,945 kB of archives.
# After this operation, 39.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgslcblas0 amd64 2.7.1+dfsg-3 [94.4 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgsl27 amd64 2.7.1+dfsg-3 [1,000 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgsl-dev amd64 2.7.1+dfsg-3 [1,257 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libinchi1 amd64 1.03+dfsg-4 [455 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmaeparser1 amd64 1.2.4-1build1 [88.2 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libnlopt0 amd64 2.7.1-3build1 [184 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libnlopt-dev amd64 2.7.1-3build1 [44.6 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libnlopt-cxx0 amd64 2.7.1-3build1 [212 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libnlopt-cxx-dev amd64 2.7.1-3build1 [9,872 B]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenbabel7 amd64 3.1.1+dfsg-6ubuntu5 [3,231 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenbabel-dev amd64 3.1.1+dfsg-6ubuntu5 [181 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/universe amd64 openbabel amd64 3.1.1+dfsg-6ubuntu5 [128 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/main amd64 python-is-python3 all 3.9.2-2 [2,788 B]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 python-dev-is-python3 all 3.9.2-2 [1,234 B]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libeigen3-dev all 3.4.0-2ubuntu2 [1,056 kB]
# Fetched 7,945 kB in 1s (7,047 kB/s)
# Selecting previously unselected package libgslcblas0:amd64.
# (Reading database ... 129824 files and directories currently installed.)
# Preparing to unpack .../00-libgslcblas0_2.7.1+dfsg-3_amd64.deb ...
# Unpacking libgslcblas0:amd64 (2.7.1+dfsg-3) ...
# Selecting previously unselected package libgsl27:amd64.
# Preparing to unpack .../01-libgsl27_2.7.1+dfsg-3_amd64.deb ...
# Unpacking libgsl27:amd64 (2.7.1+dfsg-3) ...
# Selecting previously unselected package libgsl-dev.
# Preparing to unpack .../02-libgsl-dev_2.7.1+dfsg-3_amd64.deb ...
# Unpacking libgsl-dev (2.7.1+dfsg-3) ...
# Selecting previously unselected package libinchi1.
# Preparing to unpack .../03-libinchi1_1.03+dfsg-4_amd64.deb ...
# Unpacking libinchi1 (1.03+dfsg-4) ...
# Selecting previously unselected package libmaeparser1:amd64.
# Preparing to unpack .../04-libmaeparser1_1.2.4-1build1_amd64.deb ...
# Unpacking libmaeparser1:amd64 (1.2.4-1build1) ...
# Selecting previously unselected package libnlopt0:amd64.
# Preparing to unpack .../05-libnlopt0_2.7.1-3build1_amd64.deb ...
# Unpacking libnlopt0:amd64 (2.7.1-3build1) ...
# Selecting previously unselected package libnlopt-dev:amd64.
# Preparing to unpack .../06-libnlopt-dev_2.7.1-3build1_amd64.deb ...
# Unpacking libnlopt-dev:amd64 (2.7.1-3build1) ...
# Selecting previously unselected package libnlopt-cxx0:amd64.
# Preparing to unpack .../07-libnlopt-cxx0_2.7.1-3build1_amd64.deb ...
# Unpacking libnlopt-cxx0:amd64 (2.7.1-3build1) ...
# Selecting previously unselected package libnlopt-cxx-dev:amd64.
# Preparing to unpack .../08-libnlopt-cxx-dev_2.7.1-3build1_amd64.deb ...
# Unpacking libnlopt-cxx-dev:amd64 (2.7.1-3build1) ...
# Selecting previously unselected package libopenbabel7.
# Preparing to unpack .../09-libopenbabel7_3.1.1+dfsg-6ubuntu5_amd64.deb ...
# Unpacking libopenbabel7 (3.1.1+dfsg-6ubuntu5) ...
# Selecting previously unselected package libopenbabel-dev.
# Preparing to unpack .../10-libopenbabel-dev_3.1.1+dfsg-6ubuntu5_amd64.deb ...
# Unpacking libopenbabel-dev (3.1.1+dfsg-6ubuntu5) ...
# Selecting previously unselected package openbabel.
# Preparing to unpack .../11-openbabel_3.1.1+dfsg-6ubuntu5_amd64.deb ...
# Unpacking openbabel (3.1.1+dfsg-6ubuntu5) ...
# Selecting previously unselected package python-is-python3.
# Preparing to unpack .../12-python-is-python3_3.9.2-2_all.deb ...
# Unpacking python-is-python3 (3.9.2-2) ...
# Selecting previously unselected package python-dev-is-python3.
# Preparing to unpack .../13-python-dev-is-python3_3.9.2-2_all.deb ...
# Unpacking python-dev-is-python3 (3.9.2-2) ...
# Selecting previously unselected package libeigen3-dev.
# Preparing to unpack .../14-libeigen3-dev_3.4.0-2ubuntu2_all.deb ...
# Unpacking libeigen3-dev (3.4.0-2ubuntu2) ...
# Setting up libgslcblas0:amd64 (2.7.1+dfsg-3) ...
# Setting up libgsl27:amd64 (2.7.1+dfsg-3) ...
# Setting up libnlopt0:amd64 (2.7.1-3build1) ...
# Setting up libmaeparser1:amd64 (1.2.4-1build1) ...
# Setting up libeigen3-dev (3.4.0-2ubuntu2) ...
# Setting up libnlopt-cxx0:amd64 (2.7.1-3build1) ...
# Setting up libnlopt-dev:amd64 (2.7.1-3build1) ...
# Setting up python-is-python3 (3.9.2-2) ...
# Setting up libinchi1 (1.03+dfsg-4) ...
# Setting up libgsl-dev (2.7.1+dfsg-3) ...
# Setting up libopenbabel7 (3.1.1+dfsg-6ubuntu5) ...
# Setting up libopenbabel-dev (3.1.1+dfsg-6ubuntu5) ...
# Setting up libnlopt-cxx-dev:amd64 (2.7.1-3build1) ...
# Setting up python-dev-is-python3 (3.9.2-2) ...
# Setting up openbabel (3.1.1+dfsg-6ubuntu5) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.1) ...
# Processing triggers for man-db (2.10.2-1) ...
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.1.0-1/Mambaforge-23.1.0-1-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:12
# 🔁 Restarting kernel...
#
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         mamba (1.4.1) supported by @QuantStack
#
#         GitHub:  https://github.com/mamba-org/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
#
# Looking for: ['py-boost']
#
# [+] 0.0s
# [+] 0.1s
# anaconda/linux-64     ⣾
# anaconda/noarch       ⣾
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 0.2s
# anaconda/linux-64     ⣾
# anaconda/noarch       ⣾
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 0.3s
# anaconda/linux-64     ⣾
# anaconda/noarch       ⣾
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  anaconda/noarch
# [+] 0.4s
# anaconda/linux-64     ⣾
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 0.5s
# anaconda/linux-64     ⣾
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 0.6s
# anaconda/linux-64     ⣾
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 0.7s
# anaconda/linux-64     ⣾
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 0.8s
# anaconda/linux-64     ⣾
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  anaconda/linux-64
# [+] 0.9s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 1.0s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 1.1s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 1.2s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 1.3s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 1.4s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 1.5s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 1.6s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 1.7s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 1.8s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 1.9s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 2.0s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 2.1s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 2.2s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 2.3s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 2.4s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 2.5s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 2.6s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 2.7s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 2.8s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 2.9s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 3.0s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 3.1s
# conda-forge/linux-64  ⣾
# conda-forge/noarch   100%[+] 3.2s
# conda-forge/linux-64  ⣾
# conda-forge/noarch   100%conda-forge/noarch
# [+] 3.3s
# conda-forge/linux-64  ⣾  [+] 3.4s
# conda-forge/linux-64  ⣾  [+] 3.5s
# conda-forge/linux-64  ⣾  [+] 3.6s
# conda-forge/linux-64  ⣾  [+] 3.7s
# conda-forge/linux-64  ⣾  [+] 3.8s
# conda-forge/linux-64  ⣾  [+] 3.9s
# conda-forge/linux-64  ⣾  [+] 4.0s
# conda-forge/linux-64  ⣾  [+] 4.1s
# conda-forge/linux-64  ⣾  [+] 4.2s
# conda-forge/linux-64  ⣾  [+] 4.3s
# conda-forge/linux-64  ⣾  [+] 4.4s
# conda-forge/linux-64  ⣾  [+] 4.5s
# conda-forge/linux-64  ⣾  [+] 4.6s
# conda-forge/linux-64  ⣾  [+] 4.7s
# conda-forge/linux-64  ⣾  [+] 4.8s
# conda-forge/linux-64  ⣾  [+] 4.9s
# conda-forge/linux-64  ⣾  [+] 5.0s
# conda-forge/linux-64  ⣾  [+] 5.1s
# conda-forge/linux-64  ⣾  [+] 5.2s
# conda-forge/linux-64  ⣾  [+] 5.3s
# conda-forge/linux-64  ⣾  [+] 5.4s
# conda-forge/linux-64  ⣾  [+] 5.5s
# conda-forge/linux-64  ⣾  [+] 5.6s
# conda-forge/linux-64  ⣾  [+] 5.7s
# conda-forge/linux-64  ⣾  [+] 5.8s
# conda-forge/linux-64  ⣾  [+] 5.9s
# conda-forge/linux-64  ⣾  [+] 6.0s
# conda-forge/linux-64  ⣾  [+] 6.1s
# conda-forge/linux-64  ⣾  [+] 6.2s
# conda-forge/linux-64  ⣾  [+] 6.3s
# conda-forge/linux-64  ⣾  [+] 6.4s
# conda-forge/linux-64  ⣾  [+] 6.5s
# conda-forge/linux-64  ⣾  [+] 6.6s
# conda-forge/linux-64  ⣾  [+] 6.7s
# conda-forge/linux-64 100%[+] 6.8s
# conda-forge/linux-64 100%[+] 6.9s
# conda-forge/linux-64 100%[+] 7.0s
# conda-forge/linux-64 100%[+] 7.1s
# conda-forge/linux-64 100%[+] 7.2s
# conda-forge/linux-64 100%[+] 7.3s
# conda-forge/linux-64 100%conda-forge/linux-64
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cudatoolkit 11.8.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   Updating specs:
#
#    - py-boost
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package               Version  Build             Channel                   Size
# ───────────────────────────────────────────────────────────────────────────────────
#   Install:
# ───────────────────────────────────────────────────────────────────────────────────
#
#   + libboost             1.73.0  h28710b8_12       anaconda/linux-64         22MB
#   + py-boost             1.73.0  py310h00e6091_12  anaconda/linux-64        265kB
#   + zlib                 1.2.13  h166bdaf_4        conda-forge/linux-64      94kB
#
#   Upgrade:
# ───────────────────────────────────────────────────────────────────────────────────
#
#   - ca-certificates   2022.12.7  ha878542_0        conda-forge
#   + ca-certificates  2023.01.10  h06a4308_0        anaconda/linux-64        130kB
#
#   Downgrade:
# ───────────────────────────────────────────────────────────────────────────────────
#
#   - icu                    72.1  hcb278e6_0        conda-forge
#   + icu                    58.2  he6710b0_3        anaconda/linux-64         24MB
#   - libarchive            3.6.2  h3d51595_0        conda-forge
#   + libarchive            3.5.2  hada088e_3        conda-forge/linux-64       2MB
#   - libmamba              1.4.1  hcea66bb_0        conda-forge
#   + libmamba              1.1.0  h70b1f8a_2        conda-forge/linux-64       1MB
#   - libmambapy            1.4.1  py310h1428755_0   conda-forge
#   + libmambapy            1.1.0  py310h69aa5bf_2   conda-forge/linux-64     315kB
#   - libxml2              2.10.3  hfdac1af_6        conda-forge
#   + libxml2              2.9.14  h74e7548_0        anaconda/linux-64        789kB
#   - mamba                 1.4.1  py310h51d5547_0   conda-forge
#   + mamba                 1.1.0  py310h51d5547_2   conda-forge/linux-64      49kB
#
#   Summary:
#
#   Install: 3 packages
#   Upgrade: 1 packages
#   Downgrade: 6 packages
#
#   Total download: 51MB
#
# ───────────────────────────────────────────────────────────────────────────────────
#
#
# [+] 0.0s
# Downloading        0%
# Extracting         0%[+] 0.1s
# Downloading  (5)   0%
# Extracting         0%ca-certificates                                    129.7kB @ 746.8kB/s  0.2s
# zlib                                                94.1kB @ 496.0kB/s  0.2s
# [+] 0.2s
# Downloading  (5)   1%
# Extracting   (2)  ⣾  libxml2                                            789.5kB @   3.8MB/s  0.2s
# libmamba                                             1.5MB @   5.4MB/s  0.0s
# [+] 0.3s
# Downloading  (5)  19%
# Extracting   (4)  ⣾  py-boost                                           265.1kB @ 844.2kB/s  0.1s
# [+] 0.4s
# Downloading  (5)  52%
# Extracting   (5)  ⣾  libarchive                                           1.7MB @   4.2MB/s  0.1s
# mamba                                               48.9kB @ 115.1kB/s  0.2s
# libmambapy                                         314.8kB @ 648.8kB/s  0.3s
# libboost                                            22.2MB @  44.7MB/s  0.5s
# [+] 0.5s
# Downloading  (1)  94%
# Extracting   (7)  ⣾  icu                                                 23.8MB @  47.2MB/s  0.5s
# [+] 0.6s
# Downloading      100%
# Extracting  (10)  ⣾  [+] 0.7s
# Downloading      100%
# Extracting  (10)  ⣾  [+] 0.8s
# Downloading      100%
# Extracting   (9)  ⣾  [+] 0.9s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 1.0s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 1.1s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 1.2s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 1.3s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 1.4s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 1.5s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 1.6s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 1.7s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 1.8s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 1.9s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 2.0s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 2.1s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 2.2s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 2.3s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 2.4s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 2.5s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 2.6s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 2.7s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 2.8s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 2.9s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 3.0s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 3.1s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 3.2s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 3.3s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 3.4s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 3.5s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 3.6s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 3.7s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 3.8s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 3.9s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 4.0s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 4.1s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 4.2s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 4.3s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 4.4s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 4.5s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 4.6s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 4.7s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 4.8s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 4.9s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 5.0s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 5.1s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 5.2s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 5.3s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 5.4s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 5.5s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 5.6s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 5.7s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 5.8s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 5.9s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 6.0s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 6.1s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 6.2s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 6.3s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 6.4s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 6.5s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 6.6s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 6.7s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 6.8s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 6.9s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 7.0s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 7.1s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 7.2s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 7.3s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 7.4s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 7.5s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 7.6s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 7.7s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 7.8s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 7.9s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 8.0s
# Downloading      100%
# Extracting   (3)  ⣾  [+] 8.1s
# Downloading      100%
# Extracting   (3)  ⣾  [+] 8.2s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 8.3s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 8.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 8.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 8.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 8.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 8.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 8.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 9.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 9.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 9.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 9.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 9.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 9.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 9.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 9.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 9.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 9.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 10.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 10.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 10.2s
# Downloading      100%
# Extracting   (1)  ⣾
# Downloading and Extracting Packages
#
# done
# done
# done
# Wed Jul 26 11:29:11 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0    25W / 300W |      0MiB / 16384MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !rm -rf pyLiBELa-alex-works alex-works.zip

# %%
! wget https://github.com/alessandronascimento/pyLiBELa/archive/refs/heads/alex-works.zip
# !unzip alex-works.zip
! cd pyLiBELa-alex-works; mkdir obj;
# Out:
# --2023-07-26 11:29:25--  https://github.com/alessandronascimento/pyLiBELa/archive/refs/heads/alex-works.zip
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/alessandronascimento/pyLiBELa/zip/refs/heads/alex-works [following]
# --2023-07-26 11:29:25--  https://codeload.github.com/alessandronascimento/pyLiBELa/zip/refs/heads/alex-works
# Resolving codeload.github.com (codeload.github.com)... 140.82.121.9
# Connecting to codeload.github.com (codeload.github.com)|140.82.121.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘alex-works.zip’
#
# alex-works.zip          [     <=>            ]  14.05M  13.1MB/s    in 1.1s
#
# 2023-07-26 11:29:27 (13.1 MB/s) - ‘alex-works.zip’ saved [14728303]
#
# Archive:  alex-works.zip
# 349048dad2af475c6c62debb1a3b5547415342c7
#    creating: pyLiBELa-alex-works/
#   inflating: pyLiBELa-alex-works/.gitignore
#    creating: pyLiBELa-alex-works/Colabs/
#   inflating: pyLiBELa-alex-works/Colabs/Conda.ipynb
#   inflating: pyLiBELa-alex-works/Colabs/GridNumba.ipynb
#   inflating: pyLiBELa-alex-works/Colabs/Makefile
#   inflating: pyLiBELa-alex-works/Colabs/OpenBabel.ipynb
#   inflating: pyLiBELa-alex-works/Colabs/README
#   inflating: pyLiBELa-alex-works/Colabs/Working_Example.ipynb
#   inflating: pyLiBELa-alex-works/Colabs/pyLiBELa.ipynb
#   inflating: pyLiBELa-alex-works/LICENSE
#   inflating: pyLiBELa-alex-works/Makefile
#   inflating: pyLiBELa-alex-works/README.md
#   inflating: pyLiBELa-alex-works/pymol3D_test.ipynb
#    creating: pyLiBELa-alex-works/src/
#  extracting: pyLiBELa-alex-works/src/README
#   inflating: pyLiBELa-alex-works/src/iMcLiBELa.h
#   inflating: pyLiBELa-alex-works/src/pyCOORD_MC.cpp
#   inflating: pyLiBELa-alex-works/src/pyCOORD_MC.h
#   inflating: pyLiBELa-alex-works/src/pyConformer.cpp
#   inflating: pyLiBELa-alex-works/src/pyConformer.h
#   inflating: pyLiBELa-alex-works/src/pyDocker.cpp
#   inflating: pyLiBELa-alex-works/src/pyDocker.h
#   inflating: pyLiBELa-alex-works/src/pyEnergy2.cpp
#   inflating: pyLiBELa-alex-works/src/pyEnergy2.h
#   inflating: pyLiBELa-alex-works/src/pyFindHB.cpp
#   inflating: pyLiBELa-alex-works/src/pyFindHB.h
#   inflating: pyLiBELa-alex-works/src/pyFullSearch.cpp
#   inflating: pyLiBELa-alex-works/src/pyFullSearch.h
#   inflating: pyLiBELa-alex-works/src/pyGaussian.cpp
#   inflating: pyLiBELa-alex-works/src/pyGaussian.h
#   inflating: pyLiBELa-alex-works/src/pyGrid.cpp
#   inflating: pyLiBELa-alex-works/src/pyGrid.h
#   inflating: pyLiBELa-alex-works/src/pyMC.cpp
#   inflating: pyLiBELa-alex-works/src/pyMC.h
#   inflating: pyLiBELa-alex-works/src/pyMcEntropy.cpp
#   inflating: pyLiBELa-alex-works/src/pyMcEntropy.h
#   inflating: pyLiBELa-alex-works/src/pyMol2.cpp
#   inflating: pyLiBELa-alex-works/src/pyMol2.h
#   inflating: pyLiBELa-alex-works/src/pyOptimizer.cpp
#   inflating: pyLiBELa-alex-works/src/pyOptimizer.h
#   inflating: pyLiBELa-alex-works/src/pyPARSER.cpp
#   inflating: pyLiBELa-alex-works/src/pyPARSER.h
#   inflating: pyLiBELa-alex-works/src/pyRAND.cpp
#   inflating: pyLiBELa-alex-works/src/pyRAND.h
#   inflating: pyLiBELa-alex-works/src/pySA.cpp
#   inflating: pyLiBELa-alex-works/src/pySA.h
#   inflating: pyLiBELa-alex-works/src/pyWRITER.cpp
#   inflating: pyLiBELa-alex-works/src/pyWRITER.h
#    creating: pyLiBELa-alex-works/test/
#   inflating: pyLiBELa-alex-works/test/LJ_parm.dat
#  extracting: pyLiBELa-alex-works/test/README
#    creating: pyLiBELa-alex-works/test/cuda_test/
#   inflating: pyLiBELa-alex-works/test/cuda_test/184L_SF0_1.log
#    creating: pyLiBELa-alex-works/test/cuda_test/Colabs/
#   inflating: pyLiBELa-alex-works/test/cuda_test/Colabs/CudaGrid.ipynb
#  extracting: pyLiBELa-alex-works/test/cuda_test/Colabs/README
#   inflating: pyLiBELa-alex-works/test/cuda_test/Makefile
#   inflating: pyLiBELa-alex-works/test/cuda_test/McGrid.grid
#    creating: pyLiBELa-alex-works/test/cuda_test/McGrid/
#   inflating: pyLiBELa-alex-works/test/cuda_test/McGrid/184L_SF0_1.log
#   inflating: pyLiBELa-alex-works/test/cuda_test/McGrid/Makefile
#   inflating: pyLiBELa-alex-works/test/cuda_test/McGrid/McGrid
#   inflating: pyLiBELa-alex-works/test/cuda_test/McGrid/McGrid.cpp
#   inflating: pyLiBELa-alex-works/test/cuda_test/McGrid/cuda-keyring_1.0-1_all.deb
#   inflating: pyLiBELa-alex-works/test/cuda_test/box.pdb
#   inflating: pyLiBELa-alex-works/test/cuda_test/cudaGrid.cu
#   inflating: pyLiBELa-alex-works/test/cuda_test/cudaGrid.cuh
#   inflating: pyLiBELa-alex-works/test/cuda_test/cudaGrid2.cu
#   inflating: pyLiBELa-alex-works/test/cuda_test/cudaGrid3.cu
#  extracting: pyLiBELa-alex-works/test/cuda_test/cudaPython.py
#   inflating: pyLiBELa-alex-works/test/cuda_test/cudaTest.cu
#   inflating: pyLiBELa-alex-works/test/cuda_test/cudaTest.cuh
#    creating: pyLiBELa-alex-works/test/cuda_test/input_files/
#   inflating: pyLiBELa-alex-works/test/cuda_test/input_files/184L_DOCKPREP.mol2.gz
#  extracting: pyLiBELa-alex-works/test/cuda_test/input_files/184L_LIG_DOCKPREP.mol2.gz
#   inflating: pyLiBELa-alex-works/test/cuda_test/input_files/184L_SF0_1.log
#   inflating: pyLiBELa-alex-works/test/cuda_test/input_files/McGrid.grid
#   inflating: pyLiBELa-alex-works/test/cuda_test/input_files/box.pdb
#   inflating: pyLiBELa-alex-works/test/cuda_test/input_files/pyLiBELa.inp
#   inflating: pyLiBELa-alex-works/test/cuda_test/testSource.cpp
#  extracting: pyLiBELa-alex-works/test/lig.mol2.gz
#   inflating: pyLiBELa-alex-works/test/rec.mol2.gz

# %%
! cd pyLiBELa-alex-works/test/cuda_test; make
! cd pyLiBELa-alex-works/test/cuda_test/McGrid; rm -f McGrid ; make McGrid
# Out:
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(77): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(79): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(81): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(83): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(85): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(86): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(87): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(88): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(89): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(90): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(91): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(92): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(93): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(94): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(95): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(1535): warning #20013-D: calling a constexpr __host__ function("real") from a __host__ __device__ function("abs") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(1535): warning #20013-D: calling a constexpr __host__ function("imag") from a __host__ __device__ function("abs") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(1535): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(1535): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(1540): warning #20013-D: calling a constexpr __host__ function("real") from a __host__ __device__ function("abs") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(1540): warning #20013-D: calling a constexpr __host__ function("imag") from a __host__ __device__ function("abs") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(1540): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(1540): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(1564): warning #20013-D: calling a constexpr __host__ function("real") from a __host__ __device__ function("exp") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(1565): warning #20013-D: calling a constexpr __host__ function("imag") from a __host__ __device__ function("exp") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(1566): warning #20013-D: calling a constexpr __host__ function("imag") from a __host__ __device__ function("exp") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(1564): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(1565): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(1566): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(1567): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(1572): warning #20013-D: calling a constexpr __host__ function("real") from a __host__ __device__ function("exp") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(1573): warning #20013-D: calling a constexpr __host__ function("imag") from a __host__ __device__ function("exp") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(1574): warning #20013-D: calling a constexpr __host__ function("imag") from a __host__ __device__ function("exp") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(1572): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(1573): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(1574): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(1575): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(234): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(234): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(234): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(234): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(234): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(234): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(234): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(234): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(234): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(234): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(234): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(235): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(235): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(235): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(235): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(235): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(235): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(235): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(235): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(235): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(235): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(235): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/DenseStorage.h(223): warning #20012-D: __host__ annotation is ignored on a function("DenseStorage") that is explicitly defaulted on its first declaration
#
# /usr/include/eigen3/Eigen/src/Core/DenseStorage.h(223): warning #20012-D: __device__ annotation is ignored on a function("DenseStorage") that is explicitly defaulted on its first declaration
#
# /usr/include/eigen3/Eigen/src/Core/DenseStorage.h(233): warning #20012-D: __host__ annotation is ignored on a function("operator=") that is explicitly defaulted on its first declaration
#
# /usr/include/eigen3/Eigen/src/Core/DenseStorage.h(233): warning #20012-D: __device__ annotation is ignored on a function("operator=") that is explicitly defaulted on its first declaration
#
# /usr/include/eigen3/Eigen/src/Core/DenseStorage.h(248): warning #20012-D: __host__ annotation is ignored on a function("DenseStorage") that is explicitly defaulted on its first declaration
#
# /usr/include/eigen3/Eigen/src/Core/DenseStorage.h(248): warning #20012-D: __device__ annotation is ignored on a function("DenseStorage") that is explicitly defaulted on its first declaration
#
# /usr/include/eigen3/Eigen/src/Core/DenseStorage.h(249): warning #20012-D: __host__ annotation is ignored on a function("operator=") that is explicitly defaulted on its first declaration
#
# /usr/include/eigen3/Eigen/src/Core/DenseStorage.h(249): warning #20012-D: __device__ annotation is ignored on a function("operator=") that is explicitly defaulted on its first declaration
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(110): warning #20013-D: calling a constexpr __host__ function("real") from a __host__ __device__ function("run") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#           detected during:
#             instantiation of "T Eigen::internal::real_impl<std::complex<T>>::run(const std::complex<T> &) [with T=float]"
# (1232): here
#             instantiation of "Eigen::internal::real_retval<Eigen::internal::global_math_functions_filtering_base<Scalar, void>::type>::type Eigen::numext::real(const Scalar &) [with Scalar=std::complex<float>]"
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(234): here
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(110): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#           detected during:
#             instantiation of "T Eigen::internal::real_impl<std::complex<T>>::run(const std::complex<T> &) [with T=float]"
# (1232): here
#             instantiation of "Eigen::internal::real_retval<Eigen::internal::global_math_functions_filtering_base<Scalar, void>::type>::type Eigen::numext::real(const Scalar &) [with Scalar=std::complex<float>]"
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(234): here
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(158): warning #20013-D: calling a constexpr __host__ function("imag") from a __host__ __device__ function("run") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#           detected during:
#             instantiation of "T Eigen::internal::imag_impl<std::complex<T>>::run(const std::complex<T> &) [with T=float]"
# (1253): here
#             instantiation of "Eigen::internal::imag_retval<Eigen::internal::global_math_functions_filtering_base<Scalar, void>::type>::type Eigen::numext::imag(const Scalar &) [with Scalar=std::complex<float>]"
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(234): here
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(158): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#           detected during:
#             instantiation of "T Eigen::internal::imag_impl<std::complex<T>>::run(const std::complex<T> &) [with T=float]"
# (1253): here
#             instantiation of "Eigen::internal::imag_retval<Eigen::internal::global_math_functions_filtering_base<Scalar, void>::type>::type Eigen::numext::imag(const Scalar &) [with Scalar=std::complex<float>]"
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(234): here
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(58): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#           detected during instantiation of "std::complex<T> Eigen::complex_operator_detail::complex_multiply(const std::complex<T> &, const std::complex<T> &) [with T=float]"
# (234): here
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(71): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#           detected during:
#             instantiation of "std::complex<T> Eigen::complex_operator_detail::complex_divide_fast(const std::complex<T> &, const std::complex<T> &) [with T=float]"
# (96): here
#             instantiation of "std::complex<T> Eigen::complex_operator_detail::complex_divide(const std::complex<T> &, const std::complex<T> &) [with T=float]"
# (234): here
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(110): warning #20013-D: calling a constexpr __host__ function("real") from a __host__ __device__ function("run") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#           detected during:
#             instantiation of "T Eigen::internal::real_impl<std::complex<T>>::run(const std::complex<T> &) [with T=double]"
# (1232): here
#             instantiation of "Eigen::internal::real_retval<Eigen::internal::global_math_functions_filtering_base<Scalar, void>::type>::type Eigen::numext::real(const Scalar &) [with Scalar=std::complex<double>]"
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(235): here
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(110): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#           detected during:
#             instantiation of "T Eigen::internal::real_impl<std::complex<T>>::run(const std::complex<T> &) [with T=double]"
# (1232): here
#             instantiation of "Eigen::internal::real_retval<Eigen::internal::global_math_functions_filtering_base<Scalar, void>::type>::type Eigen::numext::real(const Scalar &) [with Scalar=std::complex<double>]"
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(235): here
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(158): warning #20013-D: calling a constexpr __host__ function("imag") from a __host__ __device__ function("run") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#           detected during:
#             instantiation of "T Eigen::internal::imag_impl<std::complex<T>>::run(const std::complex<T> &) [with T=double]"
# (1253): here
#             instantiation of "Eigen::internal::imag_retval<Eigen::internal::global_math_functions_filtering_base<Scalar, void>::type>::type Eigen::numext::imag(const Scalar &) [with Scalar=std::complex<double>]"
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(235): here
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(158): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#           detected during:
#             instantiation of "T Eigen::internal::imag_impl<std::complex<T>>::run(const std::complex<T> &) [with T=double]"
# (1253): here
#             instantiation of "Eigen::internal::imag_retval<Eigen::internal::global_math_functions_filtering_base<Scalar, void>::type>::type Eigen::numext::imag(const Scalar &) [with Scalar=std::complex<double>]"
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(235): here
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(58): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#           detected during instantiation of "std::complex<T> Eigen::complex_operator_detail::complex_multiply(const std::complex<T> &, const std::complex<T> &) [with T=double]"
# (235): here
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(71): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#           detected during:
#             instantiation of "std::complex<T> Eigen::complex_operator_detail::complex_divide_fast(const std::complex<T> &, const std::complex<T> &) [with T=double]"
# (96): here
#             instantiation of "std::complex<T> Eigen::complex_operator_detail::complex_divide(const std::complex<T> &, const std::complex<T> &) [with T=double]"
# (235): here
#
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(77): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(79): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(81): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(83): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(85): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(86): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(87): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(88): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(89): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(90): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(91): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(92): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(93): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(94): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(95): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# /usr/include/eigen3/Eigen/src/Core/DenseStorage.h(223): warning #20012-D: __host__ annotation is ignored on a function("DenseStorage") that is explicitly defaulted on its first declaration
#
# /usr/include/eigen3/Eigen/src/Core/DenseStorage.h(223): warning #20012-D: __device__ annotation is ignored on a function("DenseStorage") that is explicitly defaulted on its first declaration
#
# /usr/include/eigen3/Eigen/src/Core/DenseStorage.h(233): warning #20012-D: __host__ annotation is ignored on a function("operator=") that is explicitly defaulted on its first declaration
#
# /usr/include/eigen3/Eigen/src/Core/DenseStorage.h(233): warning #20012-D: __device__ annotation is ignored on a function("operator=") that is explicitly defaulted on its first declaration
#
# /usr/include/eigen3/Eigen/src/Core/DenseStorage.h(248): warning #20012-D: __host__ annotation is ignored on a function("DenseStorage") that is explicitly defaulted on its first declaration
#
# /usr/include/eigen3/Eigen/src/Core/DenseStorage.h(248): warning #20012-D: __device__ annotation is ignored on a function("DenseStorage") that is explicitly defaulted on its first declaration
#
# /usr/include/eigen3/Eigen/src/Core/DenseStorage.h(249): warning #20012-D: __host__ annotation is ignored on a function("operator=") that is explicitly defaulted on its first declaration
#
# /usr/include/eigen3/Eigen/src/Core/DenseStorage.h(249): warning #20012-D: __device__ annotation is ignored on a function("operator=") that is explicitly defaulted on its first declaration
#
# g++ McGrid.o -o McGrid ../cudaGrid3.o -lz -L/usr/lib/x86_64-linux-gnu -lopenbabel -lgomp -lpthread -lgsl -lgslcblas -lm -lpython3.10 -lboost_python310 -L/usr/local/cuda/lib64 -lcudart

# %%
! cd pyLiBELa-alex-works/test/cuda_test/input_files; time ../McGrid/McGrid pyLiBELa.inp
# Out:
# ****************************************************************************************************
# ****************************************************************************************************
# *                  McGrid - Energy Grid Computation for Molecular Docking with McLiBELa            *
# *                                                                                                  *
# * University of Sao Paulo                                                                          *
# * More Info:                                                                                       *
# *      http://www.biotechmol.ifsc.usp.br/                                                          *
# *                                                                                                  *
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# *                  MCLiBELa - Monte Carlo-based Ligand Binding Energy Landscape                    *
# *                                      Version 1.0  - Build     0                                  *
# *                                                                                                  *
# * University of Sao Paulo                                                                          *
# * More Info:                                                                                       *
# *      http://www.biotechmol.ifsc.usp.br/                                                          *
# *                                                                                                  *
# ****************************************************************************************************
# ****************************************************************************************************
# *                                                                                                  *
# * dock_parallel                  0                                                                 *
# *                                                                                                  *
# * rec_mol2                       ./184L_DOCKPREP.mol2.gz                                           *
# * lig_mol2                       ./184L_LIG_DOCKPREP.mol2.gz                                       *
# * reflig_mol2                    ./184L_LIG_DOCKPREP.mol2.gz                                       *
# * multifile                      multimol.dat                                                      *
# * mol2_aa                        0                                                                 *
# *                                                                                                  *
# * scoring function               Amber Softcore + Desolvation                                      *
# * deltaij6                       244.14                                                            *
# * deltaij_es6                    244.14                                                            *
# * dielectric_model               r                                                                 *
# * diel                           2.000                                                             *
# * sigma                          3.500                                                             *
# * solvation_alpha                0.100                                                             *
# * solvation_beta                 -0.005                                                            *
# * use grids?                     1                                                                 *
# * grid_spacing                   0.40                                                              *
# * grid box                       20.00                 20.00                 20.00                 *
# * write grids                    ./McGrid                                                          *
# * use PBSA grids?                0                                                                 *
# * Electrostatic model            Coulomb                                                           *
# *                                                                                                  *
# * only_score                     0                                                                 *
# * use_score_optimization         0                                                                 *
# * search_box                     45.00                 45.00                 45.00                 *
# * minimization_tolerance         0.0000000001                                                      *
# * minimization_delta             0.0000100000                                                      *
# * dock_min_tol                   0.0000000001                                                      *
# * minimization_timeout           120                                                               *
# * sort_by_energy                 1                                                                 *
# * elec_scale                     1.00                                                              *
# * vdw_scale                      1.00                                                              *
# * overlay_optimizer              ln_auglag                                                         *
# * energy_optimizer               direct                                                            *
# * ignore_h                       0                                                                 *
# * deal                           0                                                                 *
# * scale_elec_energy              1.00                                                              *
# * scale_vdw_energy               1.00                                                              *
# * Overlay Cutoff                 0.00                                                              *
# *                                                                                                  *
# * generate_conformers            0                                                                 *
# *                                                                                                  *
# * output_prefix                  184L_SF0_1                                                        *
# * write_mol2                     1                                                                 *
# *                                                                                                  *
# * Ligand energy model            GAFF                                                              *
# * Atomic FF model                AMBER                                                             *
# *                                                                                                  *
# ****************************************************************************************************
# ****************************************************************************************************
# Ligand and Receptor files read!
# Found    28 HB donors and    23 HB acceptor around the active site in a 9.0 Ang search sphere radius.
# Computing grids centered at   26.96122    7.16460    3.20683.
# This may take a while...Coffee time, maybe?
# Computed energy grids with 125000 points spaced by 0.400 Angstroms in each directon.
# Grid X limits:    16.9612    36.9612.
# Grid Y limits:    -2.8354    17.1646.
# Grid Z limits:    -6.7932    13.2068.
# Grid computation took 26 seconds.
#
# Now invoking kernel:
# Entering kernel
# Last error: no error
# Kernel has ended
# Last error: no error
# ElecGrid[  0][  0][  0] =    4.358 	 CudaGrid[       0] =    4.358 	 Diff =    0.000
# VdwAGrid[  0][  0][  0] =    0.000 	 CudaGrid[       0] =    0.000 	 Diff =    0.000
# VdwBGrid[  0][  0][  0] =    0.084 	 CudaGrid[       0] =    0.084 	 Diff =    0.000
# RecSGrid[  0][  0][  0] =    2.267 	 CudaGrid[       0] =    2.267 	 Diff =    0.000
# SolvGrid[  0][  0][  0] =    0.002 	 CudaGrid[       0] =    0.002 	 Diff =    0.000
# HBAcGrid[  0][  0][  0] =   -0.000 	 CudaGrid[       0] =   -0.000 	 Diff =    0.000
# HBDoGrid[  0][  0][  0] =   -0.000 	 CudaGrid[       0] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  0][  0][  1] =    4.416 	 CudaGrid[       1] =    4.416 	 Diff =    0.000
# VdwAGrid[  0][  0][  1] =    0.000 	 CudaGrid[       1] =    0.000 	 Diff =    0.000
# VdwBGrid[  0][  0][  1] =    0.083 	 CudaGrid[       1] =    0.083 	 Diff =    0.000
# RecSGrid[  0][  0][  1] =    2.321 	 CudaGrid[       1] =    2.321 	 Diff =    0.000
# SolvGrid[  0][  0][  1] =    0.002 	 CudaGrid[       1] =    0.002 	 Diff =    0.000
# HBAcGrid[  0][  0][  1] =   -0.000 	 CudaGrid[       1] =   -0.000 	 Diff =    0.000
# HBDoGrid[  0][  0][  1] =   -0.000 	 CudaGrid[       1] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  0][  0][  2] =    4.468 	 CudaGrid[       2] =    4.468 	 Diff =    0.000
# VdwAGrid[  0][  0][  2] =    0.000 	 CudaGrid[       2] =    0.000 	 Diff =    0.000
# VdwBGrid[  0][  0][  2] =    0.083 	 CudaGrid[       2] =    0.083 	 Diff =    0.000
# RecSGrid[  0][  0][  2] =    2.374 	 CudaGrid[       2] =    2.374 	 Diff =    0.000
# SolvGrid[  0][  0][  2] =    0.002 	 CudaGrid[       2] =    0.002 	 Diff =    0.000
# HBAcGrid[  0][  0][  2] =   -0.000 	 CudaGrid[       2] =   -0.000 	 Diff =    0.000
# HBDoGrid[  0][  0][  2] =   -0.000 	 CudaGrid[       2] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  0][  0][  3] =    4.514 	 CudaGrid[       3] =    4.514 	 Diff =    0.000
# VdwAGrid[  0][  0][  3] =    0.000 	 CudaGrid[       3] =    0.000 	 Diff =    0.000
# VdwBGrid[  0][  0][  3] =    0.085 	 CudaGrid[       3] =    0.085 	 Diff =    0.000
# RecSGrid[  0][  0][  3] =    2.427 	 CudaGrid[       3] =    2.427 	 Diff =    0.000
# SolvGrid[  0][  0][  3] =    0.002 	 CudaGrid[       3] =    0.002 	 Diff =    0.000
# HBAcGrid[  0][  0][  3] =   -0.000 	 CudaGrid[       3] =   -0.000 	 Diff =    0.000
# HBDoGrid[  0][  0][  3] =   -0.000 	 CudaGrid[       3] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  0][  0][  4] =    4.558 	 CudaGrid[       4] =    4.558 	 Diff =    0.000
# VdwAGrid[  0][  0][  4] =    0.000 	 CudaGrid[       4] =    0.000 	 Diff =    0.000
# VdwBGrid[  0][  0][  4] =    0.087 	 CudaGrid[       4] =    0.087 	 Diff =    0.000
# RecSGrid[  0][  0][  4] =    2.481 	 CudaGrid[       4] =    2.481 	 Diff =    0.000
# SolvGrid[  0][  0][  4] =    0.002 	 CudaGrid[       4] =    0.002 	 Diff =    0.000
# HBAcGrid[  0][  0][  4] =   -0.000 	 CudaGrid[       4] =   -0.000 	 Diff =    0.000
# HBDoGrid[  0][  0][  4] =   -0.000 	 CudaGrid[       4] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  0][  1][  0] =    4.463 	 CudaGrid[      50] =    4.463 	 Diff =    0.000
# VdwAGrid[  0][  1][  0] =    0.000 	 CudaGrid[      50] =    0.000 	 Diff =    0.000
# VdwBGrid[  0][  1][  0] =    0.101 	 CudaGrid[      50] =    0.101 	 Diff =    0.000
# RecSGrid[  0][  1][  0] =    2.536 	 CudaGrid[      50] =    2.536 	 Diff =    0.000
# SolvGrid[  0][  1][  0] =    0.002 	 CudaGrid[      50] =    0.002 	 Diff =    0.000
# HBAcGrid[  0][  1][  0] =   -0.000 	 CudaGrid[      50] =   -0.000 	 Diff =    0.000
# HBDoGrid[  0][  1][  0] =   -0.000 	 CudaGrid[      50] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  0][  1][  1] =    4.537 	 CudaGrid[      51] =    4.537 	 Diff =    0.000
# VdwAGrid[  0][  1][  1] =    0.000 	 CudaGrid[      51] =    0.000 	 Diff =    0.000
# VdwBGrid[  0][  1][  1] =    0.099 	 CudaGrid[      51] =    0.099 	 Diff =    0.000
# RecSGrid[  0][  1][  1] =    2.596 	 CudaGrid[      51] =    2.596 	 Diff =    0.000
# SolvGrid[  0][  1][  1] =    0.002 	 CudaGrid[      51] =    0.002 	 Diff =    0.000
# HBAcGrid[  0][  1][  1] =   -0.000 	 CudaGrid[      51] =   -0.000 	 Diff =    0.000
# HBDoGrid[  0][  1][  1] =   -0.000 	 CudaGrid[      51] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  0][  1][  2] =    4.599 	 CudaGrid[      52] =    4.599 	 Diff =    0.000
# VdwAGrid[  0][  1][  2] =    0.000 	 CudaGrid[      52] =    0.000 	 Diff =    0.000
# VdwBGrid[  0][  1][  2] =    0.099 	 CudaGrid[      52] =    0.099 	 Diff =    0.000
# RecSGrid[  0][  1][  2] =    2.653 	 CudaGrid[      52] =    2.653 	 Diff =    0.000
# SolvGrid[  0][  1][  2] =    0.002 	 CudaGrid[      52] =    0.002 	 Diff =    0.000
# HBAcGrid[  0][  1][  2] =   -0.000 	 CudaGrid[      52] =   -0.000 	 Diff =    0.000
# HBDoGrid[  0][  1][  2] =   -0.000 	 CudaGrid[      52] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  0][  1][  3] =    4.649 	 CudaGrid[      53] =    4.649 	 Diff =    0.000
# VdwAGrid[  0][  1][  3] =    0.000 	 CudaGrid[      53] =    0.000 	 Diff =    0.000
# VdwBGrid[  0][  1][  3] =    0.099 	 CudaGrid[      53] =    0.099 	 Diff =    0.000
# RecSGrid[  0][  1][  3] =    2.710 	 CudaGrid[      53] =    2.710 	 Diff =    0.000
# SolvGrid[  0][  1][  3] =    0.002 	 CudaGrid[      53] =    0.002 	 Diff =    0.000
# HBAcGrid[  0][  1][  3] =   -0.000 	 CudaGrid[      53] =   -0.000 	 Diff =    0.000
# HBDoGrid[  0][  1][  3] =   -0.000 	 CudaGrid[      53] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  0][  1][  4] =    4.693 	 CudaGrid[      54] =    4.693 	 Diff =    0.000
# VdwAGrid[  0][  1][  4] =    0.000 	 CudaGrid[      54] =    0.000 	 Diff =    0.000
# VdwBGrid[  0][  1][  4] =    0.102 	 CudaGrid[      54] =    0.102 	 Diff =    0.000
# RecSGrid[  0][  1][  4] =    2.767 	 CudaGrid[      54] =    2.767 	 Diff =    0.000
# SolvGrid[  0][  1][  4] =    0.002 	 CudaGrid[      54] =    0.002 	 Diff =    0.000
# HBAcGrid[  0][  1][  4] =   -0.000 	 CudaGrid[      54] =   -0.000 	 Diff =    0.000
# HBDoGrid[  0][  1][  4] =   -0.000 	 CudaGrid[      54] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  0][  2][  0] =    4.570 	 CudaGrid[     100] =    4.570 	 Diff =    0.000
# VdwAGrid[  0][  2][  0] =    0.001 	 CudaGrid[     100] =    0.001 	 Diff =    0.000
# VdwBGrid[  0][  2][  0] =    0.122 	 CudaGrid[     100] =    0.122 	 Diff =    0.000
# RecSGrid[  0][  2][  0] =    2.813 	 CudaGrid[     100] =    2.813 	 Diff =    0.000
# SolvGrid[  0][  2][  0] =    0.002 	 CudaGrid[     100] =    0.002 	 Diff =    0.000
# HBAcGrid[  0][  2][  0] =   -0.000 	 CudaGrid[     100] =   -0.000 	 Diff =    0.000
# HBDoGrid[  0][  2][  0] =   -0.000 	 CudaGrid[     100] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  0][  2][  1] =    4.663 	 CudaGrid[     101] =    4.663 	 Diff =    0.000
# VdwAGrid[  0][  2][  1] =    0.001 	 CudaGrid[     101] =    0.001 	 Diff =    0.000
# VdwBGrid[  0][  2][  1] =    0.118 	 CudaGrid[     101] =    0.118 	 Diff =    0.000
# RecSGrid[  0][  2][  1] =    2.877 	 CudaGrid[     101] =    2.877 	 Diff =    0.000
# SolvGrid[  0][  2][  1] =    0.002 	 CudaGrid[     101] =    0.002 	 Diff =    0.000
# HBAcGrid[  0][  2][  1] =   -0.000 	 CudaGrid[     101] =   -0.000 	 Diff =    0.000
# HBDoGrid[  0][  2][  1] =   -0.000 	 CudaGrid[     101] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  0][  2][  2] =    4.736 	 CudaGrid[     102] =    4.736 	 Diff =    0.000
# VdwAGrid[  0][  2][  2] =    0.000 	 CudaGrid[     102] =    0.000 	 Diff =    0.000
# VdwBGrid[  0][  2][  2] =    0.116 	 CudaGrid[     102] =    0.116 	 Diff =    0.000
# RecSGrid[  0][  2][  2] =    2.939 	 CudaGrid[     102] =    2.939 	 Diff =    0.000
# SolvGrid[  0][  2][  2] =    0.002 	 CudaGrid[     102] =    0.002 	 Diff =    0.000
# HBAcGrid[  0][  2][  2] =   -0.000 	 CudaGrid[     102] =   -0.000 	 Diff =    0.000
# HBDoGrid[  0][  2][  2] =   -0.000 	 CudaGrid[     102] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  0][  2][  3] =    4.791 	 CudaGrid[     103] =    4.791 	 Diff =    0.000
# VdwAGrid[  0][  2][  3] =    0.000 	 CudaGrid[     103] =    0.000 	 Diff =    0.000
# VdwBGrid[  0][  2][  3] =    0.116 	 CudaGrid[     103] =    0.116 	 Diff =    0.000
# RecSGrid[  0][  2][  3] =    3.000 	 CudaGrid[     103] =    3.000 	 Diff =    0.000
# SolvGrid[  0][  2][  3] =    0.002 	 CudaGrid[     103] =    0.002 	 Diff =    0.000
# HBAcGrid[  0][  2][  3] =   -0.000 	 CudaGrid[     103] =   -0.000 	 Diff =    0.000
# HBDoGrid[  0][  2][  3] =   -0.000 	 CudaGrid[     103] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  0][  2][  4] =    4.832 	 CudaGrid[     104] =    4.832 	 Diff =    0.000
# VdwAGrid[  0][  2][  4] =    0.000 	 CudaGrid[     104] =    0.000 	 Diff =    0.000
# VdwBGrid[  0][  2][  4] =    0.119 	 CudaGrid[     104] =    0.119 	 Diff =    0.000
# RecSGrid[  0][  2][  4] =    3.061 	 CudaGrid[     104] =    3.061 	 Diff =    0.000
# SolvGrid[  0][  2][  4] =    0.002 	 CudaGrid[     104] =    0.002 	 Diff =    0.000
# HBAcGrid[  0][  2][  4] =   -0.000 	 CudaGrid[     104] =   -0.000 	 Diff =    0.000
# HBDoGrid[  0][  2][  4] =   -0.000 	 CudaGrid[     104] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  0][  3][  0] =    4.685 	 CudaGrid[     150] =    4.685 	 Diff =    0.000
# VdwAGrid[  0][  3][  0] =    0.001 	 CudaGrid[     150] =    0.001 	 Diff =    0.000
# VdwBGrid[  0][  3][  0] =    0.147 	 CudaGrid[     150] =    0.147 	 Diff =    0.000
# RecSGrid[  0][  3][  0] =    3.094 	 CudaGrid[     150] =    3.094 	 Diff =    0.000
# SolvGrid[  0][  3][  0] =    0.003 	 CudaGrid[     150] =    0.003 	 Diff =    0.000
# HBAcGrid[  0][  3][  0] =   -0.000 	 CudaGrid[     150] =   -0.000 	 Diff =    0.000
# HBDoGrid[  0][  3][  0] =   -0.000 	 CudaGrid[     150] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  0][  3][  1] =    4.800 	 CudaGrid[     151] =    4.800 	 Diff =    0.000
# VdwAGrid[  0][  3][  1] =    0.001 	 CudaGrid[     151] =    0.001 	 Diff =    0.000
# VdwBGrid[  0][  3][  1] =    0.140 	 CudaGrid[     151] =    0.140 	 Diff =    0.000
# RecSGrid[  0][  3][  1] =    3.163 	 CudaGrid[     151] =    3.163 	 Diff =    0.000
# SolvGrid[  0][  3][  1] =    0.003 	 CudaGrid[     151] =    0.003 	 Diff =    0.000
# HBAcGrid[  0][  3][  1] =   -0.000 	 CudaGrid[     151] =   -0.000 	 Diff =    0.000
# HBDoGrid[  0][  3][  1] =   -0.000 	 CudaGrid[     151] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  0][  3][  2] =    4.884 	 CudaGrid[     152] =    4.884 	 Diff =    0.000
# VdwAGrid[  0][  3][  2] =    0.001 	 CudaGrid[     152] =    0.001 	 Diff =    0.000
# VdwBGrid[  0][  3][  2] =    0.136 	 CudaGrid[     152] =    0.136 	 Diff =    0.000
# RecSGrid[  0][  3][  2] =    3.229 	 CudaGrid[     152] =    3.229 	 Diff =    0.000
# SolvGrid[  0][  3][  2] =    0.003 	 CudaGrid[     152] =    0.003 	 Diff =    0.000
# HBAcGrid[  0][  3][  2] =   -0.000 	 CudaGrid[     152] =   -0.000 	 Diff =    0.000
# HBDoGrid[  0][  3][  2] =   -0.000 	 CudaGrid[     152] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  0][  3][  3] =    4.941 	 CudaGrid[     153] =    4.941 	 Diff =    0.000
# VdwAGrid[  0][  3][  3] =    0.001 	 CudaGrid[     153] =    0.001 	 Diff =    0.000
# VdwBGrid[  0][  3][  3] =    0.135 	 CudaGrid[     153] =    0.135 	 Diff =    0.000
# RecSGrid[  0][  3][  3] =    3.294 	 CudaGrid[     153] =    3.294 	 Diff =    0.000
# SolvGrid[  0][  3][  3] =    0.003 	 CudaGrid[     153] =    0.003 	 Diff =    0.000
# HBAcGrid[  0][  3][  3] =   -0.000 	 CudaGrid[     153] =   -0.000 	 Diff =    0.000
# HBDoGrid[  0][  3][  3] =   -0.000 	 CudaGrid[     153] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  0][  3][  4] =    4.977 	 CudaGrid[     154] =    4.977 	 Diff =    0.000
# VdwAGrid[  0][  3][  4] =    0.001 	 CudaGrid[     154] =    0.001 	 Diff =    0.000
# VdwBGrid[  0][  3][  4] =    0.137 	 CudaGrid[     154] =    0.137 	 Diff =    0.000
# RecSGrid[  0][  3][  4] =    3.357 	 CudaGrid[     154] =    3.357 	 Diff =    0.000
# SolvGrid[  0][  3][  4] =    0.003 	 CudaGrid[     154] =    0.003 	 Diff =    0.000
# HBAcGrid[  0][  3][  4] =   -0.000 	 CudaGrid[     154] =   -0.000 	 Diff =    0.000
# HBDoGrid[  0][  3][  4] =   -0.000 	 CudaGrid[     154] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  0][  4][  0] =    4.816 	 CudaGrid[     200] =    4.816 	 Diff =    0.000
# VdwAGrid[  0][  4][  0] =    0.002 	 CudaGrid[     200] =    0.002 	 Diff =    0.000
# VdwBGrid[  0][  4][  0] =    0.175 	 CudaGrid[     200] =    0.175 	 Diff =    0.000
# RecSGrid[  0][  4][  0] =    3.375 	 CudaGrid[     200] =    3.375 	 Diff =    0.000
# SolvGrid[  0][  4][  0] =    0.003 	 CudaGrid[     200] =    0.003 	 Diff =    0.000
# HBAcGrid[  0][  4][  0] =   -0.000 	 CudaGrid[     200] =   -0.000 	 Diff =    0.000
# HBDoGrid[  0][  4][  0] =   -0.000 	 CudaGrid[     200] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  0][  4][  1] =    4.953 	 CudaGrid[     201] =    4.953 	 Diff =    0.000
# VdwAGrid[  0][  4][  1] =    0.001 	 CudaGrid[     201] =    0.001 	 Diff =    0.000
# VdwBGrid[  0][  4][  1] =    0.165 	 CudaGrid[     201] =    0.165 	 Diff =    0.000
# RecSGrid[  0][  4][  1] =    3.449 	 CudaGrid[     201] =    3.449 	 Diff =    0.000
# SolvGrid[  0][  4][  1] =    0.003 	 CudaGrid[     201] =    0.003 	 Diff =    0.000
# HBAcGrid[  0][  4][  1] =   -0.000 	 CudaGrid[     201] =   -0.000 	 Diff =    0.000
# HBDoGrid[  0][  4][  1] =   -0.000 	 CudaGrid[     201] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  0][  4][  2] =    5.046 	 CudaGrid[     202] =    5.046 	 Diff =    0.000
# VdwAGrid[  0][  4][  2] =    0.001 	 CudaGrid[     202] =    0.001 	 Diff =    0.000
# VdwBGrid[  0][  4][  2] =    0.158 	 CudaGrid[     202] =    0.158 	 Diff =    0.000
# RecSGrid[  0][  4][  2] =    3.519 	 CudaGrid[     202] =    3.519 	 Diff =    0.000
# SolvGrid[  0][  4][  2] =    0.003 	 CudaGrid[     202] =    0.003 	 Diff =    0.000
# HBAcGrid[  0][  4][  2] =   -0.000 	 CudaGrid[     202] =   -0.000 	 Diff =    0.000
# HBDoGrid[  0][  4][  2] =   -0.000 	 CudaGrid[     202] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  0][  4][  3] =    5.101 	 CudaGrid[     203] =    5.101 	 Diff =    0.000
# VdwAGrid[  0][  4][  3] =    0.001 	 CudaGrid[     203] =    0.001 	 Diff =    0.000
# VdwBGrid[  0][  4][  3] =    0.155 	 CudaGrid[     203] =    0.155 	 Diff =    0.000
# RecSGrid[  0][  4][  3] =    3.587 	 CudaGrid[     203] =    3.587 	 Diff =    0.000
# SolvGrid[  0][  4][  3] =    0.003 	 CudaGrid[     203] =    0.003 	 Diff =    0.000
# HBAcGrid[  0][  4][  3] =   -0.000 	 CudaGrid[     203] =   -0.000 	 Diff =    0.000
# HBDoGrid[  0][  4][  3] =   -0.000 	 CudaGrid[     203] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  0][  4][  4] =    5.127 	 CudaGrid[     204] =    5.127 	 Diff =    0.000
# VdwAGrid[  0][  4][  4] =    0.001 	 CudaGrid[     204] =    0.001 	 Diff =    0.000
# VdwBGrid[  0][  4][  4] =    0.157 	 CudaGrid[     204] =    0.157 	 Diff =    0.000
# RecSGrid[  0][  4][  4] =    3.653 	 CudaGrid[     204] =    3.653 	 Diff =    0.000
# SolvGrid[  0][  4][  4] =    0.003 	 CudaGrid[     204] =    0.003 	 Diff =    0.000
# HBAcGrid[  0][  4][  4] =   -0.000 	 CudaGrid[     204] =   -0.000 	 Diff =    0.000
# HBDoGrid[  0][  4][  4] =   -0.000 	 CudaGrid[     204] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  1][  0][  0] =    4.497 	 CudaGrid[    2500] =    4.497 	 Diff =    0.000
# VdwAGrid[  1][  0][  0] =    0.000 	 CudaGrid[    2500] =    0.000 	 Diff =    0.000
# VdwBGrid[  1][  0][  0] =    0.107 	 CudaGrid[    2500] =    0.107 	 Diff =    0.000
# RecSGrid[  1][  0][  0] =    2.664 	 CudaGrid[    2500] =    2.664 	 Diff =    0.000
# SolvGrid[  1][  0][  0] =    0.002 	 CudaGrid[    2500] =    0.002 	 Diff =    0.000
# HBAcGrid[  1][  0][  0] =   -0.000 	 CudaGrid[    2500] =   -0.000 	 Diff =    0.000
# HBDoGrid[  1][  0][  0] =   -0.000 	 CudaGrid[    2500] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  1][  0][  1] =    4.561 	 CudaGrid[    2501] =    4.561 	 Diff =    0.000
# VdwAGrid[  1][  0][  1] =    0.000 	 CudaGrid[    2501] =    0.000 	 Diff =    0.000
# VdwBGrid[  1][  0][  1] =    0.106 	 CudaGrid[    2501] =    0.106 	 Diff =    0.000
# RecSGrid[  1][  0][  1] =    2.727 	 CudaGrid[    2501] =    2.727 	 Diff =    0.000
# SolvGrid[  1][  0][  1] =    0.002 	 CudaGrid[    2501] =    0.002 	 Diff =    0.000
# HBAcGrid[  1][  0][  1] =   -0.000 	 CudaGrid[    2501] =   -0.000 	 Diff =    0.000
# HBDoGrid[  1][  0][  1] =   -0.000 	 CudaGrid[    2501] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  1][  0][  2] =    4.617 	 CudaGrid[    2502] =    4.617 	 Diff =    0.000
# VdwAGrid[  1][  0][  2] =    0.000 	 CudaGrid[    2502] =    0.000 	 Diff =    0.000
# VdwBGrid[  1][  0][  2] =    0.105 	 CudaGrid[    2502] =    0.105 	 Diff =    0.000
# RecSGrid[  1][  0][  2] =    2.788 	 CudaGrid[    2502] =    2.788 	 Diff =    0.000
# SolvGrid[  1][  0][  2] =    0.002 	 CudaGrid[    2502] =    0.002 	 Diff =    0.000
# HBAcGrid[  1][  0][  2] =   -0.000 	 CudaGrid[    2502] =   -0.000 	 Diff =    0.000
# HBDoGrid[  1][  0][  2] =   -0.000 	 CudaGrid[    2502] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  1][  0][  3] =    4.665 	 CudaGrid[    2503] =    4.665 	 Diff =    0.000
# VdwAGrid[  1][  0][  3] =    0.000 	 CudaGrid[    2503] =    0.000 	 Diff =    0.000
# VdwBGrid[  1][  0][  3] =    0.106 	 CudaGrid[    2503] =    0.106 	 Diff =    0.000
# RecSGrid[  1][  0][  3] =    2.848 	 CudaGrid[    2503] =    2.848 	 Diff =    0.000
# SolvGrid[  1][  0][  3] =    0.002 	 CudaGrid[    2503] =    0.002 	 Diff =    0.000
# HBAcGrid[  1][  0][  3] =   -0.000 	 CudaGrid[    2503] =   -0.000 	 Diff =    0.000
# HBDoGrid[  1][  0][  3] =   -0.000 	 CudaGrid[    2503] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  1][  0][  4] =    4.711 	 CudaGrid[    2504] =    4.711 	 Diff =    0.000
# VdwAGrid[  1][  0][  4] =    0.000 	 CudaGrid[    2504] =    0.000 	 Diff =    0.000
# VdwBGrid[  1][  0][  4] =    0.109 	 CudaGrid[    2504] =    0.109 	 Diff =    0.000
# RecSGrid[  1][  0][  4] =    2.908 	 CudaGrid[    2504] =    2.908 	 Diff =    0.000
# SolvGrid[  1][  0][  4] =    0.002 	 CudaGrid[    2504] =    0.002 	 Diff =    0.000
# HBAcGrid[  1][  0][  4] =   -0.000 	 CudaGrid[    2504] =   -0.000 	 Diff =    0.000
# HBDoGrid[  1][  0][  4] =   -0.000 	 CudaGrid[    2504] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  1][  1][  0] =    4.607 	 CudaGrid[    2550] =    4.607 	 Diff =    0.000
# VdwAGrid[  1][  1][  0] =    0.001 	 CudaGrid[    2550] =    0.001 	 Diff =    0.000
# VdwBGrid[  1][  1][  0] =    0.131 	 CudaGrid[    2550] =    0.131 	 Diff =    0.000
# RecSGrid[  1][  1][  0] =    2.975 	 CudaGrid[    2550] =    2.975 	 Diff =    0.000
# SolvGrid[  1][  1][  0] =    0.003 	 CudaGrid[    2550] =    0.003 	 Diff =    0.000
# HBAcGrid[  1][  1][  0] =   -0.000 	 CudaGrid[    2550] =   -0.000 	 Diff =    0.000
# HBDoGrid[  1][  1][  0] =   -0.000 	 CudaGrid[    2550] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  1][  1][  1] =    4.693 	 CudaGrid[    2551] =    4.693 	 Diff =    0.000
# VdwAGrid[  1][  1][  1] =    0.001 	 CudaGrid[    2551] =    0.001 	 Diff =    0.000
# VdwBGrid[  1][  1][  1] =    0.128 	 CudaGrid[    2551] =    0.128 	 Diff =    0.000
# RecSGrid[  1][  1][  1] =    3.044 	 CudaGrid[    2551] =    3.044 	 Diff =    0.000
# SolvGrid[  1][  1][  1] =    0.003 	 CudaGrid[    2551] =    0.003 	 Diff =    0.000
# HBAcGrid[  1][  1][  1] =   -0.000 	 CudaGrid[    2551] =   -0.000 	 Diff =    0.000
# HBDoGrid[  1][  1][  1] =   -0.000 	 CudaGrid[    2551] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  1][  1][  2] =    4.762 	 CudaGrid[    2552] =    4.762 	 Diff =    0.000
# VdwAGrid[  1][  1][  2] =    0.001 	 CudaGrid[    2552] =    0.001 	 Diff =    0.000
# VdwBGrid[  1][  1][  2] =    0.126 	 CudaGrid[    2552] =    0.126 	 Diff =    0.000
# RecSGrid[  1][  1][  2] =    3.110 	 CudaGrid[    2552] =    3.110 	 Diff =    0.000
# SolvGrid[  1][  1][  2] =    0.002 	 CudaGrid[    2552] =    0.002 	 Diff =    0.000
# HBAcGrid[  1][  1][  2] =   -0.000 	 CudaGrid[    2552] =   -0.000 	 Diff =    0.000
# HBDoGrid[  1][  1][  2] =   -0.000 	 CudaGrid[    2552] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  1][  1][  3] =    4.816 	 CudaGrid[    2553] =    4.816 	 Diff =    0.000
# VdwAGrid[  1][  1][  3] =    0.000 	 CudaGrid[    2553] =    0.000 	 Diff =    0.000
# VdwBGrid[  1][  1][  3] =    0.126 	 CudaGrid[    2553] =    0.126 	 Diff =    0.000
# RecSGrid[  1][  1][  3] =    3.175 	 CudaGrid[    2553] =    3.175 	 Diff =    0.000
# SolvGrid[  1][  1][  3] =    0.002 	 CudaGrid[    2553] =    0.002 	 Diff =    0.000
# HBAcGrid[  1][  1][  3] =   -0.000 	 CudaGrid[    2553] =   -0.000 	 Diff =    0.000
# HBDoGrid[  1][  1][  3] =   -0.000 	 CudaGrid[    2553] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  1][  1][  4] =    4.862 	 CudaGrid[    2554] =    4.862 	 Diff =    0.000
# VdwAGrid[  1][  1][  4] =    0.000 	 CudaGrid[    2554] =    0.000 	 Diff =    0.000
# VdwBGrid[  1][  1][  4] =    0.129 	 CudaGrid[    2554] =    0.129 	 Diff =    0.000
# RecSGrid[  1][  1][  4] =    3.239 	 CudaGrid[    2554] =    3.239 	 Diff =    0.000
# SolvGrid[  1][  1][  4] =    0.003 	 CudaGrid[    2554] =    0.003 	 Diff =    0.000
# HBAcGrid[  1][  1][  4] =   -0.000 	 CudaGrid[    2554] =   -0.000 	 Diff =    0.000
# HBDoGrid[  1][  1][  4] =   -0.000 	 CudaGrid[    2554] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  1][  2][  0] =    4.719 	 CudaGrid[    2600] =    4.719 	 Diff =    0.000
# VdwAGrid[  1][  2][  0] =    0.001 	 CudaGrid[    2600] =    0.001 	 Diff =    0.000
# VdwBGrid[  1][  2][  0] =    0.162 	 CudaGrid[    2600] =    0.162 	 Diff =    0.000
# RecSGrid[  1][  2][  0] =    3.294 	 CudaGrid[    2600] =    3.294 	 Diff =    0.000
# SolvGrid[  1][  2][  0] =    0.003 	 CudaGrid[    2600] =    0.003 	 Diff =    0.000
# HBAcGrid[  1][  2][  0] =   -0.000 	 CudaGrid[    2600] =   -0.000 	 Diff =    0.000
# HBDoGrid[  1][  2][  0] =   -0.000 	 CudaGrid[    2600] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  1][  2][  1] =    4.831 	 CudaGrid[    2601] =    4.831 	 Diff =    0.000
# VdwAGrid[  1][  2][  1] =    0.001 	 CudaGrid[    2601] =    0.001 	 Diff =    0.000
# VdwBGrid[  1][  2][  1] =    0.155 	 CudaGrid[    2601] =    0.155 	 Diff =    0.000
# RecSGrid[  1][  2][  1] =    3.369 	 CudaGrid[    2601] =    3.369 	 Diff =    0.000
# SolvGrid[  1][  2][  1] =    0.003 	 CudaGrid[    2601] =    0.003 	 Diff =    0.000
# HBAcGrid[  1][  2][  1] =   -0.000 	 CudaGrid[    2601] =   -0.000 	 Diff =    0.000
# HBDoGrid[  1][  2][  1] =   -0.000 	 CudaGrid[    2601] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  1][  2][  2] =    4.915 	 CudaGrid[    2602] =    4.915 	 Diff =    0.000
# VdwAGrid[  1][  2][  2] =    0.001 	 CudaGrid[    2602] =    0.001 	 Diff =    0.000
# VdwBGrid[  1][  2][  2] =    0.151 	 CudaGrid[    2602] =    0.151 	 Diff =    0.000
# RecSGrid[  1][  2][  2] =    3.440 	 CudaGrid[    2602] =    3.440 	 Diff =    0.000
# SolvGrid[  1][  2][  2] =    0.003 	 CudaGrid[    2602] =    0.003 	 Diff =    0.000
# HBAcGrid[  1][  2][  2] =   -0.000 	 CudaGrid[    2602] =   -0.000 	 Diff =    0.000
# HBDoGrid[  1][  2][  2] =   -0.000 	 CudaGrid[    2602] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  1][  2][  3] =    4.976 	 CudaGrid[    2603] =    4.976 	 Diff =    0.000
# VdwAGrid[  1][  2][  3] =    0.001 	 CudaGrid[    2603] =    0.001 	 Diff =    0.000
# VdwBGrid[  1][  2][  3] =    0.149 	 CudaGrid[    2603] =    0.149 	 Diff =    0.000
# RecSGrid[  1][  2][  3] =    3.509 	 CudaGrid[    2603] =    3.509 	 Diff =    0.000
# SolvGrid[  1][  2][  3] =    0.003 	 CudaGrid[    2603] =    0.003 	 Diff =    0.000
# HBAcGrid[  1][  2][  3] =   -0.000 	 CudaGrid[    2603] =   -0.000 	 Diff =    0.000
# HBDoGrid[  1][  2][  3] =   -0.000 	 CudaGrid[    2603] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  1][  2][  4] =    5.019 	 CudaGrid[    2604] =    5.019 	 Diff =    0.000
# VdwAGrid[  1][  2][  4] =    0.001 	 CudaGrid[    2604] =    0.001 	 Diff =    0.000
# VdwBGrid[  1][  2][  4] =    0.152 	 CudaGrid[    2604] =    0.152 	 Diff =    0.000
# RecSGrid[  1][  2][  4] =    3.576 	 CudaGrid[    2604] =    3.576 	 Diff =    0.000
# SolvGrid[  1][  2][  4] =    0.003 	 CudaGrid[    2604] =    0.003 	 Diff =    0.000
# HBAcGrid[  1][  2][  4] =   -0.000 	 CudaGrid[    2604] =   -0.000 	 Diff =    0.000
# HBDoGrid[  1][  2][  4] =   -0.000 	 CudaGrid[    2604] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  1][  3][  0] =    4.837 	 CudaGrid[    2650] =    4.837 	 Diff =    0.000
# VdwAGrid[  1][  3][  0] =    0.003 	 CudaGrid[    2650] =    0.003 	 Diff =    0.000
# VdwBGrid[  1][  3][  0] =    0.199 	 CudaGrid[    2650] =    0.199 	 Diff =    0.000
# RecSGrid[  1][  3][  0] =    3.617 	 CudaGrid[    2650] =    3.617 	 Diff =    0.000
# SolvGrid[  1][  3][  0] =    0.003 	 CudaGrid[    2650] =    0.003 	 Diff =    0.000
# HBAcGrid[  1][  3][  0] =   -0.000 	 CudaGrid[    2650] =   -0.000 	 Diff =    0.000
# HBDoGrid[  1][  3][  0] =   -0.000 	 CudaGrid[    2650] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  1][  3][  1] =    4.980 	 CudaGrid[    2651] =    4.980 	 Diff =    0.000
# VdwAGrid[  1][  3][  1] =    0.002 	 CudaGrid[    2651] =    0.002 	 Diff =    0.000
# VdwBGrid[  1][  3][  1] =    0.187 	 CudaGrid[    2651] =    0.187 	 Diff =    0.000
# RecSGrid[  1][  3][  1] =    3.697 	 CudaGrid[    2651] =    3.697 	 Diff =    0.000
# SolvGrid[  1][  3][  1] =    0.003 	 CudaGrid[    2651] =    0.003 	 Diff =    0.000
# HBAcGrid[  1][  3][  1] =   -0.000 	 CudaGrid[    2651] =   -0.000 	 Diff =    0.000
# HBDoGrid[  1][  3][  1] =   -0.000 	 CudaGrid[    2651] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  1][  3][  2] =    5.081 	 CudaGrid[    2652] =    5.081 	 Diff =    0.000
# VdwAGrid[  1][  3][  2] =    0.001 	 CudaGrid[    2652] =    0.001 	 Diff =    0.000
# VdwBGrid[  1][  3][  2] =    0.179 	 CudaGrid[    2652] =    0.179 	 Diff =    0.000
# RecSGrid[  1][  3][  2] =    3.773 	 CudaGrid[    2652] =    3.773 	 Diff =    0.000
# SolvGrid[  1][  3][  2] =    0.003 	 CudaGrid[    2652] =    0.003 	 Diff =    0.000
# HBAcGrid[  1][  3][  2] =   -0.000 	 CudaGrid[    2652] =   -0.000 	 Diff =    0.000
# HBDoGrid[  1][  3][  2] =   -0.000 	 CudaGrid[    2652] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  1][  3][  3] =    5.145 	 CudaGrid[    2653] =    5.145 	 Diff =    0.000
# VdwAGrid[  1][  3][  3] =    0.001 	 CudaGrid[    2653] =    0.001 	 Diff =    0.000
# VdwBGrid[  1][  3][  3] =    0.176 	 CudaGrid[    2653] =    0.176 	 Diff =    0.000
# RecSGrid[  1][  3][  3] =    3.846 	 CudaGrid[    2653] =    3.846 	 Diff =    0.000
# SolvGrid[  1][  3][  3] =    0.003 	 CudaGrid[    2653] =    0.003 	 Diff =    0.000
# HBAcGrid[  1][  3][  3] =   -0.000 	 CudaGrid[    2653] =   -0.000 	 Diff =    0.000
# HBDoGrid[  1][  3][  3] =   -0.000 	 CudaGrid[    2653] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  1][  3][  4] =    5.184 	 CudaGrid[    2654] =    5.184 	 Diff =    0.000
# VdwAGrid[  1][  3][  4] =    0.001 	 CudaGrid[    2654] =    0.001 	 Diff =    0.000
# VdwBGrid[  1][  3][  4] =    0.178 	 CudaGrid[    2654] =    0.178 	 Diff =    0.000
# RecSGrid[  1][  3][  4] =    3.917 	 CudaGrid[    2654] =    3.917 	 Diff =    0.000
# SolvGrid[  1][  3][  4] =    0.003 	 CudaGrid[    2654] =    0.003 	 Diff =    0.000
# HBAcGrid[  1][  3][  4] =   -0.000 	 CudaGrid[    2654] =   -0.000 	 Diff =    0.000
# HBDoGrid[  1][  3][  4] =   -0.000 	 CudaGrid[    2654] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  1][  4][  0] =    4.974 	 CudaGrid[    2700] =    4.974 	 Diff =    0.000
# VdwAGrid[  1][  4][  0] =    0.004 	 CudaGrid[    2700] =    0.004 	 Diff =    0.000
# VdwBGrid[  1][  4][  0] =    0.243 	 CudaGrid[    2700] =    0.243 	 Diff =    0.000
# RecSGrid[  1][  4][  0] =    3.938 	 CudaGrid[    2700] =    3.938 	 Diff =    0.000
# SolvGrid[  1][  4][  0] =    0.003 	 CudaGrid[    2700] =    0.003 	 Diff =    0.000
# HBAcGrid[  1][  4][  0] =   -0.000 	 CudaGrid[    2700] =   -0.000 	 Diff =    0.000
# HBDoGrid[  1][  4][  0] =   -0.000 	 CudaGrid[    2700] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  1][  4][  1] =    5.148 	 CudaGrid[    2701] =    5.148 	 Diff =    0.000
# VdwAGrid[  1][  4][  1] =    0.003 	 CudaGrid[    2701] =    0.003 	 Diff =    0.000
# VdwBGrid[  1][  4][  1] =    0.225 	 CudaGrid[    2701] =    0.225 	 Diff =    0.000
# RecSGrid[  1][  4][  1] =    4.024 	 CudaGrid[    2701] =    4.024 	 Diff =    0.000
# SolvGrid[  1][  4][  1] =    0.003 	 CudaGrid[    2701] =    0.003 	 Diff =    0.000
# HBAcGrid[  1][  4][  1] =   -0.000 	 CudaGrid[    2701] =   -0.000 	 Diff =    0.000
# HBDoGrid[  1][  4][  1] =   -0.000 	 CudaGrid[    2701] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  1][  4][  2] =    5.262 	 CudaGrid[    2702] =    5.262 	 Diff =    0.000
# VdwAGrid[  1][  4][  2] =    0.002 	 CudaGrid[    2702] =    0.002 	 Diff =    0.000
# VdwBGrid[  1][  4][  2] =    0.212 	 CudaGrid[    2702] =    0.212 	 Diff =    0.000
# RecSGrid[  1][  4][  2] =    4.105 	 CudaGrid[    2702] =    4.105 	 Diff =    0.000
# SolvGrid[  1][  4][  2] =    0.003 	 CudaGrid[    2702] =    0.003 	 Diff =    0.000
# HBAcGrid[  1][  4][  2] =   -0.000 	 CudaGrid[    2702] =   -0.000 	 Diff =    0.000
# HBDoGrid[  1][  4][  2] =   -0.000 	 CudaGrid[    2702] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  1][  4][  3] =    5.326 	 CudaGrid[    2703] =    5.326 	 Diff =    0.000
# VdwAGrid[  1][  4][  3] =    0.002 	 CudaGrid[    2703] =    0.002 	 Diff =    0.000
# VdwBGrid[  1][  4][  3] =    0.205 	 CudaGrid[    2703] =    0.205 	 Diff =    0.000
# RecSGrid[  1][  4][  3] =    4.181 	 CudaGrid[    2703] =    4.181 	 Diff =    0.000
# SolvGrid[  1][  4][  3] =    0.003 	 CudaGrid[    2703] =    0.003 	 Diff =    0.000
# HBAcGrid[  1][  4][  3] =   -0.000 	 CudaGrid[    2703] =   -0.000 	 Diff =    0.000
# HBDoGrid[  1][  4][  3] =   -0.000 	 CudaGrid[    2703] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  1][  4][  4] =    5.354 	 CudaGrid[    2704] =    5.354 	 Diff =    0.000
# VdwAGrid[  1][  4][  4] =    0.002 	 CudaGrid[    2704] =    0.002 	 Diff =    0.000
# VdwBGrid[  1][  4][  4] =    0.206 	 CudaGrid[    2704] =    0.206 	 Diff =    0.000
# RecSGrid[  1][  4][  4] =    4.255 	 CudaGrid[    2704] =    4.255 	 Diff =    0.000
# SolvGrid[  1][  4][  4] =    0.003 	 CudaGrid[    2704] =    0.003 	 Diff =    0.000
# HBAcGrid[  1][  4][  4] =   -0.000 	 CudaGrid[    2704] =   -0.000 	 Diff =    0.000
# HBDoGrid[  1][  4][  4] =   -0.000 	 CudaGrid[    2704] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  2][  0][  0] =    4.652 	 CudaGrid[    5000] =    4.652 	 Diff =    0.000
# VdwAGrid[  2][  0][  0] =    0.001 	 CudaGrid[    5000] =    0.001 	 Diff =    0.000
# VdwBGrid[  2][  0][  0] =    0.137 	 CudaGrid[    5000] =    0.137 	 Diff =    0.000
# RecSGrid[  2][  0][  0] =    3.102 	 CudaGrid[    5000] =    3.102 	 Diff =    0.000
# SolvGrid[  2][  0][  0] =    0.003 	 CudaGrid[    5000] =    0.003 	 Diff =    0.000
# HBAcGrid[  2][  0][  0] =   -0.000 	 CudaGrid[    5000] =   -0.000 	 Diff =    0.000
# HBDoGrid[  2][  0][  0] =   -0.000 	 CudaGrid[    5000] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  2][  0][  1] =    4.720 	 CudaGrid[    5001] =    4.720 	 Diff =    0.000
# VdwAGrid[  2][  0][  1] =    0.001 	 CudaGrid[    5001] =    0.001 	 Diff =    0.000
# VdwBGrid[  2][  0][  1] =    0.134 	 CudaGrid[    5001] =    0.134 	 Diff =    0.000
# RecSGrid[  2][  0][  1] =    3.175 	 CudaGrid[    5001] =    3.175 	 Diff =    0.000
# SolvGrid[  2][  0][  1] =    0.003 	 CudaGrid[    5001] =    0.003 	 Diff =    0.000
# HBAcGrid[  2][  0][  1] =   -0.000 	 CudaGrid[    5001] =   -0.000 	 Diff =    0.000
# HBDoGrid[  2][  0][  1] =   -0.000 	 CudaGrid[    5001] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  2][  0][  2] =    4.776 	 CudaGrid[    5002] =    4.776 	 Diff =    0.000
# VdwAGrid[  2][  0][  2] =    0.001 	 CudaGrid[    5002] =    0.001 	 Diff =    0.000
# VdwBGrid[  2][  0][  2] =    0.133 	 CudaGrid[    5002] =    0.133 	 Diff =    0.000
# RecSGrid[  2][  0][  2] =    3.245 	 CudaGrid[    5002] =    3.245 	 Diff =    0.000
# SolvGrid[  2][  0][  2] =    0.003 	 CudaGrid[    5002] =    0.003 	 Diff =    0.000
# HBAcGrid[  2][  0][  2] =   -0.000 	 CudaGrid[    5002] =   -0.000 	 Diff =    0.000
# HBDoGrid[  2][  0][  2] =   -0.000 	 CudaGrid[    5002] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  2][  0][  3] =    4.823 	 CudaGrid[    5003] =    4.823 	 Diff =    0.000
# VdwAGrid[  2][  0][  3] =    0.001 	 CudaGrid[    5003] =    0.001 	 Diff =    0.000
# VdwBGrid[  2][  0][  3] =    0.134 	 CudaGrid[    5003] =    0.134 	 Diff =    0.000
# RecSGrid[  2][  0][  3] =    3.313 	 CudaGrid[    5003] =    3.313 	 Diff =    0.000
# SolvGrid[  2][  0][  3] =    0.003 	 CudaGrid[    5003] =    0.003 	 Diff =    0.000
# HBAcGrid[  2][  0][  3] =   -0.000 	 CudaGrid[    5003] =   -0.000 	 Diff =    0.000
# HBDoGrid[  2][  0][  3] =   -0.000 	 CudaGrid[    5003] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  2][  0][  4] =    4.867 	 CudaGrid[    5004] =    4.867 	 Diff =    0.000
# VdwAGrid[  2][  0][  4] =    0.001 	 CudaGrid[    5004] =    0.001 	 Diff =    0.000
# VdwBGrid[  2][  0][  4] =    0.137 	 CudaGrid[    5004] =    0.137 	 Diff =    0.000
# RecSGrid[  2][  0][  4] =    3.380 	 CudaGrid[    5004] =    3.380 	 Diff =    0.000
# SolvGrid[  2][  0][  4] =    0.003 	 CudaGrid[    5004] =    0.003 	 Diff =    0.000
# HBAcGrid[  2][  0][  4] =   -0.000 	 CudaGrid[    5004] =   -0.000 	 Diff =    0.000
# HBDoGrid[  2][  0][  4] =   -0.000 	 CudaGrid[    5004] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  2][  1][  0] =    4.773 	 CudaGrid[    5050] =    4.773 	 Diff =    0.000
# VdwAGrid[  2][  1][  0] =    0.002 	 CudaGrid[    5050] =    0.002 	 Diff =    0.000
# VdwBGrid[  2][  1][  0] =    0.172 	 CudaGrid[    5050] =    0.172 	 Diff =    0.000
# RecSGrid[  2][  1][  0] =    3.458 	 CudaGrid[    5050] =    3.458 	 Diff =    0.000
# SolvGrid[  2][  1][  0] =    0.003 	 CudaGrid[    5050] =    0.003 	 Diff =    0.000
# HBAcGrid[  2][  1][  0] =   -0.000 	 CudaGrid[    5050] =   -0.000 	 Diff =    0.000
# HBDoGrid[  2][  1][  0] =   -0.000 	 CudaGrid[    5050] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  2][  1][  1] =    4.868 	 CudaGrid[    5051] =    4.868 	 Diff =    0.000
# VdwAGrid[  2][  1][  1] =    0.001 	 CudaGrid[    5051] =    0.001 	 Diff =    0.000
# VdwBGrid[  2][  1][  1] =    0.166 	 CudaGrid[    5051] =    0.166 	 Diff =    0.000
# RecSGrid[  2][  1][  1] =    3.538 	 CudaGrid[    5051] =    3.538 	 Diff =    0.000
# SolvGrid[  2][  1][  1] =    0.003 	 CudaGrid[    5051] =    0.003 	 Diff =    0.000
# HBAcGrid[  2][  1][  1] =   -0.000 	 CudaGrid[    5051] =   -0.000 	 Diff =    0.000
# HBDoGrid[  2][  1][  1] =   -0.000 	 CudaGrid[    5051] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  2][  1][  2] =    4.941 	 CudaGrid[    5052] =    4.941 	 Diff =    0.000
# VdwAGrid[  2][  1][  2] =    0.001 	 CudaGrid[    5052] =    0.001 	 Diff =    0.000
# VdwBGrid[  2][  1][  2] =    0.162 	 CudaGrid[    5052] =    0.162 	 Diff =    0.000
# RecSGrid[  2][  1][  2] =    3.613 	 CudaGrid[    5052] =    3.613 	 Diff =    0.000
# SolvGrid[  2][  1][  2] =    0.003 	 CudaGrid[    5052] =    0.003 	 Diff =    0.000
# HBAcGrid[  2][  1][  2] =   -0.000 	 CudaGrid[    5052] =   -0.000 	 Diff =    0.000
# HBDoGrid[  2][  1][  2] =   -0.000 	 CudaGrid[    5052] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  2][  1][  3] =    4.995 	 CudaGrid[    5053] =    4.995 	 Diff =    0.000
# VdwAGrid[  2][  1][  3] =    0.001 	 CudaGrid[    5053] =    0.001 	 Diff =    0.000
# VdwBGrid[  2][  1][  3] =    0.161 	 CudaGrid[    5053] =    0.161 	 Diff =    0.000
# RecSGrid[  2][  1][  3] =    3.686 	 CudaGrid[    5053] =    3.686 	 Diff =    0.000
# SolvGrid[  2][  1][  3] =    0.003 	 CudaGrid[    5053] =    0.003 	 Diff =    0.000
# HBAcGrid[  2][  1][  3] =   -0.000 	 CudaGrid[    5053] =   -0.000 	 Diff =    0.000
# HBDoGrid[  2][  1][  3] =   -0.000 	 CudaGrid[    5053] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  2][  1][  4] =    5.038 	 CudaGrid[    5054] =    5.038 	 Diff =    0.000
# VdwAGrid[  2][  1][  4] =    0.001 	 CudaGrid[    5054] =    0.001 	 Diff =    0.000
# VdwBGrid[  2][  1][  4] =    0.164 	 CudaGrid[    5054] =    0.164 	 Diff =    0.000
# RecSGrid[  2][  1][  4] =    3.757 	 CudaGrid[    5054] =    3.757 	 Diff =    0.000
# SolvGrid[  2][  1][  4] =    0.003 	 CudaGrid[    5054] =    0.003 	 Diff =    0.000
# HBAcGrid[  2][  1][  4] =   -0.000 	 CudaGrid[    5054] =   -0.000 	 Diff =    0.000
# HBDoGrid[  2][  1][  4] =   -0.000 	 CudaGrid[    5054] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  2][  2][  0] =    4.894 	 CudaGrid[    5100] =    4.894 	 Diff =    0.000
# VdwAGrid[  2][  2][  0] =    0.003 	 CudaGrid[    5100] =    0.003 	 Diff =    0.000
# VdwBGrid[  2][  2][  0] =    0.216 	 CudaGrid[    5100] =    0.216 	 Diff =    0.000
# RecSGrid[  2][  2][  0] =    3.822 	 CudaGrid[    5100] =    3.822 	 Diff =    0.000
# SolvGrid[  2][  2][  0] =    0.003 	 CudaGrid[    5100] =    0.003 	 Diff =    0.000
# HBAcGrid[  2][  2][  0] =   -0.000 	 CudaGrid[    5100] =   -0.000 	 Diff =    0.000
# HBDoGrid[  2][  2][  0] =   -0.000 	 CudaGrid[    5100] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  2][  2][  1] =    5.025 	 CudaGrid[    5101] =    5.025 	 Diff =    0.000
# VdwAGrid[  2][  2][  1] =    0.002 	 CudaGrid[    5101] =    0.002 	 Diff =    0.000
# VdwBGrid[  2][  2][  1] =    0.205 	 CudaGrid[    5101] =    0.205 	 Diff =    0.000
# RecSGrid[  2][  2][  1] =    3.908 	 CudaGrid[    5101] =    3.908 	 Diff =    0.000
# SolvGrid[  2][  2][  1] =    0.003 	 CudaGrid[    5101] =    0.003 	 Diff =    0.000
# HBAcGrid[  2][  2][  1] =   -0.000 	 CudaGrid[    5101] =   -0.000 	 Diff =    0.000
# HBDoGrid[  2][  2][  1] =   -0.000 	 CudaGrid[    5101] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  2][  2][  2] =    5.117 	 CudaGrid[    5102] =    5.117 	 Diff =    0.000
# VdwAGrid[  2][  2][  2] =    0.002 	 CudaGrid[    5102] =    0.002 	 Diff =    0.000
# VdwBGrid[  2][  2][  2] =    0.198 	 CudaGrid[    5102] =    0.198 	 Diff =    0.000
# RecSGrid[  2][  2][  2] =    3.989 	 CudaGrid[    5102] =    3.989 	 Diff =    0.000
# SolvGrid[  2][  2][  2] =    0.003 	 CudaGrid[    5102] =    0.003 	 Diff =    0.000
# HBAcGrid[  2][  2][  2] =   -0.000 	 CudaGrid[    5102] =   -0.000 	 Diff =    0.000
# HBDoGrid[  2][  2][  2] =   -0.000 	 CudaGrid[    5102] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  2][  2][  3] =    5.179 	 CudaGrid[    5103] =    5.179 	 Diff =    0.000
# VdwAGrid[  2][  2][  3] =    0.001 	 CudaGrid[    5103] =    0.001 	 Diff =    0.000
# VdwBGrid[  2][  2][  3] =    0.194 	 CudaGrid[    5103] =    0.194 	 Diff =    0.000
# RecSGrid[  2][  2][  3] =    4.067 	 CudaGrid[    5103] =    4.067 	 Diff =    0.000
# SolvGrid[  2][  2][  3] =    0.003 	 CudaGrid[    5103] =    0.003 	 Diff =    0.000
# HBAcGrid[  2][  2][  3] =   -0.000 	 CudaGrid[    5103] =   -0.000 	 Diff =    0.000
# HBDoGrid[  2][  2][  3] =   -0.000 	 CudaGrid[    5103] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  2][  2][  4] =    5.221 	 CudaGrid[    5104] =    5.221 	 Diff =    0.000
# VdwAGrid[  2][  2][  4] =    0.001 	 CudaGrid[    5104] =    0.001 	 Diff =    0.000
# VdwBGrid[  2][  2][  4] =    0.196 	 CudaGrid[    5104] =    0.196 	 Diff =    0.000
# RecSGrid[  2][  2][  4] =    4.142 	 CudaGrid[    5104] =    4.142 	 Diff =    0.000
# SolvGrid[  2][  2][  4] =    0.003 	 CudaGrid[    5104] =    0.003 	 Diff =    0.000
# HBAcGrid[  2][  2][  4] =   -0.000 	 CudaGrid[    5104] =   -0.000 	 Diff =    0.000
# HBDoGrid[  2][  2][  4] =   -0.000 	 CudaGrid[    5104] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  2][  3][  0] =    5.022 	 CudaGrid[    5150] =    5.022 	 Diff =    0.000
# VdwAGrid[  2][  3][  0] =    0.005 	 CudaGrid[    5150] =    0.005 	 Diff =    0.000
# VdwBGrid[  2][  3][  0] =    0.273 	 CudaGrid[    5150] =    0.273 	 Diff =    0.000
# RecSGrid[  2][  3][  0] =    4.189 	 CudaGrid[    5150] =    4.189 	 Diff =    0.000
# SolvGrid[  2][  3][  0] =    0.004 	 CudaGrid[    5150] =    0.004 	 Diff =    0.000
# HBAcGrid[  2][  3][  0] =   -0.000 	 CudaGrid[    5150] =   -0.000 	 Diff =    0.000
# HBDoGrid[  2][  3][  0] =   -0.000 	 CudaGrid[    5150] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  2][  3][  1] =    5.193 	 CudaGrid[    5151] =    5.193 	 Diff =    0.000
# VdwAGrid[  2][  3][  1] =    0.004 	 CudaGrid[    5151] =    0.004 	 Diff =    0.000
# VdwBGrid[  2][  3][  1] =    0.254 	 CudaGrid[    5151] =    0.254 	 Diff =    0.000
# RecSGrid[  2][  3][  1] =    4.281 	 CudaGrid[    5151] =    4.281 	 Diff =    0.000
# SolvGrid[  2][  3][  1] =    0.003 	 CudaGrid[    5151] =    0.003 	 Diff =    0.000
# HBAcGrid[  2][  3][  1] =   -0.000 	 CudaGrid[    5151] =   -0.000 	 Diff =    0.000
# HBDoGrid[  2][  3][  1] =   -0.000 	 CudaGrid[    5151] =   -0.000 	 Diff =    0.000
#
#
# ...
# HBDoGrid[  3][  4][  3] =   -0.000 	 CudaGrid[    7703] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  3][  4][  4] =    5.895 	 CudaGrid[    7704] =    5.895 	 Diff =    0.000
# VdwAGrid[  3][  4][  4] =    0.006 	 CudaGrid[    7704] =    0.006 	 Diff =    0.000
# VdwBGrid[  3][  4][  4] =    0.365 	 CudaGrid[    7704] =    0.365 	 Diff =    0.000
# RecSGrid[  3][  4][  4] =    5.621 	 CudaGrid[    7704] =    5.621 	 Diff =    0.000
# SolvGrid[  3][  4][  4] =    0.004 	 CudaGrid[    7704] =    0.004 	 Diff =    0.000
# HBAcGrid[  3][  4][  4] =   -0.000 	 CudaGrid[    7704] =   -0.000 	 Diff =    0.000
# HBDoGrid[  3][  4][  4] =   -0.000 	 CudaGrid[    7704] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  4][  0][  0] =    5.022 	 CudaGrid[   10000] =    5.022 	 Diff =    0.000
# VdwAGrid[  4][  0][  0] =    0.003 	 CudaGrid[   10000] =    0.003 	 Diff =    0.000
# VdwBGrid[  4][  0][  0] =    0.227 	 CudaGrid[   10000] =    0.227 	 Diff =    0.000
# RecSGrid[  4][  0][  0] =    4.096 	 CudaGrid[   10000] =    4.096 	 Diff =    0.000
# SolvGrid[  4][  0][  0] =    0.003 	 CudaGrid[   10000] =    0.003 	 Diff =    0.000
# HBAcGrid[  4][  0][  0] =   -0.000 	 CudaGrid[   10000] =   -0.000 	 Diff =    0.000
# HBDoGrid[  4][  0][  0] =   -0.000 	 CudaGrid[   10000] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  4][  0][  1] =    5.083 	 CudaGrid[   10001] =    5.083 	 Diff =    0.000
# VdwAGrid[  4][  0][  1] =    0.002 	 CudaGrid[   10001] =    0.002 	 Diff =    0.000
# VdwBGrid[  4][  0][  1] =    0.222 	 CudaGrid[   10001] =    0.222 	 Diff =    0.000
# RecSGrid[  4][  0][  1] =    4.193 	 CudaGrid[   10001] =    4.193 	 Diff =    0.000
# SolvGrid[  4][  0][  1] =    0.003 	 CudaGrid[   10001] =    0.003 	 Diff =    0.000
# HBAcGrid[  4][  0][  1] =   -0.000 	 CudaGrid[   10001] =   -0.000 	 Diff =    0.000
# HBDoGrid[  4][  0][  1] =   -0.000 	 CudaGrid[   10001] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  4][  0][  2] =    5.123 	 CudaGrid[   10002] =    5.123 	 Diff =    0.000
# VdwAGrid[  4][  0][  2] =    0.002 	 CudaGrid[   10002] =    0.002 	 Diff =    0.000
# VdwBGrid[  4][  0][  2] =    0.218 	 CudaGrid[   10002] =    0.218 	 Diff =    0.000
# RecSGrid[  4][  0][  2] =    4.283 	 CudaGrid[   10002] =    4.283 	 Diff =    0.000
# SolvGrid[  4][  0][  2] =    0.003 	 CudaGrid[   10002] =    0.003 	 Diff =    0.000
# HBAcGrid[  4][  0][  2] =   -0.000 	 CudaGrid[   10002] =   -0.000 	 Diff =    0.000
# HBDoGrid[  4][  0][  2] =   -0.000 	 CudaGrid[   10002] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  4][  0][  3] =    5.146 	 CudaGrid[   10003] =    5.146 	 Diff =    0.000
# VdwAGrid[  4][  0][  3] =    0.002 	 CudaGrid[   10003] =    0.002 	 Diff =    0.000
# VdwBGrid[  4][  0][  3] =    0.218 	 CudaGrid[   10003] =    0.218 	 Diff =    0.000
# RecSGrid[  4][  0][  3] =    4.369 	 CudaGrid[   10003] =    4.369 	 Diff =    0.000
# SolvGrid[  4][  0][  3] =    0.003 	 CudaGrid[   10003] =    0.003 	 Diff =    0.000
# HBAcGrid[  4][  0][  3] =   -0.000 	 CudaGrid[   10003] =   -0.000 	 Diff =    0.000
# HBDoGrid[  4][  0][  3] =   -0.000 	 CudaGrid[   10003] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  4][  0][  4] =    5.163 	 CudaGrid[   10004] =    5.163 	 Diff =    0.000
# VdwAGrid[  4][  0][  4] =    0.002 	 CudaGrid[   10004] =    0.002 	 Diff =    0.000
# VdwBGrid[  4][  0][  4] =    0.221 	 CudaGrid[   10004] =    0.221 	 Diff =    0.000
# RecSGrid[  4][  0][  4] =    4.451 	 CudaGrid[   10004] =    4.451 	 Diff =    0.000
# SolvGrid[  4][  0][  4] =    0.003 	 CudaGrid[   10004] =    0.003 	 Diff =    0.000
# HBAcGrid[  4][  0][  4] =   -0.000 	 CudaGrid[   10004] =   -0.000 	 Diff =    0.000
# HBDoGrid[  4][  0][  4] =   -0.000 	 CudaGrid[   10004] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  4][  1][  0] =    5.191 	 CudaGrid[   10050] =    5.191 	 Diff =    0.000
# VdwAGrid[  4][  1][  0] =    0.005 	 CudaGrid[   10050] =    0.005 	 Diff =    0.000
# VdwBGrid[  4][  1][  0] =    0.297 	 CudaGrid[   10050] =    0.297 	 Diff =    0.000
# RecSGrid[  4][  1][  0] =    4.549 	 CudaGrid[   10050] =    4.549 	 Diff =    0.000
# SolvGrid[  4][  1][  0] =    0.004 	 CudaGrid[   10050] =    0.004 	 Diff =    0.000
# HBAcGrid[  4][  1][  0] =   -0.000 	 CudaGrid[   10050] =   -0.000 	 Diff =    0.000
# HBDoGrid[  4][  1][  0] =   -0.000 	 CudaGrid[   10050] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  4][  1][  1] =    5.290 	 CudaGrid[   10051] =    5.290 	 Diff =    0.000
# VdwAGrid[  4][  1][  1] =    0.004 	 CudaGrid[   10051] =    0.004 	 Diff =    0.000
# VdwBGrid[  4][  1][  1] =    0.285 	 CudaGrid[   10051] =    0.285 	 Diff =    0.000
# RecSGrid[  4][  1][  1] =    4.654 	 CudaGrid[   10051] =    4.654 	 Diff =    0.000
# SolvGrid[  4][  1][  1] =    0.004 	 CudaGrid[   10051] =    0.004 	 Diff =    0.000
# HBAcGrid[  4][  1][  1] =   -0.000 	 CudaGrid[   10051] =   -0.000 	 Diff =    0.000
# HBDoGrid[  4][  1][  1] =   -0.000 	 CudaGrid[   10051] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  4][  1][  2] =    5.349 	 CudaGrid[   10052] =    5.349 	 Diff =    0.000
# VdwAGrid[  4][  1][  2] =    0.004 	 CudaGrid[   10052] =    0.004 	 Diff =    0.000
# VdwBGrid[  4][  1][  2] =    0.276 	 CudaGrid[   10052] =    0.276 	 Diff =    0.000
# RecSGrid[  4][  1][  2] =    4.751 	 CudaGrid[   10052] =    4.751 	 Diff =    0.000
# SolvGrid[  4][  1][  2] =    0.004 	 CudaGrid[   10052] =    0.004 	 Diff =    0.000
# HBAcGrid[  4][  1][  2] =   -0.000 	 CudaGrid[   10052] =   -0.000 	 Diff =    0.000
# HBDoGrid[  4][  1][  2] =   -0.000 	 CudaGrid[   10052] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  4][  1][  3] =    5.377 	 CudaGrid[   10053] =    5.377 	 Diff =    0.000
# VdwAGrid[  4][  1][  3] =    0.003 	 CudaGrid[   10053] =    0.003 	 Diff =    0.000
# VdwBGrid[  4][  1][  3] =    0.272 	 CudaGrid[   10053] =    0.272 	 Diff =    0.000
# RecSGrid[  4][  1][  3] =    4.842 	 CudaGrid[   10053] =    4.842 	 Diff =    0.000
# SolvGrid[  4][  1][  3] =    0.003 	 CudaGrid[   10053] =    0.003 	 Diff =    0.000
# HBAcGrid[  4][  1][  3] =   -0.000 	 CudaGrid[   10053] =   -0.000 	 Diff =    0.000
# HBDoGrid[  4][  1][  3] =   -0.000 	 CudaGrid[   10053] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  4][  1][  4] =    5.390 	 CudaGrid[   10054] =    5.390 	 Diff =    0.000
# VdwAGrid[  4][  1][  4] =    0.003 	 CudaGrid[   10054] =    0.003 	 Diff =    0.000
# VdwBGrid[  4][  1][  4] =    0.274 	 CudaGrid[   10054] =    0.274 	 Diff =    0.000
# RecSGrid[  4][  1][  4] =    4.929 	 CudaGrid[   10054] =    4.929 	 Diff =    0.000
# SolvGrid[  4][  1][  4] =    0.003 	 CudaGrid[   10054] =    0.003 	 Diff =    0.000
# HBAcGrid[  4][  1][  4] =   -0.000 	 CudaGrid[   10054] =   -0.000 	 Diff =    0.000
# HBDoGrid[  4][  1][  4] =   -0.000 	 CudaGrid[   10054] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  4][  2][  0] =    5.359 	 CudaGrid[   10100] =    5.359 	 Diff =    0.000
# VdwAGrid[  4][  2][  0] =    0.011 	 CudaGrid[   10100] =    0.011 	 Diff =    0.000
# VdwBGrid[  4][  2][  0] =    0.394 	 CudaGrid[   10100] =    0.394 	 Diff =    0.000
# RecSGrid[  4][  2][  0] =    5.009 	 CudaGrid[   10100] =    5.009 	 Diff =    0.000
# SolvGrid[  4][  2][  0] =    0.004 	 CudaGrid[   10100] =    0.004 	 Diff =    0.000
# HBAcGrid[  4][  2][  0] =   -0.000 	 CudaGrid[   10100] =   -0.000 	 Diff =    0.000
# HBDoGrid[  4][  2][  0] =   -0.000 	 CudaGrid[   10100] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  4][  2][  1] =    5.507 	 CudaGrid[   10101] =    5.507 	 Diff =    0.000
# VdwAGrid[  4][  2][  1] =    0.009 	 CudaGrid[   10101] =    0.009 	 Diff =    0.000
# VdwBGrid[  4][  2][  1] =    0.369 	 CudaGrid[   10101] =    0.369 	 Diff =    0.000
# RecSGrid[  4][  2][  1] =    5.122 	 CudaGrid[   10101] =    5.122 	 Diff =    0.000
# SolvGrid[  4][  2][  1] =    0.004 	 CudaGrid[   10101] =    0.004 	 Diff =    0.000
# HBAcGrid[  4][  2][  1] =   -0.000 	 CudaGrid[   10101] =   -0.000 	 Diff =    0.000
# HBDoGrid[  4][  2][  1] =   -0.000 	 CudaGrid[   10101] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  4][  2][  2] =    5.594 	 CudaGrid[   10102] =    5.594 	 Diff =    0.000
# VdwAGrid[  4][  2][  2] =    0.007 	 CudaGrid[   10102] =    0.007 	 Diff =    0.000
# VdwBGrid[  4][  2][  2] =    0.350 	 CudaGrid[   10102] =    0.350 	 Diff =    0.000
# RecSGrid[  4][  2][  2] =    5.226 	 CudaGrid[   10102] =    5.226 	 Diff =    0.000
# SolvGrid[  4][  2][  2] =    0.004 	 CudaGrid[   10102] =    0.004 	 Diff =    0.000
# HBAcGrid[  4][  2][  2] =   -0.000 	 CudaGrid[   10102] =   -0.000 	 Diff =    0.000
# HBDoGrid[  4][  2][  2] =   -0.000 	 CudaGrid[   10102] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  4][  2][  3] =    5.631 	 CudaGrid[   10103] =    5.631 	 Diff =    0.000
# VdwAGrid[  4][  2][  3] =    0.005 	 CudaGrid[   10103] =    0.005 	 Diff =    0.000
# VdwBGrid[  4][  2][  3] =    0.338 	 CudaGrid[   10103] =    0.338 	 Diff =    0.000
# RecSGrid[  4][  2][  3] =    5.323 	 CudaGrid[   10103] =    5.323 	 Diff =    0.000
# SolvGrid[  4][  2][  3] =    0.004 	 CudaGrid[   10103] =    0.004 	 Diff =    0.000
# HBAcGrid[  4][  2][  3] =   -0.000 	 CudaGrid[   10103] =   -0.000 	 Diff =    0.000
# HBDoGrid[  4][  2][  3] =   -0.000 	 CudaGrid[   10103] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  4][  2][  4] =    5.641 	 CudaGrid[   10104] =    5.641 	 Diff =    0.000
# VdwAGrid[  4][  2][  4] =    0.005 	 CudaGrid[   10104] =    0.005 	 Diff =    0.000
# VdwBGrid[  4][  2][  4] =    0.337 	 CudaGrid[   10104] =    0.337 	 Diff =    0.000
# RecSGrid[  4][  2][  4] =    5.414 	 CudaGrid[   10104] =    5.414 	 Diff =    0.000
# SolvGrid[  4][  2][  4] =    0.004 	 CudaGrid[   10104] =    0.004 	 Diff =    0.000
# HBAcGrid[  4][  2][  4] =   -0.000 	 CudaGrid[   10104] =   -0.000 	 Diff =    0.000
# HBDoGrid[  4][  2][  4] =   -0.000 	 CudaGrid[   10104] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  4][  3][  0] =    5.526 	 CudaGrid[   10150] =    5.526 	 Diff =    0.000
# VdwAGrid[  4][  3][  0] =    0.025 	 CudaGrid[   10150] =    0.025 	 Diff =    0.000
# VdwBGrid[  4][  3][  0] =    0.525 	 CudaGrid[   10150] =    0.525 	 Diff =    0.000
# RecSGrid[  4][  3][  0] =    5.468 	 CudaGrid[   10150] =    5.468 	 Diff =    0.000
# SolvGrid[  4][  3][  0] =    0.004 	 CudaGrid[   10150] =    0.004 	 Diff =    0.000
# HBAcGrid[  4][  3][  0] =   -0.000 	 CudaGrid[   10150] =   -0.000 	 Diff =    0.000
# HBDoGrid[  4][  3][  0] =   -0.000 	 CudaGrid[   10150] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  4][  3][  1] =    5.735 	 CudaGrid[   10151] =    5.735 	 Diff =    0.000
# VdwAGrid[  4][  3][  1] =    0.018 	 CudaGrid[   10151] =    0.018 	 Diff =    0.000
# VdwBGrid[  4][  3][  1] =    0.480 	 CudaGrid[   10151] =    0.480 	 Diff =    0.000
# RecSGrid[  4][  3][  1] =    5.589 	 CudaGrid[   10151] =    5.589 	 Diff =    0.000
# SolvGrid[  4][  3][  1] =    0.004 	 CudaGrid[   10151] =    0.004 	 Diff =    0.000
# HBAcGrid[  4][  3][  1] =   -0.000 	 CudaGrid[   10151] =   -0.000 	 Diff =    0.000
# HBDoGrid[  4][  3][  1] =   -0.000 	 CudaGrid[   10151] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  4][  3][  2] =    5.855 	 CudaGrid[   10152] =    5.855 	 Diff =    0.000
# VdwAGrid[  4][  3][  2] =    0.013 	 CudaGrid[   10152] =    0.013 	 Diff =    0.000
# VdwBGrid[  4][  3][  2] =    0.443 	 CudaGrid[   10152] =    0.443 	 Diff =    0.000
# RecSGrid[  4][  3][  2] =    5.701 	 CudaGrid[   10152] =    5.701 	 Diff =    0.000
# SolvGrid[  4][  3][  2] =    0.004 	 CudaGrid[   10152] =    0.004 	 Diff =    0.000
# HBAcGrid[  4][  3][  2] =   -0.000 	 CudaGrid[   10152] =   -0.000 	 Diff =    0.000
# HBDoGrid[  4][  3][  2] =   -0.000 	 CudaGrid[   10152] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  4][  3][  3] =    5.904 	 CudaGrid[   10153] =    5.904 	 Diff =    0.000
# VdwAGrid[  4][  3][  3] =    0.010 	 CudaGrid[   10153] =    0.010 	 Diff =    0.000
# VdwBGrid[  4][  3][  3] =    0.419 	 CudaGrid[   10153] =    0.419 	 Diff =    0.000
# RecSGrid[  4][  3][  3] =    5.803 	 CudaGrid[   10153] =    5.803 	 Diff =    0.000
# SolvGrid[  4][  3][  3] =    0.004 	 CudaGrid[   10153] =    0.004 	 Diff =    0.000
# HBAcGrid[  4][  3][  3] =   -0.000 	 CudaGrid[   10153] =   -0.000 	 Diff =    0.000
# HBDoGrid[  4][  3][  3] =   -0.000 	 CudaGrid[   10153] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  4][  3][  4] =    5.911 	 CudaGrid[   10154] =    5.911 	 Diff =    0.000
# VdwAGrid[  4][  3][  4] =    0.007 	 CudaGrid[   10154] =    0.007 	 Diff =    0.000
# VdwBGrid[  4][  3][  4] =    0.411 	 CudaGrid[   10154] =    0.411 	 Diff =    0.000
# RecSGrid[  4][  3][  4] =    5.898 	 CudaGrid[   10154] =    5.898 	 Diff =    0.000
# SolvGrid[  4][  3][  4] =    0.004 	 CudaGrid[   10154] =    0.004 	 Diff =    0.000
# HBAcGrid[  4][  3][  4] =   -0.000 	 CudaGrid[   10154] =   -0.000 	 Diff =    0.000
# HBDoGrid[  4][  3][  4] =   -0.000 	 CudaGrid[   10154] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  4][  4][  0] =    5.709 	 CudaGrid[   10200] =    5.709 	 Diff =    0.000
# VdwAGrid[  4][  4][  0] =    0.052 	 CudaGrid[   10200] =    0.052 	 Diff =    0.000
# VdwBGrid[  4][  4][  0] =    0.698 	 CudaGrid[   10200] =    0.698 	 Diff =    0.000
# RecSGrid[  4][  4][  0] =    5.921 	 CudaGrid[   10200] =    5.921 	 Diff =    0.000
# SolvGrid[  4][  4][  0] =    0.005 	 CudaGrid[   10200] =    0.005 	 Diff =    0.000
# HBAcGrid[  4][  4][  0] =   -0.000 	 CudaGrid[   10200] =   -0.000 	 Diff =    0.000
# HBDoGrid[  4][  4][  0] =   -0.000 	 CudaGrid[   10200] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  4][  4][  1] =    5.979 	 CudaGrid[   10201] =    5.979 	 Diff =    0.000
# VdwAGrid[  4][  4][  1] =    0.037 	 CudaGrid[   10201] =    0.037 	 Diff =    0.000
# VdwBGrid[  4][  4][  1] =    0.620 	 CudaGrid[   10201] =    0.620 	 Diff =    0.000
# RecSGrid[  4][  4][  1] =    6.051 	 CudaGrid[   10201] =    6.051 	 Diff =    0.000
# SolvGrid[  4][  4][  1] =    0.005 	 CudaGrid[   10201] =    0.005 	 Diff =    0.000
# HBAcGrid[  4][  4][  1] =   -0.000 	 CudaGrid[   10201] =   -0.000 	 Diff =    0.000
# HBDoGrid[  4][  4][  1] =   -0.000 	 CudaGrid[   10201] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  4][  4][  2] =    6.131 	 CudaGrid[   10202] =    6.131 	 Diff =    0.000
# VdwAGrid[  4][  4][  2] =    0.025 	 CudaGrid[   10202] =    0.025 	 Diff =    0.000
# VdwBGrid[  4][  4][  2] =    0.558 	 CudaGrid[   10202] =    0.558 	 Diff =    0.000
# RecSGrid[  4][  4][  2] =    6.170 	 CudaGrid[   10202] =    6.170 	 Diff =    0.000
# SolvGrid[  4][  4][  2] =    0.005 	 CudaGrid[   10202] =    0.005 	 Diff =    0.000
# HBAcGrid[  4][  4][  2] =   -0.000 	 CudaGrid[   10202] =   -0.000 	 Diff =    0.000
# HBDoGrid[  4][  4][  2] =   -0.000 	 CudaGrid[   10202] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  4][  4][  3] =    6.190 	 CudaGrid[   10203] =    6.190 	 Diff =    0.000
# VdwAGrid[  4][  4][  3] =    0.017 	 CudaGrid[   10203] =    0.017 	 Diff =    0.000
# VdwBGrid[  4][  4][  3] =    0.515 	 CudaGrid[   10203] =    0.515 	 Diff =    0.000
# RecSGrid[  4][  4][  3] =    6.278 	 CudaGrid[   10203] =    6.278 	 Diff =    0.000
# SolvGrid[  4][  4][  3] =    0.005 	 CudaGrid[   10203] =    0.005 	 Diff =    0.000
# HBAcGrid[  4][  4][  3] =   -0.000 	 CudaGrid[   10203] =   -0.000 	 Diff =    0.000
# HBDoGrid[  4][  4][  3] =   -0.000 	 CudaGrid[   10203] =   -0.000 	 Diff =    0.000
#
#
# ElecGrid[  4][  4][  4] =    6.191 	 CudaGrid[   10204] =    6.191 	 Diff =    0.000
# VdwAGrid[  4][  4][  4] =    0.012 	 CudaGrid[   10204] =    0.012 	 Diff =    0.000
# VdwBGrid[  4][  4][  4] =    0.496 	 CudaGrid[   10204] =    0.496 	 Diff =    0.000
# RecSGrid[  4][  4][  4] =    6.377 	 CudaGrid[   10204] =    6.377 	 Diff =    0.000
# SolvGrid[  4][  4][  4] =    0.005 	 CudaGrid[   10204] =    0.005 	 Diff =    0.000
# HBAcGrid[  4][  4][  4] =   -0.000 	 CudaGrid[   10204] =   -0.000 	 Diff =    0.000
# HBDoGrid[  4][  4][  4] =   -0.000 	 CudaGrid[   10204] =   -0.000 	 Diff =    0.000
#
#
# Invoking finished
# Grid computation took   0.474 seconds.
# N (atoms): 2602
# dielectric_model: r
# Grids x y z: 50 50 50
#
# ****************************************************************************************************
# ****************************************************************************************************
#
# real	0m15.931s
# user	0m26.495s
# sys	0m0.210s

# %% [markdown]
# # Map 3D vector into a 1D vector
#
# Uma forma de mapear um vetor 3D em um vetor 1D seria a seguinte:
#
# Para um vetor de dimensão $D$:
#
# $ i = z + (y \times D) + (D \times D \times x) $
#
# Se estou pensando da forma correta, estamos mapeando um vetor no qual o índice z rola mais rápido e o índice x rola por último.
#
# A testar!
