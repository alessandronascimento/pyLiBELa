# %% [markdown]
# <a href="https://colab.research.google.com/github/alessandronascimento/pyLiBELa/blob/main/Colabs/pyLiBELa_SB2021_cuda_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # First things first
# ### From now on, we will be only using CUDA, a GPU computing API.
# ### In order to do that, we need to use the GPU runtime from Google Colab that can be selected following the steps in the menu:
# ### `Runtime > Change Runtime Type > T4 GPU`

# %%
#@title Downloading dependencies {display-mode: "form"}

# %%capture
! apt-get install python-dev-is-python3 zlib1g-dev libeigen3-dev libgsl-dev libnlopt-cxx-dev libgsl-dev
# !pip install ipython-autotime
# %load_ext autotime
# !pip3 install condacolab
import condacolab
condacolab.install()
# !mamba install openbabel
# Out:
# time: 50.3 s (started: 2023-09-22 19:52:51 +00:00)

# %%
#@title Installing pyLiBELa {display-mode: "form"}

# %%capture
! git clone --branch alex-works https://github.com/alessandronascimento/pyLiBELa.git
! mv pyLiBELa/src src
! rm -rf pyLiBELa
! mkdir -p obj
! rm -f Makefile*
! wget https://raw.githubusercontent.com/alessandronascimento/pyLiBELa/alex-works/Colabs/Makefile
! sed -i 's+-I/usr/include/openbabel3+-I/usr/local/include/openbabel3+g' Makefile
! make -j2
# Out:
# Cloning into 'pyLiBELa'...
# remote: Enumerating objects: 2581, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 2581 (delta 28), reused 26 (delta 21), pack-reused 2528
# Receiving objects: 100% (2581/2581), 30.80 MiB | 952.00 KiB/s, done.
# Resolving deltas: 100% (1744/1744), done.
# --2023-09-22 19:54:25--  https://raw.githubusercontent.com/alessandronascimento/pyLiBELa/alex-works/Colabs/Makefile
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6058 (5.9K) [text/plain]
# Saving to: ‘Makefile’
#
# Makefile            100%[===================>]   5.92K  --.-KB/s    in 0s
#
# 2023-09-22 19:54:25 (72.5 MB/s) - ‘Makefile’ saved [6058/6058]
#
# g++ -fPIC -O3 -I/usr/include/python3.10 -I/usr/local/include/openbabel3 -I/usr/include/eigen3 -DBUILD=0 -DHAVE_EIGEN -Wunused-value src/pyPARSER.cpp -c -o obj/pyPARSER.o
# g++ -fPIC -O3 -I/usr/include/python3.10 -I/usr/local/include/openbabel3 -I/usr/include/eigen3 -DBUILD=0 -DHAVE_EIGEN -Wunused-value src/pyMol2.cpp -c -o obj/pyMol2.o
# In file included from /usr/include/boost/smart_ptr/detail/sp_thread_sleep.hpp:22,
#                  from /usr/include/boost/smart_ptr/detail/yield_k.hpp:23,
#                  from /usr/include/boost/smart_ptr/detail/spinlock_gcc_atomic.hpp:14,
#                  from /usr/include/boost/smart_ptr/detail/spinlock.hpp:42,
#                  from /usr/include/boost/smart_ptr/detail/spinlock_pool.hpp:25,
#                  from /usr/include/boost/smart_ptr/shared_ptr.hpp:29,
#                  from /usr/include/boost/shared_ptr.hpp:17,
#                  from /usr/include/boost/python/converter/shared_ptr_to_python.hpp:12,
#                  from /usr/include/boost/python/converter/arg_to_python.hpp:15,
#                  from /usr/include/boost/python/call.hpp:15,
#                  from /usr/include/boost/python/object_core.hpp:14,
#                  from /usr/include/boost/python/args.hpp:22,
#                  from /usr/include/boost/python.hpp:11,
#                  from src/pyPARSER.cpp:591:
# /usr/include/boost/bind.hpp:36:1: note: ‘#pragma message: The practice of declaring the Bind placeholders (_1, _2, ...) in the global namespace is deprecated. Please use <boost/bind/bind.hpp> + using namespace boost::placeholders, or define BOOST_BIND_GLOBAL_PLACEHOLDERS to retain the current behavior.’
#    36 | BOOST_PRAGMA_MESSAGE(
#       | ^~~~~~~~~~~~~~~~~~~~
# /usr/include/boost/detail/iterator.hpp:13:1: note: ‘#pragma message: This header is deprecated. Use <iterator> instead.’
#    13 | BOOST_HEADER_DEPRECATED("<iterator>")
#       | ^~~~~~~~~~~~~~~~~~~~~~~
# src/pyMol2.cpp: In member function ‘bool Mol2::parse_smiles(PARSER*, std::string, std::string)’:
# src/pyMol2.cpp:110:28: warning: format ‘%s’ expects argument of type ‘char*’, but argument 2 has type ‘std::string’ {aka ‘std::__cxx11::basic_string<char>’} [-Wformat=]
#   110 |                     printf("bret set to false because of atom %s\n", sybyl_atom);
#       |                            ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# In file included from /usr/include/boost/smart_ptr/detail/sp_thread_sleep.hpp:22,
#                  from /usr/include/boost/smart_ptr/detail/yield_k.hpp:23,
#                  from /usr/include/boost/smart_ptr/detail/spinlock_gcc_atomic.hpp:14,
#                  from /usr/include/boost/smart_ptr/detail/spinlock.hpp:42,
#                  from /usr/include/boost/smart_ptr/detail/spinlock_pool.hpp:25,
#                  from /usr/include/boost/smart_ptr/shared_ptr.hpp:29,
#                  from /usr/include/boost/shared_ptr.hpp:17,
#                  from /usr/include/boost/python/converter/shared_ptr_to_python.hpp:12,
#                  from /usr/include/boost/python/converter/arg_to_python.hpp:15,
#                  from /usr/include/boost/python/call.hpp:15,
#                  from /usr/include/boost/python/object_core.hpp:14,
#                  from /usr/include/boost/python/args.hpp:22,
#                  from /usr/include/boost/python.hpp:11,
#                  from src/pyMol2.cpp:2282:
# /usr/include/boost/bind.hpp: At global scope:
# /usr/include/boost/bind.hpp:36:1: note: ‘#pragma message: The practice of declaring the Bind placeholders (_1, _2, ...) in the global namespace is deprecated. Please use <boost/bind/bind.hpp> + using namespace boost::placeholders, or define BOOST_BIND_GLOBAL_PLACEHOLDERS to retain the current behavior.’
#    36 | BOOST_PRAGMA_MESSAGE(
#       | ^~~~~~~~~~~~~~~~~~~~
# /usr/include/boost/detail/iterator.hpp:13:1: note: ‘#pragma message: This header is deprecated. Use <iterator> instead.’
#    13 | BOOST_HEADER_DEPRECATED("<iterator>")
#       | ^~~~~~~~~~~~~~~~~~~~~~~
#
# g++ -fPIC -O3 -I/usr/include/python3.10 -I/usr/local/include/openbabel3 -I/usr/include/eigen3 -DBUILD=0 -DHAVE_EIGEN -Wunused-value src/pyWRITER.cpp -c -o obj/pyWRITER.o
# src/pyMol2.cpp: In member function ‘bool Mol2::parse_mol2file(PARSER*, std::string)’:
# src/pyMol2.cpp:221:18: warning: ignoring return value of ‘char* fgets(char*, int, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#   221 |             fgets(str, 80, mol2file);
#       |             ~~~~~^~~~~~~~~~~~~~~~~~~
# src/pyMol2.cpp:224:14: warning: ignoring return value of ‘char* fgets(char*, int, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#   224 |         fgets(str, 80, mol2file);
#       |         ~~~~~^~~~~~~~~~~~~~~~~~~
# src/pyMol2.cpp:227:15: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#   227 |         fscanf(mol2file, "%d %d %d %d %d", &this->N, &this->Nbonds, &this->Nres, &tint, &tint);
#       |         ~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyMol2.cpp:231:18: warning: ignoring return value of ‘char* fgets(char*, int, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#   231 |             fgets(str, 80, mol2file);
#       |             ~~~~~^~~~~~~~~~~~~~~~~~~
# src/pyMol2.cpp:236:19: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#   236 |             fscanf(mol2file, "%d %s %f %f %f %s %d %s %f\n", &tint, str, &tx, &ty, &tz, tatomtype, &tres, resname, &tcharge);
#       |             ~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyMol2.cpp:291:18: warning: ignoring return value of ‘char* fgets(char*, int, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#   291 |             fgets(str, 80, mol2file);
#       |             ~~~~~^~~~~~~~~~~~~~~~~~~
# src/pyMol2.cpp:298:19: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#   298 |             fscanf(mol2file, "%d%s%s%s\n", &tint, s1, s2, s3);
#       |             ~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyMol2.cpp: In member function ‘void Mol2::initialize_gaff()’:
# src/pyMol2.cpp:483:18: warning: ignoring return value of ‘char* fgets(char*, int, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#   483 |             fgets(str, 80, gaff_file);
#       |             ~~~~~^~~~~~~~~~~~~~~~~~~~
# In file included from /usr/include/boost/smart_ptr/detail/sp_thread_sleep.hpp:22,
#                  from /usr/include/boost/smart_ptr/detail/yield_k.hpp:23,
#                  from /usr/include/boost/smart_ptr/detail/spinlock_gcc_atomic.hpp:14,
#                  from /usr/include/boost/smart_ptr/detail/spinlock.hpp:42,
#                  from /usr/include/boost/smart_ptr/detail/spinlock_pool.hpp:25,
#                  from /usr/include/boost/smart_ptr/shared_ptr.hpp:29,
#                  from /usr/include/boost/shared_ptr.hpp:17,
#                  from /usr/include/boost/python/converter/shared_ptr_to_python.hpp:12,
#                  from /usr/include/boost/python/converter/arg_to_python.hpp:15,
#                  from /usr/include/boost/python/call.hpp:15,
#                  from /usr/include/boost/python/object_core.hpp:14,
#                  from /usr/include/boost/python/args.hpp:22,
#                  from /usr/include/boost/python.hpp:11,
#                  from src/pyWRITER.cpp:713:
# /usr/include/boost/bind.hpp:36:1: note: ‘#pragma message: The practice of declaring the Bind placeholders (_1, _2, ...) in the global namespace is deprecated. Please use <boost/bind/bind.hpp> + using namespace boost::placeholders, or define BOOST_BIND_GLOBAL_PLACEHOLDERS to retain the current behavior.’
#    36 | BOOST_PRAGMA_MESSAGE(
#       | ^~~~~~~~~~~~~~~~~~~~
# /usr/include/boost/detail/iterator.hpp:13:1: note: ‘#pragma message: This header is deprecated. Use <iterator> instead.’
#    13 | BOOST_HEADER_DEPRECATED("<iterator>")
#       | ^~~~~~~~~~~~~~~~~~~~~~~
#
# g++ -fPIC -O3 -I/usr/include/python3.10 -I/usr/local/include/openbabel3 -I/usr/include/eigen3 -DBUILD=0 -DHAVE_EIGEN -Wunused-value src/pyGrid.cpp -c -o obj/pyGrid.o
#
# Building CUDA objects
# nvcc --compiler-options '-fPIC' -c src/cudaGrid.cu -o obj/cudaGrid.o -DBUILD=0 -DHAVE_EIGEN -I/usr/local/include/openbabel3 -I/usr/include/eigen3 -I/usr/include/python3.10
# In file included from /usr/include/boost/smart_ptr/detail/sp_thread_sleep.hpp:22,
#                  from /usr/include/boost/smart_ptr/detail/yield_k.hpp:23,
#                  from /usr/include/boost/smart_ptr/detail/spinlock_gcc_atomic.hpp:14,
#                  from /usr/include/boost/smart_ptr/detail/spinlock.hpp:42,
#                  from /usr/include/boost/smart_ptr/detail/spinlock_pool.hpp:25,
#                  from /usr/include/boost/smart_ptr/shared_ptr.hpp:29,
#                  from /usr/include/boost/shared_ptr.hpp:17,
#                  from /usr/include/boost/python/converter/shared_ptr_to_python.hpp:12,
#                  from /usr/include/boost/python/converter/arg_to_python.hpp:15,
#                  from /usr/include/boost/python/call.hpp:15,
#                  from /usr/include/boost/python/object_core.hpp:14,
#                  from /usr/include/boost/python/args.hpp:22,
#                  from /usr/include/boost/python.hpp:11,
#                  from src/pyGrid.cpp:1673:
# /usr/include/boost/bind.hpp:36:1: note: ‘#pragma message: The practice of declaring the Bind placeholders (_1, _2, ...) in the global namespace is deprecated. Please use <boost/bind/bind.hpp> + using namespace boost::placeholders, or define BOOST_BIND_GLOBAL_PLACEHOLDERS to retain the current behavior.’
#    36 | BOOST_PRAGMA_MESSAGE(
#       | ^~~~~~~~~~~~~~~~~~~~
# /usr/include/boost/detail/iterator.hpp:13:1: note: ‘#pragma message: This header is deprecated. Use <iterator> instead.’
#    13 | BOOST_HEADER_DEPRECATED("<iterator>")
#       | ^~~~~~~~~~~~~~~~~~~~~~~
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(77): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(79): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(81): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(83): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(85): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(86): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(87): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(88): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(89): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(90): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(91): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(92): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(93): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(94): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(95): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# src/pyGrid.cpp: In member function ‘void Grid::load_Ambergrids_from_file()’:
# src/pyGrid.cpp:717:18: warning: ignoring return value of ‘char* fgets(char*, int, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#   717 |             fgets(str, 80, pbsa_map);
#       |             ~~~~~^~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:722:15: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#   722 |         fscanf(pbsa_map, "%d %d %d", &this->npointsx, &this->npointsy, &this->npointsz);
#       |         ~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:749:27: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#   749 |                     fscanf(pbsa_map, "%f", &phi);
#       |                     ~~~~~~^~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp: In member function ‘void Grid::load_Delphi_Grid_from_file()’:
# src/pyGrid.cpp:1030:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1030 |     fread(&tmpi, sizeof(int), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1039:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1039 |     fread(&tmpi, sizeof(int), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1040:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1040 |     fread(&tmpi, sizeof(int), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1042:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1042 |     fread(&ivary, sizeof(int), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1043:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1043 |     fread(&nbyte, sizeof(int), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1044:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1044 |     fread(&inddat, sizeof(int), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1046:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1046 |     fread(&extent, sizeof(double), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1047:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1047 |     fread(&extent, sizeof(double), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1048:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1048 |     fread(&extent, sizeof(double), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1050:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1050 |     fread(&xang, sizeof(double), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1051:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1051 |     fread(&yang, sizeof(double), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1052:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1052 |     fread(&zang, sizeof(double), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1054:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1054 |     fread(&xstart, sizeof(double), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1055:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1055 |     fread(&xend, sizeof(double), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1057:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1057 |     fread(&ystart, sizeof(double), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1058:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1058 |     fread(&yend, sizeof(double), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1060:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1060 |     fread(&zstart, sizeof(double), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1061:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1061 |     fread(&zend, sizeof(double), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1063:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1063 |     fread(&intx, sizeof(int), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1064:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1064 |     fread(&inty, sizeof(int), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1065:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1065 |     fread(&intz, sizeof(int), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1107:22: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1107 |                 fread(&phi, sizeof(double), 1, phimap);
#       |                 ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp: In member function ‘void Grid::load_phimap_from_file(int)’:
# src/pyGrid.cpp:1142:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1142 |     fread(&tmpi, sizeof(int), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1151:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1151 |     fread(&tmpi, sizeof(int), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1152:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1152 |     fread(&tmpi, sizeof(int), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1168:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1168 |     fread(&tmpi, sizeof(int), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1169:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1169 |     fread(&tmpi, sizeof(int), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1191:22: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1191 |                 fread(&kt_phi, sizeof(float), 1, phimap);
#       |                 ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1197:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1197 |     fread(&tmpi, sizeof(int), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1198:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1198 |     fread(&tmpi, sizeof(int), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1207:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1207 |     fread(&tmpi, sizeof(int), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1208:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1208 |     fread(&tmpi, sizeof(int), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1215:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1215 |     fread(&scale, sizeof(float), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1216:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1216 |     fread(&oldmid_x, sizeof(float), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1217:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1217 |     fread(&oldmid_y, sizeof(float), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1218:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1218 |     fread(&oldmid_z, sizeof(float), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1219:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1219 |     fread(&igrid, sizeof(int), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp: In member function ‘void Grid::load_delphi_cube()’:
# src/pyGrid.cpp:1263:11: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1263 |     fscanf(phimap, "%f %d %f %f %f", &scale, &igrid, &centerx, &centery, &centerz);
#       |     ~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1277:10: warning: ignoring return value of ‘char* fgets(char*, int, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1277 |     fgets(str, 80, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1278:10: warning: ignoring return value of ‘char* fgets(char*, int, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1278 |     fgets(str, 80, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1279:11: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1279 |     fscanf(phimap, "%d %f %f %f", &itmp, &dtmp, &dtmp, &dtmp);
#       |     ~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1280:11: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1280 |     fscanf(phimap, "%d %f %f %f", &itmp, &dtmp, &dtmp, &dtmp);
#       |     ~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1281:11: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1281 |     fscanf(phimap, "%d %f %f %f", &itmp, &dtmp, &dtmp, &dtmp);
#       |     ~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1282:11: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1282 |     fscanf(phimap, "%d %f %f %f", &itmp, &dtmp, &dtmp, &dtmp);
#       |     ~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1283:11: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1283 |     fscanf(phimap, "%d %f %f %f %f", &itmp, &dtmp, &dtmp, &dtmp, &dtmp);
#       |     ~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1300:23: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#  1300 |                 fscanf(phimap, "%f", &phi);
#       |                 ~~~~~~^~~~~~~~~~~~~~~~~~~~
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(1535): warning #20013-D: calling a constexpr __host__ function("real") from a __host__ __device__ function("abs") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(1535): warning #20013-D: calling a constexpr __host__ function("imag") from a __host__ __device__ function("abs") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(1535): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(1535): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(1540): warning #20013-D: calling a constexpr __host__ function("real") from a __host__ __device__ function("abs") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(1540): warning #20013-D: calling a constexpr __host__ function("imag") from a __host__ __device__ function("abs") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(1540): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(1540): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(1564): warning #20013-D: calling a constexpr __host__ function("real") from a __host__ __device__ function("exp") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(1565): warning #20013-D: calling a constexpr __host__ function("imag") from a __host__ __device__ function("exp") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(1566): warning #20013-D: calling a constexpr __host__ function("imag") from a __host__ __device__ function("exp") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(1564): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(1565): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(1566): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(1567): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(1572): warning #20013-D: calling a constexpr __host__ function("real") from a __host__ __device__ function("exp") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(1573): warning #20013-D: calling a constexpr __host__ function("imag") from a __host__ __device__ function("exp") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(1574): warning #20013-D: calling a constexpr __host__ function("imag") from a __host__ __device__ function("exp") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(1572): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(1573): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(1574): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(1575): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(234): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(234): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(234): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(234): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(234): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(234): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(234): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(234): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(234): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(234): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(234): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(235): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(235): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(235): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(235): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(235): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(235): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(235): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(235): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(235): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(235): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(235): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#
# /usr/include/eigen3/Eigen/src/Core/DenseStorage.h(223): warning #20012-D: __host__ annotation is ignored on a function("DenseStorage") that is explicitly defaulted on its first declaration
#
# /usr/include/eigen3/Eigen/src/Core/DenseStorage.h(223): warning #20012-D: __device__ annotation is ignored on a function("DenseStorage") that is explicitly defaulted on its first declaration
#
# /usr/include/eigen3/Eigen/src/Core/DenseStorage.h(233): warning #20012-D: __host__ annotation is ignored on a function("operator=") that is explicitly defaulted on its first declaration
#
# /usr/include/eigen3/Eigen/src/Core/DenseStorage.h(233): warning #20012-D: __device__ annotation is ignored on a function("operator=") that is explicitly defaulted on its first declaration
#
# /usr/include/eigen3/Eigen/src/Core/DenseStorage.h(248): warning #20012-D: __host__ annotation is ignored on a function("DenseStorage") that is explicitly defaulted on its first declaration
#
# /usr/include/eigen3/Eigen/src/Core/DenseStorage.h(248): warning #20012-D: __device__ annotation is ignored on a function("DenseStorage") that is explicitly defaulted on its first declaration
#
# /usr/include/eigen3/Eigen/src/Core/DenseStorage.h(249): warning #20012-D: __host__ annotation is ignored on a function("operator=") that is explicitly defaulted on its first declaration
#
# /usr/include/eigen3/Eigen/src/Core/DenseStorage.h(249): warning #20012-D: __device__ annotation is ignored on a function("operator=") that is explicitly defaulted on its first declaration
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(110): warning #20013-D: calling a constexpr __host__ function("real") from a __host__ __device__ function("run") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#           detected during:
#             instantiation of "T Eigen::internal::real_impl<std::complex<T>>::run(const std::complex<T> &) [with T=float]"
# (1232): here
#             instantiation of "Eigen::internal::real_retval<Eigen::internal::global_math_functions_filtering_base<Scalar, void>::type>::type Eigen::numext::real(const Scalar &) [with Scalar=std::complex<float>]"
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(234): here
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(110): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#           detected during:
#             instantiation of "T Eigen::internal::real_impl<std::complex<T>>::run(const std::complex<T> &) [with T=float]"
# (1232): here
#             instantiation of "Eigen::internal::real_retval<Eigen::internal::global_math_functions_filtering_base<Scalar, void>::type>::type Eigen::numext::real(const Scalar &) [with Scalar=std::complex<float>]"
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(234): here
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(158): warning #20013-D: calling a constexpr __host__ function("imag") from a __host__ __device__ function("run") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#           detected during:
#             instantiation of "T Eigen::internal::imag_impl<std::complex<T>>::run(const std::complex<T> &) [with T=float]"
# (1253): here
#             instantiation of "Eigen::internal::imag_retval<Eigen::internal::global_math_functions_filtering_base<Scalar, void>::type>::type Eigen::numext::imag(const Scalar &) [with Scalar=std::complex<float>]"
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(234): here
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(158): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#           detected during:
#             instantiation of "T Eigen::internal::imag_impl<std::complex<T>>::run(const std::complex<T> &) [with T=float]"
# (1253): here
#             instantiation of "Eigen::internal::imag_retval<Eigen::internal::global_math_functions_filtering_base<Scalar, void>::type>::type Eigen::numext::imag(const Scalar &) [with Scalar=std::complex<float>]"
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(234): here
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(58): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#           detected during instantiation of "std::complex<T> Eigen::complex_operator_detail::complex_multiply(const std::complex<T> &, const std::complex<T> &) [with T=float]"
# (234): here
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(71): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#           detected during:
#             instantiation of "std::complex<T> Eigen::complex_operator_detail::complex_divide_fast(const std::complex<T> &, const std::complex<T> &) [with T=float]"
# (96): here
#             instantiation of "std::complex<T> Eigen::complex_operator_detail::complex_divide(const std::complex<T> &, const std::complex<T> &) [with T=float]"
# (234): here
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(110): warning #20013-D: calling a constexpr __host__ function("real") from a __host__ __device__ function("run") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#           detected during:
#             instantiation of "T Eigen::internal::real_impl<std::complex<T>>::run(const std::complex<T> &) [with T=double]"
# (1232): here
#             instantiation of "Eigen::internal::real_retval<Eigen::internal::global_math_functions_filtering_base<Scalar, void>::type>::type Eigen::numext::real(const Scalar &) [with Scalar=std::complex<double>]"
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(235): here
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(110): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#           detected during:
#             instantiation of "T Eigen::internal::real_impl<std::complex<T>>::run(const std::complex<T> &) [with T=double]"
# (1232): here
#             instantiation of "Eigen::internal::real_retval<Eigen::internal::global_math_functions_filtering_base<Scalar, void>::type>::type Eigen::numext::real(const Scalar &) [with Scalar=std::complex<double>]"
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(235): here
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(158): warning #20013-D: calling a constexpr __host__ function("imag") from a __host__ __device__ function("run") is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#           detected during:
#             instantiation of "T Eigen::internal::imag_impl<std::complex<T>>::run(const std::complex<T> &) [with T=double]"
# (1253): here
#             instantiation of "Eigen::internal::imag_retval<Eigen::internal::global_math_functions_filtering_base<Scalar, void>::type>::type Eigen::numext::imag(const Scalar &) [with Scalar=std::complex<double>]"
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(235): here
#
# /usr/include/eigen3/Eigen/src/Core/MathFunctions.h(158): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#           detected during:
#             instantiation of "T Eigen::internal::imag_impl<std::complex<T>>::run(const std::complex<T> &) [with T=double]"
# (1253): here
#             instantiation of "Eigen::internal::imag_retval<Eigen::internal::global_math_functions_filtering_base<Scalar, void>::type>::type Eigen::numext::imag(const Scalar &) [with Scalar=std::complex<double>]"
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(235): here
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(58): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#           detected during instantiation of "std::complex<T> Eigen::complex_operator_detail::complex_multiply(const std::complex<T> &, const std::complex<T> &) [with T=double]"
# (235): here
#
# /usr/include/eigen3/Eigen/src/Core/arch/CUDA/Complex.h(71): warning #20015-D: calling a constexpr __host__ function from a __host__ __device__ function is not allowed. The experimental flag '--expt-relaxed-constexpr' can be used to allow this.
#           detected during:
#             instantiation of "std::complex<T> Eigen::complex_operator_detail::complex_divide_fast(const std::complex<T> &, const std::complex<T> &) [with T=double]"
# (96): here
#             instantiation of "std::complex<T> Eigen::complex_operator_detail::complex_divide(const std::complex<T> &, const std::complex<T> &) [with T=double]"
# (235): here
#
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(77): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(79): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(81): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(83): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# /usr/include/eigen3/Eigen/src/Core/util/DisableStupidWarnings.h(85): warning #20236-D: pragma "diag_suppress" is deprecated, use "nv_diag_suppress" instead
#
# ...
#    13 | BOOST_HEADER_DEPRECATED("<iterator>")
#       | ^~~~~~~~~~~~~~~~~~~~~~~
# In file included from /usr/include/boost/smart_ptr/detail/sp_thread_sleep.hpp:22,
#                  from /usr/include/boost/smart_ptr/detail/yield_k.hpp:23,
#                  from /usr/include/boost/smart_ptr/detail/spinlock_gcc_atomic.hpp:14,
#                  from /usr/include/boost/smart_ptr/detail/spinlock.hpp:42,
#                  from /usr/include/boost/smart_ptr/detail/spinlock_pool.hpp:25,
#                  from /usr/include/boost/smart_ptr/shared_ptr.hpp:29,
#                  from /usr/include/boost/shared_ptr.hpp:17,
#                  from /usr/include/boost/python/converter/shared_ptr_to_python.hpp:12,
#                  from /usr/include/boost/python/converter/arg_to_python.hpp:15,
#                  from /usr/include/boost/python/call.hpp:15,
#                  from /usr/include/boost/python/object_core.hpp:14,
#                  from /usr/include/boost/python/args.hpp:22,
#                  from /usr/include/boost/python.hpp:11,
#                  from src/pyGaussian.cpp:239:
# /usr/include/boost/bind.hpp:36:1: note: ‘#pragma message: The practice of declaring the Bind placeholders (_1, _2, ...) in the global namespace is deprecated. Please use <boost/bind/bind.hpp> + using namespace boost::placeholders, or define BOOST_BIND_GLOBAL_PLACEHOLDERS to retain the current behavior.’
#    36 | BOOST_PRAGMA_MESSAGE(
#       | ^~~~~~~~~~~~~~~~~~~~
# /usr/include/boost/detail/iterator.hpp:13:1: note: ‘#pragma message: This header is deprecated. Use <iterator> instead.’
#    13 | BOOST_HEADER_DEPRECATED("<iterator>")
#       | ^~~~~~~~~~~~~~~~~~~~~~~
#
# g++ -fPIC -O3 -I/usr/include/python3.10 -I/usr/local/include/openbabel3 -I/usr/include/eigen3 -DBUILD=0 -DHAVE_EIGEN -Wunused-value src/pyMcEntropy.cpp -c -o obj/pyMcEntropy.o
#
# g++ -fPIC -O3 -I/usr/include/python3.10 -I/usr/local/include/openbabel3 -I/usr/include/eigen3 -DBUILD=0 -DHAVE_EIGEN -Wunused-value src/pySA.cpp -c -o obj/pySA.o
# In file included from /usr/include/boost/smart_ptr/detail/sp_thread_sleep.hpp:22,
#                  from /usr/include/boost/smart_ptr/detail/yield_k.hpp:23,
#                  from /usr/include/boost/smart_ptr/detail/spinlock_gcc_atomic.hpp:14,
#                  from /usr/include/boost/smart_ptr/detail/spinlock.hpp:42,
#                  from /usr/include/boost/smart_ptr/detail/spinlock_pool.hpp:25,
#                  from /usr/include/boost/smart_ptr/shared_ptr.hpp:29,
#                  from /usr/include/boost/shared_ptr.hpp:17,
#                  from /usr/include/boost/python/converter/shared_ptr_to_python.hpp:12,
#                  from /usr/include/boost/python/converter/arg_to_python.hpp:15,
#                  from /usr/include/boost/python/call.hpp:15,
#                  from /usr/include/boost/python/object_core.hpp:14,
#                  from /usr/include/boost/python/args.hpp:22,
#                  from /usr/include/boost/python.hpp:11,
#                  from src/pyMcEntropy.cpp:242:
# /usr/include/boost/bind.hpp:36:1: note: ‘#pragma message: The practice of declaring the Bind placeholders (_1, _2, ...) in the global namespace is deprecated. Please use <boost/bind/bind.hpp> + using namespace boost::placeholders, or define BOOST_BIND_GLOBAL_PLACEHOLDERS to retain the current behavior.’
#    36 | BOOST_PRAGMA_MESSAGE(
#       | ^~~~~~~~~~~~~~~~~~~~
# /usr/include/boost/detail/iterator.hpp:13:1: note: ‘#pragma message: This header is deprecated. Use <iterator> instead.’
#    13 | BOOST_HEADER_DEPRECATED("<iterator>")
#       | ^~~~~~~~~~~~~~~~~~~~~~~
# In file included from /usr/include/boost/smart_ptr/detail/sp_thread_sleep.hpp:22,
#                  from /usr/include/boost/smart_ptr/detail/yield_k.hpp:23,
#                  from /usr/include/boost/smart_ptr/detail/spinlock_gcc_atomic.hpp:14,
#                  from /usr/include/boost/smart_ptr/detail/spinlock.hpp:42,
#                  from /usr/include/boost/smart_ptr/detail/spinlock_pool.hpp:25,
#                  from /usr/include/boost/smart_ptr/shared_ptr.hpp:29,
#                  from /usr/include/boost/shared_ptr.hpp:17,
#                  from /usr/include/boost/python/converter/shared_ptr_to_python.hpp:12,
#                  from /usr/include/boost/python/converter/arg_to_python.hpp:15,
#                  from /usr/include/boost/python/call.hpp:15,
#                  from /usr/include/boost/python/object_core.hpp:14,
#                  from /usr/include/boost/python/args.hpp:22,
#                  from /usr/include/boost/python.hpp:11,
#                  from src/pySA.cpp:171:
# /usr/include/boost/bind.hpp:36:1: note: ‘#pragma message: The practice of declaring the Bind placeholders (_1, _2, ...) in the global namespace is deprecated. Please use <boost/bind/bind.hpp> + using namespace boost::placeholders, or define BOOST_BIND_GLOBAL_PLACEHOLDERS to retain the current behavior.’
#    36 | BOOST_PRAGMA_MESSAGE(
#       | ^~~~~~~~~~~~~~~~~~~~
# /usr/include/boost/detail/iterator.hpp:13:1: note: ‘#pragma message: This header is deprecated. Use <iterator> instead.’
#    13 | BOOST_HEADER_DEPRECATED("<iterator>")
#       | ^~~~~~~~~~~~~~~~~~~~~~~
#
# g++ -fPIC -O3 -I/usr/include/python3.10 -I/usr/local/include/openbabel3 -I/usr/include/eigen3 -DBUILD=0 -DHAVE_EIGEN -Wunused-value src/pyMC.cpp -c -o obj/pyMC.o
#
# g++ -fPIC -O3 -I/usr/include/python3.10 -I/usr/local/include/openbabel3 -I/usr/include/eigen3 -DBUILD=0 -DHAVE_EIGEN -Wunused-value src/pyOptimizer.cpp -c -o obj/pyOptimizer.o
# In file included from /usr/include/boost/smart_ptr/detail/sp_thread_sleep.hpp:22,
#                  from /usr/include/boost/smart_ptr/detail/yield_k.hpp:23,
#                  from /usr/include/boost/smart_ptr/detail/spinlock_gcc_atomic.hpp:14,
#                  from /usr/include/boost/smart_ptr/detail/spinlock.hpp:42,
#                  from /usr/include/boost/smart_ptr/detail/spinlock_pool.hpp:25,
#                  from /usr/include/boost/smart_ptr/shared_ptr.hpp:29,
#                  from /usr/include/boost/shared_ptr.hpp:17,
#                  from /usr/include/boost/python/converter/shared_ptr_to_python.hpp:12,
#                  from /usr/include/boost/python/converter/arg_to_python.hpp:15,
#                  from /usr/include/boost/python/call.hpp:15,
#                  from /usr/include/boost/python/object_core.hpp:14,
#                  from /usr/include/boost/python/args.hpp:22,
#                  from /usr/include/boost/python.hpp:11,
#                  from src/pyMC.cpp:1337:
# /usr/include/boost/bind.hpp:36:1: note: ‘#pragma message: The practice of declaring the Bind placeholders (_1, _2, ...) in the global namespace is deprecated. Please use <boost/bind/bind.hpp> + using namespace boost::placeholders, or define BOOST_BIND_GLOBAL_PLACEHOLDERS to retain the current behavior.’
#    36 | BOOST_PRAGMA_MESSAGE(
#       | ^~~~~~~~~~~~~~~~~~~~
# /usr/include/boost/detail/iterator.hpp:13:1: note: ‘#pragma message: This header is deprecated. Use <iterator> instead.’
#    13 | BOOST_HEADER_DEPRECATED("<iterator>")
#       | ^~~~~~~~~~~~~~~~~~~~~~~
# In file included from /usr/include/boost/smart_ptr/detail/sp_thread_sleep.hpp:22,
#                  from /usr/include/boost/smart_ptr/detail/yield_k.hpp:23,
#                  from /usr/include/boost/smart_ptr/detail/spinlock_gcc_atomic.hpp:14,
#                  from /usr/include/boost/smart_ptr/detail/spinlock.hpp:42,
#                  from /usr/include/boost/smart_ptr/detail/spinlock_pool.hpp:25,
#                  from /usr/include/boost/smart_ptr/shared_ptr.hpp:29,
#                  from /usr/include/boost/shared_ptr.hpp:17,
#                  from /usr/include/boost/python/converter/shared_ptr_to_python.hpp:12,
#                  from /usr/include/boost/python/converter/arg_to_python.hpp:15,
#                  from /usr/include/boost/python/call.hpp:15,
#                  from /usr/include/boost/python/object_core.hpp:14,
#                  from /usr/include/boost/python/args.hpp:22,
#                  from /usr/include/boost/python.hpp:11,
#                  from src/pyOptimizer.cpp:1528:
# /usr/include/boost/bind.hpp:36:1: note: ‘#pragma message: The practice of declaring the Bind placeholders (_1, _2, ...) in the global namespace is deprecated. Please use <boost/bind/bind.hpp> + using namespace boost::placeholders, or define BOOST_BIND_GLOBAL_PLACEHOLDERS to retain the current behavior.’
#    36 | BOOST_PRAGMA_MESSAGE(
#       | ^~~~~~~~~~~~~~~~~~~~
# /usr/include/boost/detail/iterator.hpp:13:1: note: ‘#pragma message: This header is deprecated. Use <iterator> instead.’
#    13 | BOOST_HEADER_DEPRECATED("<iterator>")
#       | ^~~~~~~~~~~~~~~~~~~~~~~
#
# g++ -fPIC -O3 -I/usr/include/python3.10 -I/usr/local/include/openbabel3 -I/usr/include/eigen3 -DBUILD=0 -DHAVE_EIGEN -Wunused-value src/pyDocker.cpp -c -o obj/pyDocker.o
#
# g++ -fPIC -O3 -I/usr/include/python3.10 -I/usr/local/include/openbabel3 -I/usr/include/eigen3 -DBUILD=0 -DHAVE_EIGEN -Wunused-value src/pyFullSearch.cpp -c -o obj/pyFullSearch.o
# In file included from /usr/include/boost/smart_ptr/detail/sp_thread_sleep.hpp:22,
#                  from /usr/include/boost/smart_ptr/detail/yield_k.hpp:23,
#                  from /usr/include/boost/smart_ptr/detail/spinlock_gcc_atomic.hpp:14,
#                  from /usr/include/boost/smart_ptr/detail/spinlock.hpp:42,
#                  from /usr/include/boost/smart_ptr/detail/spinlock_pool.hpp:25,
#                  from /usr/include/boost/smart_ptr/shared_ptr.hpp:29,
#                  from /usr/include/boost/shared_ptr.hpp:17,
#                  from /usr/include/boost/python/converter/shared_ptr_to_python.hpp:12,
#                  from /usr/include/boost/python/converter/arg_to_python.hpp:15,
#                  from /usr/include/boost/python/call.hpp:15,
#                  from /usr/include/boost/python/object_core.hpp:14,
#                  from /usr/include/boost/python/args.hpp:22,
#                  from /usr/include/boost/python.hpp:11,
#                  from src/pyDocker.cpp:1608:
# /usr/include/boost/bind.hpp:36:1: note: ‘#pragma message: The practice of declaring the Bind placeholders (_1, _2, ...) in the global namespace is deprecated. Please use <boost/bind/bind.hpp> + using namespace boost::placeholders, or define BOOST_BIND_GLOBAL_PLACEHOLDERS to retain the current behavior.’
#    36 | BOOST_PRAGMA_MESSAGE(
#       | ^~~~~~~~~~~~~~~~~~~~
# /usr/include/boost/detail/iterator.hpp:13:1: note: ‘#pragma message: This header is deprecated. Use <iterator> instead.’
#    13 | BOOST_HEADER_DEPRECATED("<iterator>")
#       | ^~~~~~~~~~~~~~~~~~~~~~~
# In file included from /usr/include/boost/smart_ptr/detail/sp_thread_sleep.hpp:22,
#                  from /usr/include/boost/smart_ptr/detail/yield_k.hpp:23,
#                  from /usr/include/boost/smart_ptr/detail/spinlock_gcc_atomic.hpp:14,
#                  from /usr/include/boost/smart_ptr/detail/spinlock.hpp:42,
#                  from /usr/include/boost/smart_ptr/detail/spinlock_pool.hpp:25,
#                  from /usr/include/boost/smart_ptr/shared_ptr.hpp:29,
#                  from /usr/include/boost/shared_ptr.hpp:17,
#                  from /usr/include/boost/python/converter/shared_ptr_to_python.hpp:12,
#                  from /usr/include/boost/python/converter/arg_to_python.hpp:15,
#                  from /usr/include/boost/python/call.hpp:15,
#                  from /usr/include/boost/python/object_core.hpp:14,
#                  from /usr/include/boost/python/args.hpp:22,
#                  from /usr/include/boost/python.hpp:11,
#                  from src/pyFullSearch.cpp:216:
# /usr/include/boost/bind.hpp:36:1: note: ‘#pragma message: The practice of declaring the Bind placeholders (_1, _2, ...) in the global namespace is deprecated. Please use <boost/bind/bind.hpp> + using namespace boost::placeholders, or define BOOST_BIND_GLOBAL_PLACEHOLDERS to retain the current behavior.’
#    36 | BOOST_PRAGMA_MESSAGE(
#       | ^~~~~~~~~~~~~~~~~~~~
# /usr/include/boost/detail/iterator.hpp:13:1: note: ‘#pragma message: This header is deprecated. Use <iterator> instead.’
#    13 | BOOST_HEADER_DEPRECATED("<iterator>")
#       | ^~~~~~~~~~~~~~~~~~~~~~~
#
# Building PARSER dynamic library.
# g++ -shared obj/pyPARSER.o -o pyPARSER.so -L/usr/lib/x86_64-linux-gnu -lboost_python310 -lz -lopenbabel -lgsl -lnlopt_cxx -lgsl -lgslcblas -lm
#
# Building MOL2 dynamic library.
# g++ -shared obj/pyMol2.o obj/pyPARSER.o -o pyMol2.so -L/usr/lib/x86_64-linux-gnu -lboost_python310 -lz -lopenbabel -lgsl -lnlopt_cxx -lgsl -lgslcblas -lm
#
# Building WRITER dynamic library.
# g++ -shared obj/pyWRITER.o obj/pyMol2.o obj/pyPARSER.o -o pyWRITER.so -L/usr/lib/x86_64-linux-gnu -lboost_python310 -lz -lopenbabel -lgsl -lnlopt_cxx -lgsl -lgslcblas -lm
#
# Building GRID dynamic library.
# g++ -shared obj/pyGrid.o obj/pyMol2.o obj/pyPARSER.o obj/pyWRITER.o obj/cudaGrid.o -o pyGrid.so -L/usr/lib/x86_64-linux-gnu -lboost_python310 -lz -lopenbabel -lgsl -lnlopt_cxx -lgsl -lgslcblas -lm  -L/usr/local/cuda/lib64 -lcudart
#
# Building COORD_MC dynamic library.
# g++ -shared obj/pyCOORD_MC.o obj/pyRAND.o obj/pyMol2.o -o pyCOORD_MC.so -L/usr/lib/x86_64-linux-gnu -lboost_python310 -lz -lopenbabel -lgsl -lnlopt_cxx -lgsl -lgslcblas -lm
#
# Building FIND_HB dynamic library.
# g++ -shared obj/pyFindHB.o obj/pyMol2.o obj/pyPARSER.o obj/pyCOORD_MC.o -o pyFindHB.so -L/usr/lib/x86_64-linux-gnu -lboost_python310 -lz -lopenbabel -lgsl -lnlopt_cxx -lgsl -lgslcblas -lm
#
# Building ENERGY2 dynamic library.
# g++ -shared obj/pyEnergy2.o obj/pyPARSER.o obj/pyMol2.o obj/pyGrid.o obj/cudaGrid.o obj/pyWRITER.o -o pyEnergy2.so -L/usr/lib/x86_64-linux-gnu -lboost_python310 -lz -lopenbabel -lgsl -lnlopt_cxx -lgsl -lgslcblas -lm  -L/usr/local/cuda/lib64 -lcudart
#
# Building CONFORMER dynamic library.
# g++ -shared obj/pyConformer.o obj/pyPARSER.o obj/pyMol2.o -o pyConformer.so -L/usr/lib/x86_64-linux-gnu -lboost_python310 -lz -lopenbabel -lgsl -lnlopt_cxx -lgsl -lgslcblas -lm
#
# Building GAUSSIAN dynamic library.
# g++ -shared obj/pyGaussian.o obj/pyMol2.o obj/pyPARSER.o -o pyGaussian.so -L/usr/lib/x86_64-linux-gnu -lboost_python310 -lz -lopenbabel -lgsl -lnlopt_cxx -lgsl -lgslcblas -lm
#
# Building MCENTROPY dynamic library.
# g++ -shared obj/pyMcEntropy.o obj/pyPARSER.o obj/pyMol2.o obj/pyCOORD_MC.o -o pyMcEntropy.so -L/usr/lib/x86_64-linux-gnu -lboost_python310 -lz -lopenbabel -lgsl -lnlopt_cxx -lgsl -lgslcblas -lm
#
# Building SA dynamic library.
# g++ -shared obj/pySA.o obj/pyMol2.o obj/pyGrid.o obj/pyEnergy2.o obj/pyCOORD_MC.o obj/pyWRITER.o obj/pyPARSER.o obj/cudaGrid.o -o pySA.so -L/usr/lib/x86_64-linux-gnu -lboost_python310 -lz -lopenbabel -lgsl -lnlopt_cxx -lgsl -lgslcblas -lm  -L/usr/local/cuda/lib64 -lcudart
#
# Building MC dynamic library.
# g++ -shared obj/pyMC.o obj/pyPARSER.o obj/pyGrid.o obj/pyMol2.o obj/pyCOORD_MC.o obj/pyEnergy2.o obj/pyWRITER.o obj/pyMcEntropy.o obj/pyOptimizer.o obj/pyGaussian.o obj/pySA.o obj/cudaGrid.o -o pyMC.so -L/usr/lib/x86_64-linux-gnu -lboost_python310 -lz -lopenbabel -lgsl -lnlopt_cxx -lgsl -lgslcblas -lm  -L/usr/local/cuda/lib64 -lcudart
#
# Building OPTIMIZER dynamic library.
# g++ -shared obj/pyOptimizer.o obj/pyMol2.o obj/pyEnergy2.o obj/pyPARSER.o obj/pyCOORD_MC.o obj/pyGaussian.o obj/pyWRITER.o obj/pySA.o obj/pyMC.o obj/pyGrid.o obj/pyMcEntropy.o obj/cudaGrid.o -o pyOptimizer.so -L/usr/lib/x86_64-linux-gnu -lboost_python310 -lz -lopenbabel -lgsl -lnlopt_cxx -lgsl -lgslcblas -lm  -L/usr/local/cuda/lib64 -lcudart
#
# Building DOCKER dynamic library.
# g++ -shared obj/pyDocker.o obj/pyMol2.o obj/pyOptimizer.o obj/pyPARSER.o obj/pyWRITER.o obj/pyCOORD_MC.o obj/pyGrid.o obj/pySA.o obj/pyEnergy2.o obj/pyGaussian.o obj/cudaGrid.o -o pyDocker.so -L/usr/lib/x86_64-linux-gnu -lboost_python310 -lz -lopenbabel -lgsl -lnlopt_cxx -lgsl -lgslcblas -lm  -L/usr/local/cuda/lib64 -lcudart
#
# Building FULLSEARCH dynamic library.
# g++ -shared obj/pyFullSearch.o obj/pyMol2.o obj/pyPARSER.o obj/pyConformer.o obj/pyWRITER.o obj/pyCOORD_MC.o obj/pyGrid.o obj/pyEnergy2.o obj/cudaGrid.o -o pyFullSearch.so -L/usr/lib/x86_64-linux-gnu -lboost_python310 -lz -lopenbabel -lgsl -lnlopt_cxx -lgsl -lgslcblas -lm  -L/usr/local/cuda/lib64 -lcudart

# %%
#@title Importing pyLiBELa {display-mode: "form"}
import random

try:
  from pyPARSER import *
  from pyMol2 import *
  from pyWRITER import *
  from pyGrid import *
  from pyCOORD_MC import *
  from pyFindHB import *
  from pyEnergy2 import *
  from pyGaussian import *
  from pyConformer import *
  from pyRAND import *
  from pyMcEntropy import *
  from pySA import *
  from pyOptimizer import *
  from pyMC import *
  from pyFullSearch import *
  from pyDocker import *
  print('pyLiBELa is imported!')
except ImportError:
  print('An ImportError occurred, try running this cell again!')
# Out:
# pyLiBELa is imported!

# %%
#@title Getting SB2021 data {display-mode: "form"}

# %%capture
from google.colab import drive
drive.mount('/content/drive/')
sb_folder = '/content/drive/MyDrive/pyLiBELa/SB/' #@param {type:"string"}

# %cd $sb_folder
targets=[]
targets_file = open('list', 'r');
for line in targets_file:
  targets.append(line.strip())
targets_file.close()

# %%
#@title Docking parameters {display-mode: "form"}

import os
import timeit
import numpy as np

Input = PARSER()

# Some default options:
# 1. We are using two processors for Grid calculations;
#

Input.generate_conformers = True;
Input.dock_parallel = True;
Input.parallel_jobs = 2;
Input.write_grids = True
Input.use_grids = True
Input.write_mol2 = True
Input.atom_limit = 150 #@param {type:"number"}
    #atom limit not counting H

# Energy Calculation Parameters:
scoring_function = "0" #@param ["0", "1", "2", "3"]
Input.dielectric_model = "r" #@param ["r", "constant"]
Input.scoring_function = int(scoring_function)
grid_dimension = 30.0 #@param {type:"number"}
Input.grid_spacing = 0.5 #@param {type:"number"}
Input.solvation_alpha = 0.1 #@param {type:"number"}
Input.solvation_beta = -0.005 #@param {type:"number"}

# Optimization parameter:
Input.min_tol = 1E-4;
Input.min_delta = 1E-5;
Input.dock_min_tol = 1E-4;
search_box = 30.0 #@param {type:"number"}
Input.timeout = 30 #@param {type:"number"}
Input.min_timeout = 30 #@param {type:"number"}
Input.overlay_optimizer = "mma" #@param ["mma", "ln_auglag", "subplex", "none"]
Input.energy_optimizer = "mma" #@param ["direct", "isres", "crs", "esch", "stogo", "mma", "simplex", "none"]
if (Input.scoring_function < 3):
  delta = 2.5 #@param {type:"number"}
  Input.deltaij6 = (delta*delta*delta*delta*delta*delta)
  delta_es = 2.5 #@param {type:"number"}
  Input.deltaij_es6 = pow(delta_es, 6);
  Input.deltaij_es3 = (delta_es*delta_es*delta_es)

Input.search_box_x, Input.search_box_y, Input.search_box_z = search_box, search_box, search_box;
Input.x_dim, Input.y_dim, Input.z_dim = grid_dimension, grid_dimension, grid_dimension;
Input.grid_prefix = "McGrid"

# %%
#@title Organizing test files {display-mode: "form"}

#%load_ext autotime



print('#%10s %10s' % ('TARGET', 'RMSD(Ang)'))

targets_random=random.sample(targets, len(targets));


target = targets[500]

for i in range(1):
#  target=targets_random[68]
  folder = sb_folder+target
#  print()
#  print()
  # %cd $folder
  ! mkdir -p test
  # %cd test
  ! rm -f *

  print()
  print()

  ! cp ../*lig.am1bcc.mol2.gz lig.mol2.gz
  ! cp ../*.rec.clean.mol2.gz rec.mol2.gz
  ! obabel -imol2 lig.mol2.gz -osmi -O lig2.smi &> /dev/null #self docking

  insmiles = open('lig2.smi', 'r');
  line=insmiles.readline().strip()
  line2 = line.split()
  ligand_smiles = line2[0]
  insmiles.close();

  Lig2 = Mol2()
  ligcheck = Lig2.parse_smiles(Input, ligand_smiles, 'LIG')
#  if (not ligcheck):
#    print("#Ops! A problem was identified in ligand %s" % target);

  lig_src =  'lig.mol2.gz'
  rec_src = 'rec.mol2.gz'

  REC = Mol2(Input, rec_src)
  RefLig = Mol2(Input, lig_src)

#  print("Receptor has %4d atoms." % REC.N)
#  print('Reference Ligand has %4d atoms' % RefLig.N)
#  print('Search ligand has %4d atoms' % Lig2.N)

  if (ligcheck):
    Writer = WRITER(Input)
    Coord = COORD_MC()
    HB = FindHB()
    Ene  = Energy2(Input)

    for i in range(len(REC.residue_pointer)-1):
      HB.parse_residue(REC.residue_pointer[i]-1, REC.residue_pointer[i+1]-2, REC.resnames[i], REC, RefLig, 9.0);
    HB.find_ligandHB(lig_src, RefLig);

#    print('The receptor has %5d / %5d HB donors/acceptors around the active site.' % (len(REC.HBdonors), len(REC.HBacceptors)));

    Dock = Docker(Writer)
    center = Coord.compute_com(RefLig)

#    print()

    start_energy = Ene.compute_ene(REC, RefLig, RefLig.xyz);

#    print('Starting energy: %7.3f kcal/mol' % start_energy);
#    print('Generating grids. This may take a while..')

    Grids = Grid(Input, Writer, REC, center)
    grid_energy = Ene.compute_ene(Grids, RefLig, RefLig.xyz);

#    print('Grid original energy: %7.3f kcal/mol' % grid_energy);
#    print('Grid error: %7.3f %%' % abs(100.*(start_energy-grid_energy)/start_energy));

#    print('Starting docking calculation...')

    Dock.run(REC, Lig2, RefLig, center, Input, Grids, 0)

#    Computing the RMSD

    ! obabel -imol2 McLiBELa_dock.mol2.gz -pdb -O docked_ligand.pdb &> /dev/null
    rmsd = ! obrms lig.mol2.gz docked_ligand.pdb
    if (len(rmsd) > 0):
      rmsd = rmsd[0].split()
#      print(rmsd)
      if (len(rmsd) == 3):
        print('%10s %10.10s Ang' % (target, rmsd[2]))
    else:
      print('%10s %10.10s Ang' % (target, 'N/A'));
    print('***********************************************************************************************')
# Out:
# #    TARGET  RMSD(Ang)
# /content/drive/MyDrive/pyLiBELa/SB/1QBS
# /content/drive/MyDrive/pyLiBELa/SB/1QBS/test
#
#
#       1QBS        inf Ang
# ***********************************************************************************************

# %%
#@title Preparing Output Files
# !rm -rf lig2.pdb lig_ref.pdb rec.pdb


# !obabel -imol2 McLiBELa_dock.mol2.gz -opdb -O lig2.pdb
# !obabel -imol2 test/lig.mol2.gz -opdb -O lig_ref.pdb
# !obabel -imol2 test/rec.mol2.gz -opdb -O rec.pdb

lig2_pdb = open('lig2.pdb', 'r').read()
lig_ref_pdb = open('lig_ref.pdb', 'r').read()
rec_pdb = open('rec.pdb','r').read()

box_pdb = open('box.pdb','r').read()

def join_pdb(name_file_rec,name_file_lig,name_file_merge):
  # !cp $name_file_rec temp_rec.pdb
  # !cp $name_file_lig temp_lig.pdb

  # !sed -i '/END\|CONECT/d' temp_rec.pdb #tira o end e o conect do arquivo do receptor

  # !sed -i 's/A  /B  /g' temp_lig.pdb #troca a cadeia A por B no arquivo do ligante

  # !sed -i '/CONECT/d' temp_lig.pdb #tira o conect do arquivo do ligante

  # !cat temp_rec.pdb temp_lig.pdb > $name_file_merge #concatena os arquivos

  # !rm -rf temp_rec.pdb temp_lig.pdb


join_pdb('rec.pdb','lig_ref.pdb','complex1.pdb')
complex1_pdb = open('complex1.pdb','r').read()

join_pdb('rec.pdb','lig2.pdb','complex2.pdb')
complex2_pdb = open('complex2.pdb','r').read()

# %%
#@title Calculating RMSD
# !obrms lig_ref.pdb lig2.pdb > rmsd.txt
with open('rmsd.txt') as rmsd_text:
   rmsd_list = rmsd_text.readlines()

#print(rmsd_list)
rmsd = rmsd_list[0].split()[-1]

print('The RMSD between the reference ligand and its reference after docking is %s.' %rmsd)

# %%
#@title Setting view
# %%capture
try:
  import py3Dmol
except:
  # !pip install py3Dmol
  import py3Dmol
aminoacids = ['MET', 'THR', 'ASN', 'LYS', 'SER', 'ARG', 'VAL', 'ALA', 'ASP', 'GLU', 'GLY', 'PHE', 'LEU', 'TYR', 'CYS', 'TRP', 'PRO', 'HIS', 'GLN', 'ILE', 'ASH', 'CYX', 'GLH', 'HIE', 'HID', 'HIP','HOH']

# %%
#@title Ligands
#@markdown The reference ligand is in green and the docked ligand is in yellow.
view = py3Dmol.view()

#Adding models
view.addModel(lig2_pdb,'pdb') #model 0
view.addModel(lig_ref_pdb,'pdb') #model 1
#view.addModel(box_pdb,'pdb') #something wrong with it

view.setStyle({'model':0},{'stick': {'colorscheme':'yellowCarbon'}})
view.setStyle({'model':1},{'stick': {'colorscheme':'greenCarbon'}})


view.setBackgroundColor('white')
view.zoomTo()
view.show()

# %%
#@title Docking complex
view = py3Dmol.view(width=1200,height=800)

#Adding models
view.addModel(complex2_pdb,'pdb')
view.addModel(lig_ref_pdb,'pdb') #model 1

view.setStyle({'chain':'B'},{'stick': {'colorscheme':'yellowCarbon'}})

view.setStyle({'chain':'A'},  {"cartoon":{'arrows':True,'colorscheme':'ssPymol','opacity':0.7}})
view.setStyle({ 'chain':'A', 'not':{'resn':aminoacids}}, {'sphere':{}})
view.addStyle({'chain':'A','within':{'distance':'5', 'sel':{'chain':'B'}},'byres':True}, {'stick': {'colorscheme':'skyblueCarbon'}})
view.setStyle({'model':1},{'stick': {'colorscheme':'greenCarbon','opacity':0.7}})

view.setBackgroundColor('white')
view.zoomTo({'chain':'B'})
view.show()

# %%
grid_name = Input.grid_prefix + '.grid'
# !mv $grid_name test/
log_name = 'McLiBELa' + target + '_' + tag + '.log'


# !mv McLiBELa.log test/$log_name

# %%
# !tail McLiBELa.log
rmsd = 0
use_cuda = 'False'
log_add = 'Use CUDA = %s \n Grids Time = %.2f \n Time per atom  = %.2f \n RMSD = %.2f'%(use_cuda,time,time_per_atom,rmsd)
print(log_add)
#!sed -i
#printf("* %-30s %-66d*\n", "number_of_conformers", Input->lig_conformers);
