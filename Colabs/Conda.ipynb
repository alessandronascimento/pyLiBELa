# %% [markdown]
# <a href="https://colab.research.google.com/github/alessandronascimento/pyLiBELa/blob/main/Colabs/Conda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install condacolab
import condacolab
condacolab.install()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting condacolab
#   Downloading condacolab-0.1.7-py3-none-any.whl (7.2 kB)
# Installing collected packages: condacolab
# Successfully installed condacolab-0.1.7
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.1.0-1/Mambaforge-23.1.0-1-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:21
# 🔁 Restarting kernel...

# %%
# %time
! apt-get install openbabel libopenbabel-dev python-dev-is-python3 zlib1g-dev libeigen3-dev libgsl-dev libnlopt-cxx-dev libgsl-dev
! mamba install -c anaconda py-boost
! git clone https://github.com/alessandronascimento/pyLiBELa.git
! mv pyLiBELa/src src
! rm -rf pyLiBELa
! mkdir -p obj
! rm -f Makefile*
# !wget https://raw.githubusercontent.com/alessandronascimento/pyLiBELa/main/Colabs/Makefile
# !make -j4
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 6.91 µs
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# zlib1g-dev is already the newest version (1:1.2.11.dfsg-2ubuntu1.5).
# zlib1g-dev set to manually installed.
# The following additional packages will be installed:
#   libgsl23 libgslcblas0 libnlopt-cxx0 libnlopt-dev libnlopt0 libopenbabel6
#   libschroedinger-maeparser1 python-is-python3
# Suggested packages:
#   libeigen3-doc libmpfrc++-dev gsl-ref-psdoc | gsl-doc-pdf | gsl-doc-info
#   | gsl-ref-html libopenbabel-doc
# The following NEW packages will be installed:
#   libeigen3-dev libgsl-dev libgsl23 libgslcblas0 libnlopt-cxx-dev
#   libnlopt-cxx0 libnlopt-dev libnlopt0 libopenbabel-dev libopenbabel6
#   libschroedinger-maeparser1 openbabel python-dev-is-python3 python-is-python3
# 0 upgraded, 14 newly installed, 0 to remove and 24 not upgraded.
# Need to get 7,174 kB of archives.
# After this operation, 37.0 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 libgslcblas0 amd64 2.5+dfsg-6build1 [84.6 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/universe amd64 libgsl23 amd64 2.5+dfsg-6build1 [850 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal/universe amd64 libgsl-dev amd64 2.5+dfsg-6build1 [1,064 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal/universe amd64 libnlopt0 amd64 2.6.1-8ubuntu2 [167 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal/universe amd64 libnlopt-dev amd64 2.6.1-8ubuntu2 [29.6 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal/universe amd64 libnlopt-cxx0 amd64 2.6.1-8ubuntu2 [193 kB]
# Get:7 http://archive.ubuntu.com/ubuntu focal/universe amd64 libnlopt-cxx-dev amd64 2.6.1-8ubuntu2 [11.0 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal/universe amd64 libschroedinger-maeparser1 amd64 1.2.2-1build1 [89.1 kB]
# Get:9 http://archive.ubuntu.com/ubuntu focal/universe amd64 libopenbabel6 amd64 3.0.0+dfsg-3ubuntu3 [3,568 kB]
# Get:10 http://archive.ubuntu.com/ubuntu focal/universe amd64 libopenbabel-dev amd64 3.0.0+dfsg-3ubuntu3 [173 kB]
# Get:11 http://archive.ubuntu.com/ubuntu focal/universe amd64 openbabel amd64 3.0.0+dfsg-3ubuntu3 [127 kB]
# Get:12 http://archive.ubuntu.com/ubuntu focal/main amd64 python-is-python3 all 3.8.2-4 [2,364 B]
# Get:13 http://archive.ubuntu.com/ubuntu focal/main amd64 python-dev-is-python3 all 3.8.2-4 [1,264 B]
# Get:14 http://archive.ubuntu.com/ubuntu focal/universe amd64 libeigen3-dev all 3.3.7-2 [815 kB]
# Fetched 7,174 kB in 1s (7,312 kB/s)
# Selecting previously unselected package libgslcblas0:amd64.
# (Reading database ... 122518 files and directories currently installed.)
# Preparing to unpack .../00-libgslcblas0_2.5+dfsg-6build1_amd64.deb ...
# Unpacking libgslcblas0:amd64 (2.5+dfsg-6build1) ...
# Selecting previously unselected package libgsl23:amd64.
# Preparing to unpack .../01-libgsl23_2.5+dfsg-6build1_amd64.deb ...
# Unpacking libgsl23:amd64 (2.5+dfsg-6build1) ...
# Selecting previously unselected package libgsl-dev.
# Preparing to unpack .../02-libgsl-dev_2.5+dfsg-6build1_amd64.deb ...
# Unpacking libgsl-dev (2.5+dfsg-6build1) ...
# Selecting previously unselected package libnlopt0:amd64.
# Preparing to unpack .../03-libnlopt0_2.6.1-8ubuntu2_amd64.deb ...
# Unpacking libnlopt0:amd64 (2.6.1-8ubuntu2) ...
# Selecting previously unselected package libnlopt-dev:amd64.
# Preparing to unpack .../04-libnlopt-dev_2.6.1-8ubuntu2_amd64.deb ...
# Unpacking libnlopt-dev:amd64 (2.6.1-8ubuntu2) ...
# Selecting previously unselected package libnlopt-cxx0:amd64.
# Preparing to unpack .../05-libnlopt-cxx0_2.6.1-8ubuntu2_amd64.deb ...
# Unpacking libnlopt-cxx0:amd64 (2.6.1-8ubuntu2) ...
# Selecting previously unselected package libnlopt-cxx-dev:amd64.
# Preparing to unpack .../06-libnlopt-cxx-dev_2.6.1-8ubuntu2_amd64.deb ...
# Unpacking libnlopt-cxx-dev:amd64 (2.6.1-8ubuntu2) ...
# Selecting previously unselected package libschroedinger-maeparser1:amd64.
# Preparing to unpack .../07-libschroedinger-maeparser1_1.2.2-1build1_amd64.deb ...
# Unpacking libschroedinger-maeparser1:amd64 (1.2.2-1build1) ...
# Selecting previously unselected package libopenbabel6.
# Preparing to unpack .../08-libopenbabel6_3.0.0+dfsg-3ubuntu3_amd64.deb ...
# Unpacking libopenbabel6 (3.0.0+dfsg-3ubuntu3) ...
# Selecting previously unselected package libopenbabel-dev.
# Preparing to unpack .../09-libopenbabel-dev_3.0.0+dfsg-3ubuntu3_amd64.deb ...
# Unpacking libopenbabel-dev (3.0.0+dfsg-3ubuntu3) ...
# Selecting previously unselected package openbabel.
# Preparing to unpack .../10-openbabel_3.0.0+dfsg-3ubuntu3_amd64.deb ...
# Unpacking openbabel (3.0.0+dfsg-3ubuntu3) ...
# Selecting previously unselected package python-is-python3.
# Preparing to unpack .../11-python-is-python3_3.8.2-4_all.deb ...
# Unpacking python-is-python3 (3.8.2-4) ...
# Selecting previously unselected package python-dev-is-python3.
# Preparing to unpack .../12-python-dev-is-python3_3.8.2-4_all.deb ...
# Unpacking python-dev-is-python3 (3.8.2-4) ...
# Selecting previously unselected package libeigen3-dev.
# Preparing to unpack .../13-libeigen3-dev_3.3.7-2_all.deb ...
# Unpacking libeigen3-dev (3.3.7-2) ...
# Setting up libgslcblas0:amd64 (2.5+dfsg-6build1) ...
# Setting up libnlopt0:amd64 (2.6.1-8ubuntu2) ...
# Setting up libschroedinger-maeparser1:amd64 (1.2.2-1build1) ...
# Setting up libgsl23:amd64 (2.5+dfsg-6build1) ...
# Setting up libeigen3-dev (3.3.7-2) ...
# Setting up libnlopt-cxx0:amd64 (2.6.1-8ubuntu2) ...
# Setting up libnlopt-dev:amd64 (2.6.1-8ubuntu2) ...
# Setting up python-is-python3 (3.8.2-4) ...
# Setting up libgsl-dev (2.5+dfsg-6build1) ...
# Setting up libopenbabel6 (3.0.0+dfsg-3ubuntu3) ...
# Setting up openbabel (3.0.0+dfsg-3ubuntu3) ...
# Setting up libopenbabel-dev (3.0.0+dfsg-3ubuntu3) ...
# Setting up libnlopt-cxx-dev:amd64 (2.6.1-8ubuntu2) ...
# Setting up python-dev-is-python3 (3.8.2-4) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
#
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         mamba (1.4.1) supported by @QuantStack
#
#         GitHub:  https://github.com/mamba-org/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
#
# Looking for: ['py-boost']
#
# [+] 0.0s
# [+] 0.1s
# anaconda/linux-64     ⣾
# anaconda/noarch       ⣾
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 0.2s
# anaconda/linux-64     ⣾
# anaconda/noarch       ⣾
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  anaconda/noarch
# [+] 0.3s
# anaconda/linux-64     ⣾
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 0.4s
# anaconda/linux-64     ⣾
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 0.5s
# anaconda/linux-64     ⣾
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 0.6s
# anaconda/linux-64     ⣾
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 0.7s
# anaconda/linux-64     ⣾
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 0.8s
# anaconda/linux-64    100%
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  anaconda/linux-64
# [+] 0.9s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 1.0s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 1.1s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 1.2s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 1.3s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 1.4s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 1.5s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 1.6s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 1.7s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 1.8s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 1.9s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 2.0s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 2.1s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 2.2s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 2.3s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 2.4s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 2.5s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 2.6s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 2.7s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 2.8s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 2.9s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 3.0s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 3.1s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 3.2s
# conda-forge/linux-64  ⣾
# conda-forge/noarch   100%conda-forge/noarch
# [+] 3.3s
# conda-forge/linux-64  ⣾  [+] 3.4s
# conda-forge/linux-64  ⣾  [+] 3.5s
# conda-forge/linux-64  ⣾  [+] 3.6s
# conda-forge/linux-64  ⣾  [+] 3.7s
# conda-forge/linux-64  ⣾  [+] 3.8s
# conda-forge/linux-64  ⣾  [+] 3.9s
# conda-forge/linux-64  ⣾  [+] 4.0s
# conda-forge/linux-64  ⣾  [+] 4.1s
# conda-forge/linux-64  ⣾  [+] 4.2s
# conda-forge/linux-64  ⣾  [+] 4.3s
# conda-forge/linux-64  ⣾  [+] 4.4s
# conda-forge/linux-64  ⣾  [+] 4.5s
# conda-forge/linux-64  ⣾  [+] 4.6s
# conda-forge/linux-64  ⣾  [+] 4.7s
# conda-forge/linux-64  ⣾  [+] 4.8s
# conda-forge/linux-64  ⣾  [+] 4.9s
# conda-forge/linux-64  ⣾  [+] 5.0s
# conda-forge/linux-64  ⣾  [+] 5.1s
# conda-forge/linux-64  ⣾  [+] 5.2s
# conda-forge/linux-64  ⣾  [+] 5.3s
# conda-forge/linux-64  ⣾  [+] 5.4s
# conda-forge/linux-64  ⣾  [+] 5.5s
# conda-forge/linux-64  ⣾  [+] 5.6s
# conda-forge/linux-64  ⣾  [+] 5.7s
# conda-forge/linux-64  ⣾  [+] 5.8s
# conda-forge/linux-64  ⣾  [+] 5.9s
# conda-forge/linux-64  ⣾  [+] 6.0s
# conda-forge/linux-64  ⣾  [+] 6.1s
# conda-forge/linux-64  ⣾  [+] 6.2s
# conda-forge/linux-64  ⣾  [+] 6.3s
# conda-forge/linux-64  ⣾  [+] 6.4s
# conda-forge/linux-64  ⣾  [+] 6.5s
# conda-forge/linux-64  ⣾  [+] 6.6s
# conda-forge/linux-64  ⣾  [+] 6.7s
# conda-forge/linux-64  ⣾  [+] 6.8s
# conda-forge/linux-64  ⣾  [+] 6.9s
# conda-forge/linux-64  ⣾  [+] 7.0s
# conda-forge/linux-64  ⣾  [+] 7.1s
# conda-forge/linux-64  ⣾  [+] 7.2s
# conda-forge/linux-64  ⣾  [+] 7.3s
# conda-forge/linux-64 100%[+] 7.4s
# conda-forge/linux-64 100%[+] 7.5s
# conda-forge/linux-64 100%[+] 7.6s
# conda-forge/linux-64 100%[+] 7.7s
# conda-forge/linux-64 100%[+] 7.8s
# conda-forge/linux-64 100%[+] 7.9s
# conda-forge/linux-64 100%[+] 8.0s
# conda-forge/linux-64 100%[+] 8.1s
# conda-forge/linux-64 100%[+] 8.2s
# conda-forge/linux-64 100%conda-forge/linux-64
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cudatoolkit 11.8.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   Updating specs:
#
#    - py-boost
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package               Version  Build             Channel                   Size
# ───────────────────────────────────────────────────────────────────────────────────
#   Install:
# ───────────────────────────────────────────────────────────────────────────────────
#
#   + libboost             1.73.0  h28710b8_12       anaconda/linux-64         22MB
#   + py-boost             1.73.0  py310h00e6091_12  anaconda/linux-64        265kB
#   + zlib                 1.2.13  h166bdaf_4        conda-forge/linux-64      94kB
#
#   Upgrade:
# ───────────────────────────────────────────────────────────────────────────────────
#
#   - ca-certificates   2022.12.7  ha878542_0        conda-forge
#   + ca-certificates  2023.01.10  h06a4308_0        anaconda/linux-64        130kB
#
#   Downgrade:
# ───────────────────────────────────────────────────────────────────────────────────
#
#   - icu                    72.1  hcb278e6_0        conda-forge
#   + icu                    58.2  he6710b0_3        anaconda/linux-64         24MB
#   - libarchive            3.6.2  h3d51595_0        conda-forge
#   + libarchive            3.5.2  hada088e_3        conda-forge/linux-64       2MB
#   - libmamba              1.4.1  hcea66bb_0        conda-forge
#   + libmamba              1.1.0  h70b1f8a_2        conda-forge/linux-64       1MB
#   - libmambapy            1.4.1  py310h1428755_0   conda-forge
#   + libmambapy            1.1.0  py310h69aa5bf_2   conda-forge/linux-64     315kB
#   - libxml2              2.10.3  hfdac1af_6        conda-forge
#   + libxml2              2.9.14  h74e7548_0        anaconda/linux-64        789kB
#   - mamba                 1.4.1  py310h51d5547_0   conda-forge
#   + mamba                 1.1.0  py310h51d5547_2   conda-forge/linux-64      49kB
#
#   Summary:
#
#   Install: 3 packages
#   Upgrade: 1 packages
#   Downgrade: 6 packages
#
#   Total download: 51MB
#
# ───────────────────────────────────────────────────────────────────────────────────
#
#
# [+] 0.0s
# Downloading        0%
# Extracting         0%[+] 0.1s
# Downloading  (5)   0%
# Extracting         0%ca-certificates                                    129.7kB @   1.2MB/s  0.1s
# zlib                                                94.1kB @ 795.7kB/s  0.1s
# py-boost                                           265.1kB @   1.4MB/s  0.1s
# libmambapy                                         314.8kB @   1.7MB/s  0.1s
# [+] 0.2s
# Downloading  (5)   6%
# Extracting   (2)  ⣾  libxml2                                            789.5kB @   3.8MB/s  0.2s
# mamba                                               48.9kB @ 184.4kB/s  0.1s
# [+] 0.3s
# Downloading  (4)  38%
# Extracting   (6)  ⣾  libarchive                                           1.7MB @   5.8MB/s  0.1s
# libmamba                                             1.5MB @   4.4MB/s  0.1s
# [+] 0.4s
# Downloading  (2)  54%
# Extracting   (8)  ⣾  icu                                                 23.8MB @  51.7MB/s  0.5s
# [+] 0.5s
# Downloading  (1)  91%
# Extracting   (9)  ⣾  libboost                                            22.2MB @  42.2MB/s  0.5s
# [+] 0.6s
# Downloading      100%
# Extracting  (10)  ⣾  [+] 0.7s
# Downloading      100%
# Extracting  (10)  ⣾  [+] 0.8s
# Downloading      100%
# Extracting   (9)  ⣾  [+] 0.9s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 1.0s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 1.1s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 1.2s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 1.3s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 1.4s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 1.5s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 1.6s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 1.7s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 1.8s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 1.9s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 2.0s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 2.1s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 2.2s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 2.3s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 2.4s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 2.5s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 2.6s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 2.7s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 2.8s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 2.9s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 3.0s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 3.1s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 3.2s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 3.3s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 3.4s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 3.5s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 3.6s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 3.7s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 3.8s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 3.9s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 4.0s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 4.1s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 4.2s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 4.3s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 4.4s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 4.5s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 4.6s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 4.7s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 4.8s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 4.9s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 5.0s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 5.1s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 5.2s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 5.3s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 5.4s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 5.5s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 5.6s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 5.7s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 5.8s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 5.9s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 6.0s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 6.1s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 6.2s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 6.3s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 6.4s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 6.5s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 6.6s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 6.7s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 6.8s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 6.9s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 7.0s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 7.1s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 7.2s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 7.3s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 7.4s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 7.5s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 7.6s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 7.7s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 7.8s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 7.9s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 8.0s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 8.1s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 8.2s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 8.3s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 8.4s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 8.5s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 8.6s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 8.7s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 8.8s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 8.9s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 9.0s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 9.1s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 9.2s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 9.3s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 9.4s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 9.5s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 9.6s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 9.7s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 9.8s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 9.9s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 10.0s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 10.1s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 10.2s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 10.3s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 10.4s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 10.5s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 10.6s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 10.7s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 10.8s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 10.9s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 11.0s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 11.1s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 11.2s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 11.3s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 11.4s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 11.5s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 11.6s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 11.7s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 11.8s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 11.9s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 12.0s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 12.1s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 12.2s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 12.3s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 12.4s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 12.5s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 12.6s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 12.7s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 12.8s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 12.9s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 13.0s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 13.1s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 13.2s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 13.3s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 13.4s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 13.5s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 13.6s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 13.7s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 13.8s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 13.9s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 14.0s
# Downloading      100%
# Extracting   (3)  ⣾  [+] 14.1s
# Downloading      100%
# Extracting   (3)  ⣾  [+] 14.2s
# Downloading      100%
# Extracting   (3)  ⣾  [+] 14.3s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 14.4s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 14.5s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 14.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 14.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 14.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 14.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 21.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 21.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 21.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 21.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 21.4s
# Downloading      100%
# Extracting       100%
# Downloading and Extracting Packages
#
# done
# done
# done
# Cloning into 'pyLiBELa'...
# remote: Enumerating objects: 1666, done.
# remote: Counting objects: 100% (291/291), done.
# remote: Compressing objects: 100% (105/105), done.
# remote: Total 1666 (delta 200), reused 262 (delta 185), pack-reused 1375
# Receiving objects: 100% (1666/1666), 4.06 MiB | 14.13 MiB/s, done.
# Resolving deltas: 100% (1136/1136), done.
# --2023-05-03 20:19:07--  https://raw.githubusercontent.com/alessandronascimento/pyLiBELa/main/Colabs/Makefile
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5678 (5.5K) [text/plain]
# Saving to: ‘Makefile’
#
# Makefile            100%[===================>]   5.54K  --.-KB/s    in 0s
#
# 2023-05-03 20:19:07 (46.0 MB/s) - ‘Makefile’ saved [5678/5678]
#
# g++ -fPIC -O3 -I/usr/local/include/python3.10 -I/usr/include/openbabel3 -I/usr/include/eigen3 -DBUILD=0 -DHAVE_EIGEN -Wunused-value src/pyPARSER.cpp -c -o obj/pyPARSER.o
# g++ -fPIC -O3 -I/usr/local/include/python3.10 -I/usr/include/openbabel3 -I/usr/include/eigen3 -DBUILD=0 -DHAVE_EIGEN -Wunused-value src/pyMol2.cpp -c -o obj/pyMol2.o
# g++ -fPIC -O3 -I/usr/local/include/python3.10 -I/usr/include/openbabel3 -I/usr/include/eigen3 -DBUILD=0 -DHAVE_EIGEN -Wunused-value src/pyWRITER.cpp -c -o obj/pyWRITER.o
# g++ -fPIC -O3 -I/usr/local/include/python3.10 -I/usr/include/openbabel3 -I/usr/include/eigen3 -DBUILD=0 -DHAVE_EIGEN -Wunused-value src/pyGrid.cpp -c -o obj/pyGrid.o
# In file included from /usr/local/include/boost/bind.hpp:30,
#                  from /usr/local/include/boost/python/exception_translator.hpp:10,
#                  from /usr/local/include/boost/python.hpp:28,
#                  from src/pyPARSER.cpp:580:
# /usr/local/include/boost/bind.hpp:36:1: note: #pragma message: The practice of declaring the Bind placeholders (_1, _2, ...) in the global namespace is deprecated. Please use <boost/bind/bind.hpp> + using namespace boost::placeholders, or define BOOST_BIND_GLOBAL_PLACEHOLDERS to retain the current behavior.
#    36 | BOOST_PRAGMA_MESSAGE(
#       | ^~~~~~~~~~~~~~~~~~~~
# In file included from /usr/local/include/boost/bind.hpp:30,
#                  from /usr/local/include/boost/python/exception_translator.hpp:10,
#                  from /usr/local/include/boost/python.hpp:28,
#                  from src/pyMol2.cpp:2200:
# /usr/local/include/boost/bind.hpp:36:1: note: #pragma message: The practice of declaring the Bind placeholders (_1, _2, ...) in the global namespace is deprecated. Please use <boost/bind/bind.hpp> + using namespace boost::placeholders, or define BOOST_BIND_GLOBAL_PLACEHOLDERS to retain the current behavior.
#    36 | BOOST_PRAGMA_MESSAGE(
#       | ^~~~~~~~~~~~~~~~~~~~
# In file included from /usr/local/include/boost/bind.hpp:30,
#                  from /usr/local/include/boost/python/exception_translator.hpp:10,
#                  from /usr/local/include/boost/python.hpp:28,
#                  from src/pyGrid.cpp:1668:
# /usr/local/include/boost/bind.hpp:36:1: note: #pragma message: The practice of declaring the Bind placeholders (_1, _2, ...) in the global namespace is deprecated. Please use <boost/bind/bind.hpp> + using namespace boost::placeholders, or define BOOST_BIND_GLOBAL_PLACEHOLDERS to retain the current behavior.
#    36 | BOOST_PRAGMA_MESSAGE(
#       | ^~~~~~~~~~~~~~~~~~~~
# In file included from /usr/local/include/boost/bind.hpp:30,
#                  from /usr/local/include/boost/python/exception_translator.hpp:10,
#                  from /usr/local/include/boost/python.hpp:28,
#                  from src/pyWRITER.cpp:712:
# /usr/local/include/boost/bind.hpp:36:1: note: #pragma message: The practice of declaring the Bind placeholders (_1, _2, ...) in the global namespace is deprecated. Please use <boost/bind/bind.hpp> + using namespace boost::placeholders, or define BOOST_BIND_GLOBAL_PLACEHOLDERS to retain the current behavior.
#    36 | BOOST_PRAGMA_MESSAGE(
#       | ^~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp: In member function ‘void Grid::load_Ambergrids_from_file()’:
# src/pyGrid.cpp:712:18: warning: ignoring return value of ‘char* fgets(char*, int, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#   712 |             fgets(str, 80, pbsa_map);
#       |             ~~~~~^~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:717:15: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’, declared with attribute warn_unused_result [-Wunused-result]
#   717 |         fscanf(pbsa_map, "%d %d %d", &this->npointsx, &this->npointsy, &this->npointsz);
#       |         ~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:744:27: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’, declared with attribute warn_unused_result [-Wunused-result]
#   744 |                     fscanf(pbsa_map, "%f", &phi);
#       |                     ~~~~~~^~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp: In member function ‘void Grid::load_Delphi_Grid_from_file()’:
# src/pyGrid.cpp:1025:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#  1025 |     fread(&tmpi, sizeof(int), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1034:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#  1034 |     fread(&tmpi, sizeof(int), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1035:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#  1035 |     fread(&tmpi, sizeof(int), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1037:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#  1037 |     fread(&ivary, sizeof(int), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1038:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#  1038 |     fread(&nbyte, sizeof(int), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1039:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#  1039 |     fread(&inddat, sizeof(int), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1041:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#  1041 |     fread(&extent, sizeof(double), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1042:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#  1042 |     fread(&extent, sizeof(double), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1043:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#  1043 |     fread(&extent, sizeof(double), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1045:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#  1045 |     fread(&xang, sizeof(double), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1046:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#  1046 |     fread(&yang, sizeof(double), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1047:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#  1047 |     fread(&zang, sizeof(double), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1049:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#  1049 |     fread(&xstart, sizeof(double), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1050:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#  1050 |     fread(&xend, sizeof(double), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1052:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#  1052 |     fread(&ystart, sizeof(double), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1053:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#  1053 |     fread(&yend, sizeof(double), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1055:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#  1055 |     fread(&zstart, sizeof(double), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1056:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#  1056 |     fread(&zend, sizeof(double), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1058:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#  1058 |     fread(&intx, sizeof(int), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1059:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#  1059 |     fread(&inty, sizeof(int), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1060:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#  1060 |     fread(&intz, sizeof(int), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1102:22: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#  1102 |                 fread(&phi, sizeof(double), 1, phimap);
#       |                 ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp: In member function ‘void Grid::load_phimap_from_file(int)’:
# src/pyGrid.cpp:1137:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#  1137 |     fread(&tmpi, sizeof(int), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1146:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#  1146 |     fread(&tmpi, sizeof(int), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1147:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#  1147 |     fread(&tmpi, sizeof(int), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1163:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#  1163 |     fread(&tmpi, sizeof(int), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1164:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#  1164 |     fread(&tmpi, sizeof(int), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1186:22: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#  1186 |                 fread(&kt_phi, sizeof(float), 1, phimap);
#       |                 ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1192:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#  1192 |     fread(&tmpi, sizeof(int), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1193:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#  1193 |     fread(&tmpi, sizeof(int), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1202:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#  1202 |     fread(&tmpi, sizeof(int), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1203:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#  1203 |     fread(&tmpi, sizeof(int), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1210:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#  1210 |     fread(&scale, sizeof(float), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1211:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#  1211 |     fread(&oldmid_x, sizeof(float), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1212:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#  1212 |     fread(&oldmid_y, sizeof(float), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1213:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#  1213 |     fread(&oldmid_z, sizeof(float), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1214:10: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#  1214 |     fread(&igrid, sizeof(int), 1, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp: In member function ‘void Grid::load_delphi_cube()’:
# src/pyGrid.cpp:1258:11: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’, declared with attribute warn_unused_result [-Wunused-result]
#  1258 |     fscanf(phimap, "%f %d %f %f %f", &scale, &igrid, &centerx, &centery, &centerz);
#       |     ~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1272:10: warning: ignoring return value of ‘char* fgets(char*, int, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#  1272 |     fgets(str, 80, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1273:10: warning: ignoring return value of ‘char* fgets(char*, int, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#  1273 |     fgets(str, 80, phimap);
#       |     ~~~~~^~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1274:11: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’, declared with attribute warn_unused_result [-Wunused-result]
#  1274 |     fscanf(phimap, "%d %f %f %f", &itmp, &dtmp, &dtmp, &dtmp);
#       |     ~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1275:11: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’, declared with attribute warn_unused_result [-Wunused-result]
#  1275 |     fscanf(phimap, "%d %f %f %f", &itmp, &dtmp, &dtmp, &dtmp);
#       |     ~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1276:11: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’, declared with attribute warn_unused_result [-Wunused-result]
#  1276 |     fscanf(phimap, "%d %f %f %f", &itmp, &dtmp, &dtmp, &dtmp);
#       |     ~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1277:11: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’, declared with attribute warn_unused_result [-Wunused-result]
#  1277 |     fscanf(phimap, "%d %f %f %f", &itmp, &dtmp, &dtmp, &dtmp);
#       |     ~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1278:11: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’, declared with attribute warn_unused_result [-Wunused-result]
#  1278 |     fscanf(phimap, "%d %f %f %f %f", &itmp, &dtmp, &dtmp, &dtmp, &dtmp);
#       |     ~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyGrid.cpp:1295:23: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’, declared with attribute warn_unused_result [-Wunused-result]
#  1295 |                 fscanf(phimap, "%f", &phi);
#       |                 ~~~~~~^~~~~~~~~~~~~~~~~~~~
#
# g++ -fPIC -O3 -I/usr/local/include/python3.10 -I/usr/include/openbabel3 -I/usr/include/eigen3 -DBUILD=0 -DHAVE_EIGEN -Wunused-value src/pyCOORD_MC.cpp -c -o obj/pyCOORD_MC.o
# src/pyMol2.cpp: In member function ‘bool Mol2::parse_mol2file(PARSER*, std::string)’:
# src/pyMol2.cpp:210:18: warning: ignoring return value of ‘char* fgets(char*, int, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#   210 |             fgets(str, 80, mol2file);
#       |             ~~~~~^~~~~~~~~~~~~~~~~~~
# src/pyMol2.cpp:213:14: warning: ignoring return value of ‘char* fgets(char*, int, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#   213 |         fgets(str, 80, mol2file);
#       |         ~~~~~^~~~~~~~~~~~~~~~~~~
# src/pyMol2.cpp:216:15: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’, declared with attribute warn_unused_result [-Wunused-result]
#   216 |         fscanf(mol2file, "%d %d %d %d %d", &this->N, &this->Nbonds, &this->Nres, &tint, &tint);
#       |         ~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyMol2.cpp:220:18: warning: ignoring return value of ‘char* fgets(char*, int, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#   220 |             fgets(str, 80, mol2file);
#       |             ~~~~~^~~~~~~~~~~~~~~~~~~
# src/pyMol2.cpp:225:19: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’, declared with attribute warn_unused_result [-Wunused-result]
#   225 |             fscanf(mol2file, "%d %s %f %f %f %s %d %s %f\n", &tint, str, &tx, &ty, &tz, tatomtype, &tres, resname, &tcharge);
#       |             ~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyMol2.cpp:280:18: warning: ignoring return value of ‘char* fgets(char*, int, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#   280 |             fgets(str, 80, mol2file);
#       |             ~~~~~^~~~~~~~~~~~~~~~~~~
# src/pyMol2.cpp:287:19: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’, declared with attribute warn_unused_result [-Wunused-result]
#   287 |             fscanf(mol2file, "%d%s%s%s\n", &tint, s1, s2, s3);
#       |             ~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/pyMol2.cpp: In member function ‘void Mol2::initialize_gaff()’:
# src/pyMol2.cpp:473:18: warning: ignoring return value of ‘char* fgets(char*, int, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#   473 |             fgets(str, 80, gaff_file);
#       |             ~~~~~^~~~~~~~~~~~~~~~~~~~
#
# g++ -fPIC -O3 -I/usr/local/include/python3.10 -I/usr/include/openbabel3 -I/usr/include/eigen3 -DBUILD=0 -DHAVE_EIGEN -Wunused-value src/pyRAND.cpp -c -o obj/pyRAND.o
#
# g++ -fPIC -O3 -I/usr/local/include/python3.10 -I/usr/include/openbabel3 -I/usr/include/eigen3 -DBUILD=0 -DHAVE_EIGEN -Wunused-value src/pyFindHB.cpp -c -o obj/pyFindHB.o
# In file included from /usr/local/include/boost/bind.hpp:30,
#                  from /usr/local/include/boost/python/exception_translator.hpp:10,
#                  from /usr/local/include/boost/python.hpp:28,
#                  from src/pyCOORD_MC.cpp:236:
# /usr/local/include/boost/bind.hpp:36:1: note: #pragma message: The practice of declaring the Bind placeholders (_1, _2, ...) in the global namespace is deprecated. Please use <boost/bind/bind.hpp> + using namespace boost::placeholders, or define BOOST_BIND_GLOBAL_PLACEHOLDERS to retain the current behavior.
#    36 | BOOST_PRAGMA_MESSAGE(
#       | ^~~~~~~~~~~~~~~~~~~~
# In file included from /usr/local/include/boost/bind.hpp:30,
#                  from /usr/local/include/boost/python/exception_translator.hpp:10,
#                  from /usr/local/include/boost/python.hpp:28,
#                  from src/pyRAND.cpp:84:
# /usr/local/include/boost/bind.hpp:36:1: note: #pragma message: The practice of declaring the Bind placeholders (_1, _2, ...) in the global namespace is deprecated. Please use <boost/bind/bind.hpp> + using namespace boost::placeholders, or define BOOST_BIND_GLOBAL_PLACEHOLDERS to retain the current behavior.
#    36 | BOOST_PRAGMA_MESSAGE(
#       | ^~~~~~~~~~~~~~~~~~~~
#
# g++ -fPIC -O3 -I/usr/local/include/python3.10 -I/usr/include/openbabel3 -I/usr/include/eigen3 -DBUILD=0 -DHAVE_EIGEN -Wunused-value src/pyEnergy2.cpp -c -o obj/pyEnergy2.o
#
# g++ -fPIC -O3 -I/usr/local/include/python3.10 -I/usr/include/openbabel3 -I/usr/include/eigen3 -DBUILD=0 -DHAVE_EIGEN -Wunused-value src/pyConformer.cpp -c -o obj/pyConformer.o
# In file included from /usr/local/include/boost/bind.hpp:30,
#                  from /usr/local/include/boost/python/exception_translator.hpp:10,
#                  from /usr/local/include/boost/python.hpp:28,
#                  from src/pyFindHB.cpp:444:
# /usr/local/include/boost/bind.hpp:36:1: note: #pragma message: The practice of declaring the Bind placeholders (_1, _2, ...) in the global namespace is deprecated. Please use <boost/bind/bind.hpp> + using namespace boost::placeholders, or define BOOST_BIND_GLOBAL_PLACEHOLDERS to retain the current behavior.
#    36 | BOOST_PRAGMA_MESSAGE(
#       | ^~~~~~~~~~~~~~~~~~~~
# In file included from /usr/local/include/boost/bind.hpp:30,
#                  from /usr/local/include/boost/python/exception_translator.hpp:10,
#                  from /usr/local/include/boost/python.hpp:28,
#                  from src/pyConformer.cpp:149:
# /usr/local/include/boost/bind.hpp:36:1: note: #pragma message: The practice of declaring the Bind placeholders (_1, _2, ...) in the global namespace is deprecated. Please use <boost/bind/bind.hpp> + using namespace boost::placeholders, or define BOOST_BIND_GLOBAL_PLACEHOLDERS to retain the current behavior.
#    36 | BOOST_PRAGMA_MESSAGE(
#       | ^~~~~~~~~~~~~~~~~~~~
# In file included from /usr/local/include/boost/bind.hpp:30,
#                  from /usr/local/include/boost/python/exception_translator.hpp:10,
#                  from /usr/local/include/boost/python.hpp:28,
#                  from src/pyEnergy2.cpp:1297:
# /usr/local/include/boost/bind.hpp:36:1: note: #pragma message: The practice of declaring the Bind placeholders (_1, _2, ...) in the global namespace is deprecated. Please use <boost/bind/bind.hpp> + using namespace boost::placeholders, or define BOOST_BIND_GLOBAL_PLACEHOLDERS to retain the current behavior.
#    36 | BOOST_PRAGMA_MESSAGE(
#       | ^~~~~~~~~~~~~~~~~~~~
#
# g++ -fPIC -O3 -I/usr/local/include/python3.10 -I/usr/include/openbabel3 -I/usr/include/eigen3 -DBUILD=0 -DHAVE_EIGEN -Wunused-value src/pyGaussian.cpp -c -o obj/pyGaussian.o
#
# g++ -fPIC -O3 -I/usr/local/include/python3.10 -I/usr/include/openbabel3 -I/usr/include/eigen3 -DBUILD=0 -DHAVE_EIGEN -Wunused-value src/pyMcEntropy.cpp -c -o obj/pyMcEntropy.o
#
# g++ -fPIC -O3 -I/usr/local/include/python3.10 -I/usr/include/openbabel3 -I/usr/include/eigen3 -DBUILD=0 -DHAVE_EIGEN -Wunused-value src/pySA.cpp -c -o obj/pySA.o
#
# g++ -fPIC -O3 -I/usr/local/include/python3.10 -I/usr/include/openbabel3 -I/usr/include/eigen3 -DBUILD=0 -DHAVE_EIGEN -Wunused-value src/pyMC.cpp -c -o obj/pyMC.o
# In file included from /usr/local/include/boost/bind.hpp:30,
#                  from /usr/local/include/boost/python/exception_translator.hpp:10,
#                  from /usr/local/include/boost/python.hpp:28,
#                  from src/pyGaussian.cpp:239:
# /usr/local/include/boost/bind.hpp:36:1: note: #pragma message: The practice of declaring the Bind placeholders (_1, _2, ...) in the global namespace is deprecated. Please use <boost/bind/bind.hpp> + using namespace boost::placeholders, or define BOOST_BIND_GLOBAL_PLACEHOLDERS to retain the current behavior.
#    36 | BOOST_PRAGMA_MESSAGE(
#       | ^~~~~~~~~~~~~~~~~~~~
# In file included from /usr/local/include/boost/bind.hpp:30,
#                  from /usr/local/include/boost/python/exception_translator.hpp:10,
#                  from /usr/local/include/boost/python.hpp:28,
#                  from src/pyMcEntropy.cpp:242:
# /usr/local/include/boost/bind.hpp:36:1: note: #pragma message: The practice of declaring the Bind placeholders (_1, _2, ...) in the global namespace is deprecated. Please use <boost/bind/bind.hpp> + using namespace boost::placeholders, or define BOOST_BIND_GLOBAL_PLACEHOLDERS to retain the current behavior.
#    36 | BOOST_PRAGMA_MESSAGE(
#       | ^~~~~~~~~~~~~~~~~~~~
#
# g++ -fPIC -O3 -I/usr/local/include/python3.10 -I/usr/include/openbabel3 -I/usr/include/eigen3 -DBUILD=0 -DHAVE_EIGEN -Wunused-value src/pyOptimizer.cpp -c -o obj/pyOptimizer.o
# In file included from /usr/local/include/boost/bind.hpp:30,
#                  from /usr/local/include/boost/python/exception_translator.hpp:10,
#                  from /usr/local/include/boost/python.hpp:28,
#                  from src/pySA.cpp:171:
# /usr/local/include/boost/bind.hpp:36:1: note: #pragma message: The practice of declaring the Bind placeholders (_1, _2, ...) in the global namespace is deprecated. Please use <boost/bind/bind.hpp> + using namespace boost::placeholders, or define BOOST_BIND_GLOBAL_PLACEHOLDERS to retain the current behavior.
#    36 | BOOST_PRAGMA_MESSAGE(
#       | ^~~~~~~~~~~~~~~~~~~~
#
# Building FULLSEARCH dynamic library.
# g++ -shared obj/pyMol2.o obj/pyPARSER.o obj/pyConformer.o obj/pyWRITER.o obj/pyCOORD_MC.o obj/pyGrid.o obj/pyEnergy2.o -o pyFullSearch.so -L/usr/lib/x86_64-linux-gnu -lboost_python310 -lz -lopenbabel -lgsl -lnlopt_cxx -lgsl -lgslcblas -lm
#
# Building PARSER dynamic library.
# g++ -shared obj/pyPARSER.o -o pyPARSER.so -L/usr/lib/x86_64-linux-gnu -lboost_python310 -lz -lopenbabel -lgsl -lnlopt_cxx -lgsl -lgslcblas -lm
# In file included from /usr/local/include/boost/bind.hpp:30,
#                  from /usr/local/include/boost/python/exception_translator.hpp:10,
#                  from /usr/local/include/boost/python.hpp:28,
#                  from src/pyMC.cpp:1337:
# /usr/local/include/boost/bind.hpp:36:1: note: #pragma message: The practice of declaring the Bind placeholders (_1, _2, ...) in the global namespace is deprecated. Please use <boost/bind/bind.hpp> + using namespace boost::placeholders, or define BOOST_BIND_GLOBAL_PLACEHOLDERS to retain the current behavior.
#    36 | BOOST_PRAGMA_MESSAGE(
#       | ^~~~~~~~~~~~~~~~~~~~
#
# Building MOL2 dynamic library.
# g++ -shared obj/pyMol2.o obj/pyPARSER.o -o pyMol2.so -L/usr/lib/x86_64-linux-gnu -lboost_python310 -lz -lopenbabel -lgsl -lnlopt_cxx -lgsl -lgslcblas -lm
#
# Building WRITER dynamic library.
# g++ -shared obj/pyWRITER.o obj/pyMol2.o obj/pyPARSER.o -o pyWRITER.so -L/usr/lib/x86_64-linux-gnu -lboost_python310 -lz -lopenbabel -lgsl -lnlopt_cxx -lgsl -lgslcblas -lm
#
# Building GRID dynamic library.
# g++ -shared obj/pyGrid.o obj/pyMol2.o obj/pyPARSER.o obj/pyWRITER.o -o pyGrid.so -L/usr/lib/x86_64-linux-gnu -lboost_python310 -lz -lopenbabel -lgsl -lnlopt_cxx -lgsl -lgslcblas -lm
#
# Building COORD_MC dynamic library.
# g++ -shared obj/pyCOORD_MC.o obj/pyRAND.o obj/pyMol2.o -o pyCOORD_MC.so -L/usr/lib/x86_64-linux-gnu -lboost_python310 -lz -lopenbabel -lgsl -lnlopt_cxx -lgsl -lgslcblas -lm
#
# Building FIND_HB dynamic library.
# g++ -shared obj/pyFindHB.o obj/pyMol2.o obj/pyPARSER.o obj/pyCOORD_MC.o -o pyFindHB.so -L/usr/lib/x86_64-linux-gnu -lboost_python310 -lz -lopenbabel -lgsl -lnlopt_cxx -lgsl -lgslcblas -lm
#
# Building ENERGY2 dynamic library.
# g++ -shared obj/pyEnergy2.o obj/pyPARSER.o obj/pyMol2.o obj/pyGrid.o obj/pyWRITER.o -o pyEnergy2.so -L/usr/lib/x86_64-linux-gnu -lboost_python310 -lz -lopenbabel -lgsl -lnlopt_cxx -lgsl -lgslcblas -lm
#
# Building CONFORMER dynamic library.
# g++ -shared obj/pyConformer.o obj/pyPARSER.o obj/pyMol2.o -o pyConformer.so -L/usr/lib/x86_64-linux-gnu -lboost_python310 -lz -lopenbabel -lgsl -lnlopt_cxx -lgsl -lgslcblas -lm
#
# Building RAND dynamic library.
# g++ -shared obj/pyRAND.o obj/pyPARSER.o obj/pyMol2.o -o pyRAND.so -L/usr/lib/x86_64-linux-gnu -lboost_python310 -lz -lopenbabel -lgsl -lnlopt_cxx -lgsl -lgslcblas -lm
#
# Building GAUSSIAN dynamic library.
# g++ -shared obj/pyGaussian.o obj/pyMol2.o obj/pyPARSER.o -o pyGaussian.so -L/usr/lib/x86_64-linux-gnu -lboost_python310 -lz -lopenbabel -lgsl -lnlopt_cxx -lgsl -lgslcblas -lm
#
# Building MCENTROPY dynamic library.
# g++ -shared obj/pyMcEntropy.o obj/pyPARSER.o obj/pyMol2.o obj/pyCOORD_MC.o -o pyMcEntropy.so -L/usr/lib/x86_64-linux-gnu -lboost_python310 -lz -lopenbabel -lgsl -lnlopt_cxx -lgsl -lgslcblas -lm
#
# Building SA dynamic library.
# g++ -shared obj/pySA.o obj/pyMol2.o obj/pyGrid.o obj/pyEnergy2.o obj/pyCOORD_MC.o obj/pyWRITER.o obj/pyPARSER.o -o pySA.so -L/usr/lib/x86_64-linux-gnu -lboost_python310 -lz -lopenbabel -lgsl -lnlopt_cxx -lgsl -lgslcblas -lm
#
#
# In file included from /usr/local/include/boost/bind.hpp:30,
#                  from /usr/local/include/boost/python/exception_translator.hpp:10,
#                  from /usr/local/include/boost/python.hpp:28,
#                  from src/pyOptimizer.cpp:1528:
# /usr/local/include/boost/bind.hpp:36:1: note: #pragma message: The practice of declaring the Bind placeholders (_1, _2, ...) in the global namespace is deprecated. Please use <boost/bind/bind.hpp> + using namespace boost::placeholders, or define BOOST_BIND_GLOBAL_PLACEHOLDERS to retain the current behavior.
#    36 | BOOST_PRAGMA_MESSAGE(
#       | ^~~~~~~~~~~~~~~~~~~~
#
# Building OPTIMIZER dynamic library.
# g++ -shared obj/pyOptimizer.o obj/pyMol2.o obj/pyEnergy2.o obj/pyPARSER.o obj/pyCOORD_MC.o obj/pyGaussian.o obj/pyWRITER.o obj/pySA.o obj/pyGrid.o -o pyOptimizer.so -L/usr/lib/x86_64-linux-gnu -lboost_python310 -lz -lopenbabel -lgsl -lnlopt_cxx -lgsl -lgslcblas -lm
# Building DOCKER dynamic library.
# g++ -shared obj/pyMol2.o obj/pyOptimizer.o obj/pyPARSER.o obj/pyWRITER.o obj/pyCOORD_MC.o obj/pyGrid.o -o pyDocker.so -L/usr/lib/x86_64-linux-gnu -lboost_python310 -lz -lopenbabel -lgsl -lnlopt_cxx -lgsl -lgslcblas -lm
#
#
#
# Building MC dynamic library.
# g++ -shared obj/pyMC.o obj/pyPARSER.o obj/pyGrid.o obj/pyMol2.o obj/pyCOORD_MC.o obj/pyEnergy2.o obj/pyWRITER.o obj/pyMcEntropy.o obj/pyOptimizer.o -o pyMC.so -L/usr/lib/x86_64-linux-gnu -lboost_python310 -lz -lopenbabel -lgsl -lnlopt_cxx -lgsl -lgslcblas -lm

# %%
from pyPARSER import *
from pyMol2 import *
from pyWRITER import *
from pyGrid import *
from pyCOORD_MC import *
from pyFindHB import * 
from pyEnergy2 import *
from pyGaussian import *
from pyMcEntropy import *
from pySA import *
from pyOptimizer import *
# Out:
# <frozen importlib._bootstrap>:241: RuntimeWarning: to-Python converter for Optimizer already registered; second conversion method ignored.
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# <ipython-input-12-b43de901b2d8> in <cell line: 11>()
#       9 from pyMcEntropy import *
#      10 from pySA import *
# ---> 11 from pyOptimizer import *
#
# SystemError: initialization of pyOptimizer raised unreported exception

# %%
Input = PARSER()
Input.output = "teste" #@param {type:"string"}
Input.scoring_function = 0 #@param {type:"integer"}
Input.use_grids = True #@param {type:"boolean"}
Input.grid_prefix = "McGrid" #@param {type:"string"}
Input.search_box_x = 30.0 #@param {type:"number"}
Input.search_box_y = 30.0 #@param {type:"number"}
Input.search_box_z = 30.0 #@param {type:"number"}
Input.grid_spacing = 0.3 #@param {type:"number"}
Input.x_dim = 8.0 #@param {type:"number"}
Input.y_dim = 8.0 #@param {type:"number"}
Input.z_dim = 8.0 #@param {type:"number"}
Input.write_grids = True;

# %%
Writer = WRITER(Input)
Coord = COORD_MC()
HB = FindHB()
lig = Mol2(Input, "test/lig.mol2.gz")
rec = Mol2(Input, "test/rec.mol2.gz")
Energy = Energy2(Input)

for i in range(len(list(rec.residue_pointer))-1):
  HB.parse_residue(rec.residue_pointer[i]-1, rec.residue_pointer[i+1]-2, rec.resnames[i], rec, lig, 9.0)

HB.find_ligandHB("test/lig.mol2.gz", lig)

com = Coord.compute_com(lig)

energy1 = Energy.compute_ene(rec, lig, lig.xyz)
print("Original energy: %7.3f" % energy1)

Input.write_grids = True;
Grids = Grid(Input, Writer, rec, com)

energy2 = Energy.compute_ene(Grids, lig, lig.xyz)
print("Grid energy: %7.3f" % energy2)
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `('
# /bin/bash: -c: line 0: `Writer = WRITER(Input)'
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-8-20f827a324b4> in <cell line: 1>()
# ----> 1 get_ipython().run_cell_magic('shell', '', 'Writer = WRITER(Input)\nCoord = COORD_MC()\nHB = FindHB()\nlig = Mol2(Input, "test/lig.mol2.gz")\nrec = Mol2(Input, "test/rec.mol2.gz")\nEnergy = Energy2(Input)\n\nfor i in range(len(list(rec.residue_pointer))-1):\n  HB.parse_residue(rec.residue_pointer[i]-1, rec.residue_pointer[i+1]-2, rec.resnames[i], rec, lig, 9.0)\n\nHB.find_ligandHB("test/lig.mol2.gz", lig)\n\ncom = Coord.compute_com(lig)\n\nenergy1 = Energy.compute_ene(rec, lig, lig.xyz)\nprint("Original energy: %7.3f" % energy1)\n\nInput.write_grids = True;\nGrids = Grid(Input, Writer, rec, com)\n\nenergy2 = Energy.compute_ene(Grids, lig, lig.xyz)\nprint("Grid energy: %7.3f" % energy2)\n     \n')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     332     if line and not cell:
#     333       cell = ' '
# --> 334     return super().run_cell_magic(magic_name, line, cell)
#     335
#     336
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_system_commands.py in _shell_cell_magic(args, cmd)
#     110   result = _run_command(cmd, clear_streamed_output=False)
#     111   if not parsed_args.ignore_errors:
# --> 112     result.check_returncode()
#     113   return result
#     114
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_system_commands.py in check_returncode(self)
#     135   def check_returncode(self):
#     136     if self.returncode:
# --> 137       raise subprocess.CalledProcessError(
#     138           returncode=self.returncode, cmd=self.args, output=self.output
#     139       )
#
# CalledProcessError: Command 'Writer = WRITER(Input)
# Coord = COORD_MC()
# HB = FindHB()
# lig = Mol2(Input, "test/lig.mol2.gz")
# rec = Mol2(Input, "test/rec.mol2.gz")
# Energy = Energy2(Input)
#
# for i in range(len(list(rec.residue_pointer))-1):
#   HB.parse_residue(rec.residue_pointer[i]-1, rec.residue_pointer[i+1]-2, rec.resnames[i], rec, lig, 9.0)
#
# HB.find_ligandHB("test/lig.mol2.gz", lig)
#
# com = Coord.compute_com(lig)
#
# energy1 = Energy.compute_ene(rec, lig, lig.xyz)
# print("Original energy: %7.3f" % energy1)
#
# Input.write_grids = True;
# Grids = Grid(Input, Writer, rec, com)
#
# energy2 = Energy.compute_ene(Grids, lig, lig.xyz)
# print("Grid energy: %7.3f" % energy2)
#
# ' returned non-zero exit status 1.

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %conda  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %shell  %store  %sx  %system  %tb  %tensorflow_version  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%bigquery  %%capture  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%markdown  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%shell  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.
